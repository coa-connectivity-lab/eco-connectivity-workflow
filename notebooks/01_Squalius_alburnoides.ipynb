# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Squalius_alburnoides'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Squalius_alburnoides.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Squalius_alburnoides

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Squalius_alburnoides/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Squalius_alburnoides/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Squalius_alburnoides/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Squalius_alburnoides/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Squalius_alburnoides/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Squalius_alburnoides/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Squalius_alburnoides/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Squalius_alburnoides/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (568, 230)
#        gbifID  accessRights  bibliographicCitation  language       license  \
# 0  5935857958           NaN                    NaN       NaN  CC_BY_NC_4_0
# 1  5935768517           NaN                    NaN       NaN  CC_BY_NC_4_0
# 2  5920209974           NaN                    NaN       NaN  CC_BY_NC_4_0
# 3  5760897036           NaN                    NaN       NaN  CC_BY_NC_4_0
# 4  5293280162           NaN                    NaN       NaN     CC_BY_4_0
#
#                modified  publisher  \
# 0  2025-12-23T16:53:34Z        NaN
# 1  2025-12-22T21:48:42Z        NaN
# 2  2025-12-06T03:02:44Z        NaN
# 3  2025-08-22T10:21:57Z        NaN
# 4  2025-08-12T09:12:52Z        NaN
#
#                                           references           rightsHolder  \
# 0  https://www.inaturalist.org/observations/21220...              João Lima
# 1  https://www.inaturalist.org/observations/28013...      Miguel Berkemeier
# 2  https://www.inaturalist.org/observations/17784...       Thijs Valkenburg
# 3  https://www.inaturalist.org/observations/21488...  pedro_fonseca_alverca
# 4  https://www.inaturalist.org/observations/30563...           Duarte Frade
#
#   type  ... publishedByGbifRegion  level0Gid  level0Name level1Gid level1Name  \
# 0  NaN  ...         NORTH_AMERICA        NaN         NaN       NaN        NaN
# 1  NaN  ...         NORTH_AMERICA        NaN         NaN       NaN        NaN
# 2  NaN  ...         NORTH_AMERICA        NaN         NaN       NaN        NaN
# 3  NaN  ...         NORTH_AMERICA        NaN         NaN       NaN        NaN
# 4  NaN  ...         NORTH_AMERICA        NaN         NaN       NaN        NaN
#
#   level2Gid level2Name level3Gid level3Name  iucnRedListCategory
# 0       NaN        NaN       NaN        NaN                   LC
# 1       NaN        NaN       NaN        NaN                   LC
# 2       NaN        NaN       NaN        NaN                   LC
# 3       NaN        NaN       NaN        NaN                   LC
# 4       NaN        NaN       NaN        NaN                   LC
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (568, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (568, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (568, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (568, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (568, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (162, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (123, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (123, 12)
#         gbifID               species  decimalLatitude  decimalLongitude  \
# 18  4539325026  Squalius alburnoides        41.500448         -6.668625
# 19  4539324975  Squalius alburnoides        41.491651         -6.660076
# 20  4539324957  Squalius alburnoides        41.722137         -6.664052
# 21  4539324829  Squalius alburnoides        41.454831         -6.593814
# 22  4539324828  Squalius alburnoides        41.573917         -6.675192
#
#    countryCode   eventDate      basisOfRecord  coordinateUncertaintyInMeters  \
# 18          PT  2023-06-29  HUMAN_OBSERVATION                            5.0
# 19          PT  2021-06-29  HUMAN_OBSERVATION                            5.0
# 20          PT  2021-07-15  HUMAN_OBSERVATION                            5.0
# 21          PT  2023-07-12  HUMAN_OBSERVATION                            5.0
# 22          PT  2023-06-28  HUMAN_OBSERVATION                            5.0
#
#     year  month  day                   geometry
# 18  2023      6   29  POINT (-6.66862 41.50045)
# 19  2021      6   29  POINT (-6.66008 41.49165)
# 20  2021      7   15  POINT (-6.66405 41.72214)
# 21  2023      7   12  POINT (-6.59381 41.45483)
# 22  2023      6   28  POINT (-6.67519 41.57392)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Squalius_alburnoides

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Squalius_alburnoides/Squalius_alburnoides.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Squalius_alburnoides/Squalius_alburnoides.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Squalius_alburnoides/Squalius_alburnoides.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Squalius_alburnoides/Squalius_alburnoides.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Squalius_alburnoides
# Records: 123
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Squalius_alburnoides/Squalius_alburnoides.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Squalius_alburnoides/Squalius_alburnoides.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Squalius_alburnoides/Squalius_alburnoides.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Squalius_alburnoides/Squalius_alburnoides.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b6bd12d494a13eb93a50892f66e17f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b6bd12d494a13eb93a50892f66e17f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b6bd12d494a13eb93a50892f66e17f6 = L.map(
#                 &quot;map_9b6bd12d494a13eb93a50892f66e17f6&quot;,
#                 {
#                     center: [41.32736270731707, -6.987036577235772],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45ecf1f35ffc50423a7db67861aeacc0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_45ecf1f35ffc50423a7db67861aeacc0.addTo(map_9b6bd12d494a13eb93a50892f66e17f6);
#
#
#             var marker_cluster_9921ed6b4f6e9c91313b1841b3d51caa = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_e5c82c5f88fdcfb62c920d812c5da773 = L.circleMarker(
#                 [41.500448, -6.668625],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_9921ed6b4f6e9c91313b1841b3d51caa);
#
#
#         var popup_25be95676ea9aad0d438ea70c024589d = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_ec4565530cc9421140efd983de95dedb = $(`&lt;div id=&quot;html_ec4565530cc9421140efd983de95dedb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 4539325026&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Squalius alburnoides&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2023-06-29&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 5.0     &lt;/div&gt;`)[0];
#                 popup_25be95676ea9aad0d438ea70c024589d.setContent(html_ec4565530cc9421140efd983de95dedb);
#
#
#
#         circle_marker_e5c82c5f88fdcfb62c920d812c5da773.bindPopup(popup_25be95676ea9aad0d438ea70c024589d)
#         ;
#
#
#
#
#             var circle_marker_0607101734b4980b1bbcff62b47bb665 = L.circleMarker(
#                 [41.491651, -6.660076],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_9921ed6b4f6e9c91313b1841b3d51caa);
#
#
#         var popup_cae857750f3a2abfff9bc222932adac0 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_17fb1c10a0f3dd565d5ba431870b5586 = $(`&lt;div id=&quot;html_17fb1c10a0f3dd565d5ba431870b5586&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 4539324975&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Squalius alburnoides&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2021-06-29&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 5.0     &lt;/div&gt;`)[0];
#                 popup_cae857750f3a2abfff9bc222932adac0.setContent(html_17fb1c10a0f3dd565d5ba431870b5586);
#
#
#
#         circle_marker_0607101734b4980b1bbcff62b47bb665.bindPopup(popup_cae857750f3a2abfff9bc222932adac0)
#         ;
#
#
#
#
#             var circle_marker_2b86d58db935076b54482bd56414b3f6 = L.circleMarker(
#                 [41.722137, -6.664052],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: nul

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 123

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 123

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e82bc5c75ae98eca4af82a1f1dd0fd95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e82bc5c75ae98eca4af82a1f1dd0fd95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e82bc5c75ae98eca4af82a1f1dd0fd95 = L.map(
#                 &quot;map_e82bc5c75ae98eca4af82a1f1dd0fd95&quot;,
#                 {
#                     center: [41.32736270731707, -6.987036577235772],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a1835265656954ff79a5bd87ebcad8a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a1835265656954ff79a5bd87ebcad8a.addTo(map_e82bc5c75ae98eca4af82a1f1dd0fd95);
#
#
#             var circle_marker_600a0f31ebfcf6e1eacd73607d595fc5 = L.circleMarker(
#                 [41.500448, -6.668625],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e82bc5c75ae98eca4af82a1f1dd0fd95);
#
#
#         var popup_c8e3f9453fca477e18a68294ca651764 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_880a30253ca5ea311a037a5e989b93f0 = $(`&lt;div id=&quot;html_880a30253ca5ea311a037a5e989b93f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 4539325026&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Squalius alburnoides&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_c8e3f9453fca477e18a68294ca651764.setContent(html_880a30253ca5ea311a037a5e989b93f0);
#
#
#
#         circle_marker_600a0f31ebfcf6e1eacd73607d595fc5.bindPopup(popup_c8e3f9453fca477e18a68294ca651764)
#         ;
#
#
#
#
#             var circle_marker_a76aa6e55a253f47cd68b1e4a8838b4b = L.circleMarker(
#                 [41.491651, -6.660076],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e82bc5c75ae98eca4af82a1f1dd0fd95);
#
#
#         var popup_74e3b080dde98484a92c03df890264cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_258d119f7a8fd34d8fb9d97de11d47b1 = $(`&lt;div id=&quot;html_258d119f7a8fd34d8fb9d97de11d47b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 4539324975&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Squalius alburnoides&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_74e3b080dde98484a92c03df890264cd.setContent(html_258d119f7a8fd34d8fb9d97de11d47b1);
#
#
#
#         circle_marker_a76aa6e55a253f47cd68b1e4a8838b4b.bindPopup(popup_74e3b080dde98484a92c03df890264cd)
#         ;
#
#
#
#
#             var circle_marker_84b99fe3b8208335616abb3cf0abb707 = L.circleMarker(
#                 [41.722137, -6.664052],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e82bc5c75ae98eca4af82a1f1dd0fd95);
#
#
#         var popup_5981cb2a8ffb1702eea443b12e6337ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_588e4b5008230d6a0cffb75fc6fcb2a3 = $(`&lt;div id=&quot;html_588e4b5008230d6a0cffb75fc6fcb2a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 4539324957&lt;br&gt;     &lt;b&g

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Squalius_alburnoides/Squalius_alburnoides_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Squalius_alburnoides/Squalius_alburnoides_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Squalius_alburnoides/Squalius_alburnoides_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID               species  decimalLatitude  decimalLongitude  \
# 0  4539325026  Squalius alburnoides        41.500448         -6.668625
# 1  4539324975  Squalius alburnoides        41.491651         -6.660076
# 2  4539324957  Squalius alburnoides        41.722137         -6.664052
# 3  4539324829  Squalius alburnoides        41.454831         -6.593814
# 4  4539324828  Squalius alburnoides        41.573917         -6.675192
#
#   countryCode   eventDate      basisOfRecord  coordinateUncertaintyInMeters  \
# 0          PT  2023-06-29  HUMAN_OBSERVATION                            5.0
# 1          PT  2021-06-29  HUMAN_OBSERVATION                            5.0
# 2          PT  2021-07-15  HUMAN_OBSERVATION                            5.0
# 3          PT  2023-07-12  HUMAN_OBSERVATION                            5.0
# 4          PT  2023-06-28  HUMAN_OBSERVATION                            5.0
#
#    year  month  day                   geometry
# 0  2023      6   29  POINT (-6.66862 41.50045)
# 1  2021      6   29  POINT (-6.66008 41.49165)
# 2  2021      7   15  POINT (-6.66405 41.72214)
# 3  2023      7   12  POINT (-6.59381 41.45483)
# 4  2023      6   28  POINT (-6.67519 41.57392)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count    118.000000
# mean       5.203390
# std        0.790535
# min        5.000000
# 25%        5.000000
# 50%        5.000000
# 75%        5.000000
# max       10.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 123 original records
# 118 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Squalius_alburnoides/Squalius_alburnoides_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="spp_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Squalius_alburnoides/Squalius_alburnoides_clean.gpkg

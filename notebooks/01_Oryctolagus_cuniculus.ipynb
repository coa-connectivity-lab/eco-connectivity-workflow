# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Oryctolagus_cuniculus'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Oryctolagus_cuniculus.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Oryctolagus_cuniculus

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Oryctolagus_cuniculus/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Oryctolagus_cuniculus/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Oryctolagus_cuniculus/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Oryctolagus_cuniculus/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Oryctolagus_cuniculus/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Oryctolagus_cuniculus/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Oryctolagus_cuniculus/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Oryctolagus_cuniculus/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (2043, 230)
#        gbifID  accessRights  bibliographicCitation  language       license  \
# 0  6236362750           NaN                    NaN       NaN  CC_BY_NC_4_0
# 1  6236315522           NaN                    NaN       NaN  CC_BY_NC_4_0
# 2  6236251282           NaN                    NaN       NaN  CC_BY_NC_4_0
# 3  6236013426           NaN                    NaN       NaN     CC_BY_4_0
# 4  6235969439           NaN                    NaN       NaN     CC_BY_4_0
#
#                modified  publisher  \
# 0  2026-04-22T10:49:18Z        NaN
# 1  2026-04-17T16:13:36Z        NaN
# 2  2026-04-19T15:38:28Z        NaN
# 3  2026-04-27T18:35:21Z        NaN
# 4  2026-04-21T01:54:17Z        NaN
#
#                                           references   rightsHolder type  ...  \
# 0  https://www.inaturalist.org/observations/35193...     Luís Ramos  NaN  ...
# 1  https://www.inaturalist.org/observations/35050...         Filipa  NaN  ...
# 2  https://www.inaturalist.org/observations/35111...        alex_sp  NaN  ...
# 3  https://www.inaturalist.org/observations/35119...  Luís Ferreira  NaN  ...
# 4  https://www.inaturalist.org/observations/35155...  David Pereira  NaN  ...
#
#   publishedByGbifRegion  level0Gid  level0Name level1Gid level1Name level2Gid  \
# 0         NORTH_AMERICA        NaN         NaN       NaN        NaN       NaN
# 1                EUROPE        NaN         NaN       NaN        NaN       NaN
# 2                EUROPE        NaN         NaN       NaN        NaN       NaN
# 3                EUROPE        NaN         NaN       NaN        NaN       NaN
# 4         NORTH_AMERICA        NaN         NaN       NaN        NaN       NaN
#
#   level2Name level3Gid level3Name iucnRedListCategory
# 0        NaN       NaN        NaN                  EN
# 1        NaN       NaN        NaN                  EN
# 2        NaN       NaN        NaN                  EN
# 3        NaN       NaN        NaN                  EN
# 4        NaN       NaN        NaN                  EN
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (2043, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (2043, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (2043, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (2043, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (2043, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (1797, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (726, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (726, 12)
#         gbifID                species  decimalLatitude  decimalLongitude  \
# 9   6234803052  Oryctolagus cuniculus        33.044362        -16.368102
# 13  6228336367  Oryctolagus cuniculus        37.176184         -7.470660
# 14  6228334596  Oryctolagus cuniculus        37.770962        -25.304750
# 15  6196004780  Oryctolagus cuniculus        38.729615        -27.230950
# 39  6185110536  Oryctolagus cuniculus        37.838815        -25.794780
#
#    countryCode             eventDate      basisOfRecord  \
# 9           PT      2026-04-13T17:25  HUMAN_OBSERVATION
# 13          PT            2025-02-20  HUMAN_OBSERVATION
# 14          PT            2026-04-25  HUMAN_OBSERVATION
# 15          PT  2026-04-07T10:26:38Z  HUMAN_OBSERVATION
# 39          PT  2025-07-29T17:58:58Z  HUMAN_OBSERVATION
#
#     coordinateUncertaintyInMeters  year  month  day  \
# 9                            15.0  2026      4   13
# 13                           38.0  2025      2   20
# 14                            5.0  2026      4   25
# 15                            9.0  2026      4    7
# 39                            NaN  2025      7   29
#
#                       geometry
# 9    POINT (-16.3681 33.04436)
# 13   POINT (-7.47066 37.17618)
# 14  POINT (-25.30475 37.77096)
# 15  POINT (-27.23095 38.72962)
# 39  POINT (-25.79478 37.83882)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Oryctolagus_cuniculus

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Oryctolagus_cuniculus/Oryctolagus_cuniculus.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Oryctolagus_cuniculus/Oryctolagus_cuniculus.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Oryctolagus_cuniculus/Oryctolagus_cuniculus.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Oryctolagus_cuniculus/Oryctolagus_cuniculus.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Oryctolagus_cuniculus
# Records: 726
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Oryctolagus_cuniculus/Oryctolagus_cuniculus.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Oryctolagus_cuniculus/Oryctolagus_cuniculus.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Oryctolagus_cuniculus/Oryctolagus_cuniculus.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Oryctolagus_cuniculus/Oryctolagus_cuniculus.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e917aa3558ddf6152759c1066b78e0f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e917aa3558ddf6152759c1066b78e0f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e917aa3558ddf6152759c1066b78e0f7 = L.map(
#                 &quot;map_e917aa3558ddf6152759c1066b78e0f7&quot;,
#                 {
#                     center: [38.917901100550964, -11.454621340220385],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8b08bcc037e5d3290de4da7d0b882ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f8b08bcc037e5d3290de4da7d0b882ff.addTo(map_e917aa3558ddf6152759c1066b78e0f7);
#
#
#             var marker_cluster_7ad6e60cf44ae32d2ca531e1f3c4a9df = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_bf1b273d85d696fdb494b808a32b8852 = L.circleMarker(
#                 [33.044362, -16.368102],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_7ad6e60cf44ae32d2ca531e1f3c4a9df);
#
#
#         var popup_920ee72220e61ed47e536165225bfe01 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_20d43522f29bfd27c1c47519f639f5cf = $(`&lt;div id=&quot;html_20d43522f29bfd27c1c47519f639f5cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6234803052&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Oryctolagus cuniculus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-04-13T17:25&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 15.0     &lt;/div&gt;`)[0];
#                 popup_920ee72220e61ed47e536165225bfe01.setContent(html_20d43522f29bfd27c1c47519f639f5cf);
#
#
#
#         circle_marker_bf1b273d85d696fdb494b808a32b8852.bindPopup(popup_920ee72220e61ed47e536165225bfe01)
#         ;
#
#
#
#
#             var circle_marker_6f2445a023e24241f90e8ed0ffc41d7d = L.circleMarker(
#                 [37.176184, -7.47066],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_7ad6e60cf44ae32d2ca531e1f3c4a9df);
#
#
#         var popup_1c24b97340d2916010eff13fbefd8260 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_e82f687702d73d94f361964eaf92b070 = $(`&lt;div id=&quot;html_e82f687702d73d94f361964eaf92b070&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6228336367&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Oryctolagus cuniculus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2025-02-20&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 38.0     &lt;/div&gt;`)[0];
#                 popup_1c24b97340d2916010eff13fbefd8260.setContent(html_e82f687702d73d94f361964eaf92b070);
#
#
#
#         circle_marker_6f2445a023e24241f90e8ed0ffc41d7d.bindPopup(popup_1c24b97340d2916010eff13fbefd8260)
#         ;
#
#
#
#
#             var circle_marker_2e300ce51afd68fc06432b58b408ff67 = L.circleMarker(
#                 [37.770962, -25.30475],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffse

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 726

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 726

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_02affa6526d7bedfb0f05b4445cc2a26 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_02affa6526d7bedfb0f05b4445cc2a26&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_02affa6526d7bedfb0f05b4445cc2a26 = L.map(
#                 &quot;map_02affa6526d7bedfb0f05b4445cc2a26&quot;,
#                 {
#                     center: [38.917901100550964, -11.454621340220385],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d82c439bad3eef13084419620f789490 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d82c439bad3eef13084419620f789490.addTo(map_02affa6526d7bedfb0f05b4445cc2a26);
#
#
#             var circle_marker_0ca477622270f1c7eb6437ecff5beceb = L.circleMarker(
#                 [33.044362, -16.368102],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_02affa6526d7bedfb0f05b4445cc2a26);
#
#
#         var popup_580d6ba15eb7b1c546c29ff4bb0d60bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cb6f651bc865ee98b4036911478dd84 = $(`&lt;div id=&quot;html_1cb6f651bc865ee98b4036911478dd84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6234803052&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Oryctolagus cuniculus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_580d6ba15eb7b1c546c29ff4bb0d60bd.setContent(html_1cb6f651bc865ee98b4036911478dd84);
#
#
#
#         circle_marker_0ca477622270f1c7eb6437ecff5beceb.bindPopup(popup_580d6ba15eb7b1c546c29ff4bb0d60bd)
#         ;
#
#
#
#
#             var circle_marker_b8717f90d9944d3941a86dfb48a09b51 = L.circleMarker(
#                 [37.176184, -7.47066],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_02affa6526d7bedfb0f05b4445cc2a26);
#
#
#         var popup_f009bc5486d011ec870cd19fd7f7740b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65dcf3c3c76af5eea1479f22060604a2 = $(`&lt;div id=&quot;html_65dcf3c3c76af5eea1479f22060604a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6228336367&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Oryctolagus cuniculus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_f009bc5486d011ec870cd19fd7f7740b.setContent(html_65dcf3c3c76af5eea1479f22060604a2);
#
#
#
#         circle_marker_b8717f90d9944d3941a86dfb48a09b51.bindPopup(popup_f009bc5486d011ec870cd19fd7f7740b)
#         ;
#
#
#
#
#             var circle_marker_283f7d08326a1bc7f000556e56ccdc53 = L.circleMarker(
#                 [37.770962, -25.30475],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_02affa6526d7bedfb0f05b4445cc2a26);
#
#
#         var popup_58cb6270f642663ad358c42cd45f971b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81e25089b714dbc6ff728115c343f1ac = $(`&lt;div id=&quot;html_81e25089b714dbc6ff728115c343f1ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6228334596&lt;br&gt;     &lt

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Oryctolagus_cuniculus/Oryctolagus_cuniculus_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Oryctolagus_cuniculus/Oryctolagus_cuniculus_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Oryctolagus_cuniculus/Oryctolagus_cuniculus_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID                species  decimalLatitude  decimalLongitude  \
# 0  6234803052  Oryctolagus cuniculus        33.044362        -16.368102
# 1  6228336367  Oryctolagus cuniculus        37.176184         -7.470660
# 2  6228334596  Oryctolagus cuniculus        37.770962        -25.304750
# 3  6196004780  Oryctolagus cuniculus        38.729615        -27.230950
# 4  6185110536  Oryctolagus cuniculus        37.838815        -25.794780
#
#   countryCode                  eventDate      basisOfRecord  \
# 0          PT        2026-04-13T17:25:00  HUMAN_OBSERVATION
# 1          PT        2025-02-20T00:00:00  HUMAN_OBSERVATION
# 2          PT        2026-04-25T00:00:00  HUMAN_OBSERVATION
# 3          PT  2026-04-07T10:26:38+00:00  HUMAN_OBSERVATION
# 4          PT  2025-07-29T17:58:58+00:00  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month  day                    geometry
# 0                           15.0  2026      4   13   POINT (-16.3681 33.04436)
# 1                           38.0  2025      2   20   POINT (-7.47066 37.17618)
# 2                            5.0  2026      4   25  POINT (-25.30475 37.77096)
# 3                            9.0  2026      4    7  POINT (-27.23095 38.72962)
# 4                            NaN  2025      7   29  POINT (-25.79478 37.83882)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count     670.000000
# mean       76.956716
# std       202.216713
# min         1.000000
# 25%         5.000000
# 50%        15.000000
# 75%       100.000000
# max      2134.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 726 original records
# 425 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Oryctolagus_cuniculus/Oryctolagus_cuniculus_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="spp_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Oryctolagus_cuniculus/Oryctolagus_cuniculus_clean.gpkg

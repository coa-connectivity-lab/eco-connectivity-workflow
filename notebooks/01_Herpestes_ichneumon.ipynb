# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Herpestes_ichneumon'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Herpestes_ichneumon.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Herpestes_ichneumon

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Herpestes_ichneumon/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Herpestes_ichneumon/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Herpestes_ichneumon/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Herpestes_ichneumon/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Herpestes_ichneumon/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Herpestes_ichneumon/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Herpestes_ichneumon/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Herpestes_ichneumon/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (726, 230)
#        gbifID  accessRights  bibliographicCitation language       license  \
# 0  6236406917           NaN                    NaN      NaN  CC_BY_NC_4_0
# 1  6236264561           NaN                    NaN      NaN  CC_BY_NC_4_0
# 2  6235766601           NaN                    NaN      NaN  CC_BY_NC_4_0
# 3  6235506418           NaN                    NaN      NaN  CC_BY_NC_4_0
# 4  6234514501           NaN                    NaN      NaN  CC_BY_NC_4_0
#
#                modified  publisher  \
# 0  2026-04-26T14:32:44Z        NaN
# 1  2026-04-23T15:13:44Z        NaN
# 2  2026-04-27T15:16:57Z        NaN
# 3  2026-04-27T15:16:57Z        NaN
# 4  2026-04-25T00:41:28Z        NaN
#
#                                           references       rightsHolder type  \
# 0  https://www.inaturalist.org/observations/35431...    rodolfoferreira  NaN
# 1  https://www.inaturalist.org/observations/35223...       Rui R. Silva  NaN
# 2  https://www.inaturalist.org/observations/19050...  Américo Guerreiro  NaN
# 3  https://www.inaturalist.org/observations/33123...  Américo Guerreiro  NaN
# 4  https://www.inaturalist.org/observations/35052...         Joana Cruz  NaN
#
#    ... publishedByGbifRegion  level0Gid  level0Name level1Gid level1Name  \
# 0  ...         NORTH_AMERICA        PRT    Portugal   PRT.5_1   Bragança
# 1  ...         NORTH_AMERICA        PRT    Portugal   PRT.3_1       Beja
# 2  ...                EUROPE        PRT    Portugal  PRT.12_1     Lisboa
# 3  ...         NORTH_AMERICA        PRT    Portugal  PRT.12_1     Lisboa
# 4  ...                EUROPE        PRT    Portugal   PRT.7_1    Coimbra
#
#      level2Gid            level2Name       level3Gid             level3Name  \
# 0   PRT.5.10_1             Vila Flor   PRT.5.10.18_1  Vilarinho Das Azenhas
# 1    PRT.3.5_1                  Beja     PRT.3.5.5_1  Beja (Santiago Maior)
# 2   PRT.12.1_1              Alenquer    PRT.12.1.9_1              Carregado
# 3  PRT.12.16_1   Vila Franca de Xira  PRT.12.16.12_1    Vila Franca De Xira
# 4   PRT.7.11_1  Oliveira do Hospital   PRT.7.11.12_1   Oliveira Do Hospital
#
#   iucnRedListCategory
# 0                  LC
# 1                  LC
# 2                  LC
# 3                  LC
# 4                  LC
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (726, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (726, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (726, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (726, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (726, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (685, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (658, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (658, 12)
#        gbifID              species  decimalLatitude  decimalLongitude  \
# 0  6236406917  Herpestes ichneumon        41.363581         -7.204119
# 1  6236264561  Herpestes ichneumon        38.016712         -7.936240
# 2  6235766601  Herpestes ichneumon        39.031043         -8.939708
# 3  6235506418  Herpestes ichneumon        38.913707         -8.982198
# 4  6234514501  Herpestes ichneumon        40.369579         -7.858199
#
#   countryCode             eventDate      basisOfRecord  \
# 0          PT      2026-04-26T13:05  HUMAN_OBSERVATION
# 1          PT      2023-04-16T19:07  HUMAN_OBSERVATION
# 2          PT  2023-11-09T18:26:19Z  HUMAN_OBSERVATION
# 3          PT     2025-12-18T13:18Z  HUMAN_OBSERVATION
# 4          PT            2026-04-17  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month   day                   geometry
# 0                            8.0  2026      4  26.0  POINT (-7.20412 41.36358)
# 1                            8.0  2023      4  16.0  POINT (-7.93624 38.01671)
# 2                            3.0  2023     11   9.0  POINT (-8.93971 39.03104)
# 3                         1540.0  2025     12  18.0   POINT (-8.9822 38.91371)
# 4                          183.0  2026      4  17.0   POINT (-7.8582 40.36958)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Herpestes_ichneumon

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Herpestes_ichneumon/Herpestes_ichneumon.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Herpestes_ichneumon/Herpestes_ichneumon.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Herpestes_ichneumon/Herpestes_ichneumon.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Herpestes_ichneumon/Herpestes_ichneumon.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Herpestes_ichneumon
# Records: 658
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Herpestes_ichneumon/Herpestes_ichneumon.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Herpestes_ichneumon/Herpestes_ichneumon.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Herpestes_ichneumon/Herpestes_ichneumon.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Herpestes_ichneumon/Herpestes_ichneumon.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_750bec58136768f724e168eb9c7bfeab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_750bec58136768f724e168eb9c7bfeab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_750bec58136768f724e168eb9c7bfeab = L.map(
#                 &quot;map_750bec58136768f724e168eb9c7bfeab&quot;,
#                 {
#                     center: [38.82152242097265, -8.230269422492402],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bde4a43ac84bdb1f05a82faba0ed7d5b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bde4a43ac84bdb1f05a82faba0ed7d5b.addTo(map_750bec58136768f724e168eb9c7bfeab);
#
#
#             var marker_cluster_e21b7d724715c6cec5a41a1e63afddca = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_af497c8fa532ee8782f821e1054b1cc5 = L.circleMarker(
#                 [41.363581, -7.204119],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_e21b7d724715c6cec5a41a1e63afddca);
#
#
#         var popup_b55f5a6ac9249ff6b370df3865086bff = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_cf603019a4d4d7ebb771434643935c25 = $(`&lt;div id=&quot;html_cf603019a4d4d7ebb771434643935c25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6236406917&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Herpestes ichneumon&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-04-26T13:05&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 8.0     &lt;/div&gt;`)[0];
#                 popup_b55f5a6ac9249ff6b370df3865086bff.setContent(html_cf603019a4d4d7ebb771434643935c25);
#
#
#
#         circle_marker_af497c8fa532ee8782f821e1054b1cc5.bindPopup(popup_b55f5a6ac9249ff6b370df3865086bff)
#         ;
#
#
#
#
#             var circle_marker_63ed53327b78d88601ea91a598db2e48 = L.circleMarker(
#                 [38.016712, -7.93624],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_e21b7d724715c6cec5a41a1e63afddca);
#
#
#         var popup_0c2ae763d4e2388f94179fe6a5f32f57 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_e8c1701992dd943ee1d9349870ecf7e5 = $(`&lt;div id=&quot;html_e8c1701992dd943ee1d9349870ecf7e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6236264561&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Herpestes ichneumon&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2023-04-16T19:07&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 8.0     &lt;/div&gt;`)[0];
#                 popup_0c2ae763d4e2388f94179fe6a5f32f57.setContent(html_e8c1701992dd943ee1d9349870ecf7e5);
#
#
#
#         circle_marker_63ed53327b78d88601ea91a598db2e48.bindPopup(popup_0c2ae763d4e2388f94179fe6a5f32f57)
#         ;
#
#
#
#
#             var circle_marker_49b8c084d35029bef467c2eb18d7307f = L.circleMarker(
#                 [39.031043, -8.939708],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&q

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 658

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 658

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7f4702c5ab6851473846b3fc5c8bbd9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7f4702c5ab6851473846b3fc5c8bbd9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7f4702c5ab6851473846b3fc5c8bbd9 = L.map(
#                 &quot;map_c7f4702c5ab6851473846b3fc5c8bbd9&quot;,
#                 {
#                     center: [38.82152242097265, -8.230269422492402],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6f84dbd063e467e1f1e70f5330491dd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f6f84dbd063e467e1f1e70f5330491dd.addTo(map_c7f4702c5ab6851473846b3fc5c8bbd9);
#
#
#             var circle_marker_8694bdf12ee51e492bcae796d31612e6 = L.circleMarker(
#                 [41.363581, -7.204119],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c7f4702c5ab6851473846b3fc5c8bbd9);
#
#
#         var popup_9fafdeb7ddfd458a7f2329cddc4e38d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df87467386d665f37ec65464f5e6895e = $(`&lt;div id=&quot;html_df87467386d665f37ec65464f5e6895e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6236406917&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Herpestes ichneumon&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_9fafdeb7ddfd458a7f2329cddc4e38d8.setContent(html_df87467386d665f37ec65464f5e6895e);
#
#
#
#         circle_marker_8694bdf12ee51e492bcae796d31612e6.bindPopup(popup_9fafdeb7ddfd458a7f2329cddc4e38d8)
#         ;
#
#
#
#
#             var circle_marker_c5c6d5751d4a7bfd33b9322032f22087 = L.circleMarker(
#                 [38.016712, -7.93624],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c7f4702c5ab6851473846b3fc5c8bbd9);
#
#
#         var popup_1ab4d7ac9f52f0ecd75086da4b818529 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31afc3f2a56c5dcfe852f688f51cafe4 = $(`&lt;div id=&quot;html_31afc3f2a56c5dcfe852f688f51cafe4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6236264561&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Herpestes ichneumon&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_1ab4d7ac9f52f0ecd75086da4b818529.setContent(html_31afc3f2a56c5dcfe852f688f51cafe4);
#
#
#
#         circle_marker_c5c6d5751d4a7bfd33b9322032f22087.bindPopup(popup_1ab4d7ac9f52f0ecd75086da4b818529)
#         ;
#
#
#
#
#             var circle_marker_6625de624992afc722845afb281f7f91 = L.circleMarker(
#                 [39.031043, -8.939708],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c7f4702c5ab6851473846b3fc5c8bbd9);
#
#
#         var popup_cfbf1fe8c383ee90ed860cbb970b23c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48bdb387e2981700788d6420b4db19dd = $(`&lt;div id=&quot;html_48bdb387e2981700788d6420b4db19dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6235766601&lt;br&gt;     &lt;b&gt;S

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Herpestes_ichneumon/Herpestes_ichneumon_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Herpestes_ichneumon/Herpestes_ichneumon_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Herpestes_ichneumon/Herpestes_ichneumon_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID              species  decimalLatitude  decimalLongitude  \
# 0  6236406917  Herpestes ichneumon        41.363581         -7.204119
# 1  6236264561  Herpestes ichneumon        38.016712         -7.936240
# 2  6235766601  Herpestes ichneumon        39.031043         -8.939708
# 3  6235506418  Herpestes ichneumon        38.913707         -8.982198
# 4  6234514501  Herpestes ichneumon        40.369579         -7.858199
#
#   countryCode             eventDate      basisOfRecord  \
# 0          PT      2026-04-26T13:05  HUMAN_OBSERVATION
# 1          PT      2023-04-16T19:07  HUMAN_OBSERVATION
# 2          PT  2023-11-09T18:26:19Z  HUMAN_OBSERVATION
# 3          PT     2025-12-18T13:18Z  HUMAN_OBSERVATION
# 4          PT            2026-04-17  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month   day                   geometry
# 0                            8.0  2026      4  26.0  POINT (-7.20412 41.36358)
# 1                            8.0  2023      4  16.0  POINT (-7.93624 38.01671)
# 2                            3.0  2023     11   9.0  POINT (-8.93971 39.03104)
# 3                         1540.0  2025     12  18.0   POINT (-8.9822 38.91371)
# 4                          183.0  2026      4  17.0   POINT (-7.8582 40.36958)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count     601.000000
# mean      227.579035
# std       666.656591
# min         1.000000
# 25%        19.000000
# 50%        30.000000
# 75%        71.000000
# max      5000.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 658 original records
# 381 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Herpestes_ichneumon/Herpestes_ichneumonclean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="Herpestes_ichneumon_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Herpestes_ichneumon/Herpestes_ichneumonclean.gpkg

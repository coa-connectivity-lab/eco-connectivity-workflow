# %%
if haskey(ENV, "SKIP_OMNISCAPE")
    println("Skipping Omniscape in CI")
else
    println("Hello, World!")
end
# Out:
# Hello, World!

# %%
import os

if os.getenv("SKIP_OMNISCAPE"):
    print("Skipping Omniscape in CI")
else:
    print("Hello, World!")
# Out:
# ArgumentError: Package os not found in current path.
# - Run `import Pkg; Pkg.add("os")` to install the os package.
#
# Stacktrace:
#  [1] macro expansion
#    @ ./loading.jl:2405 [inlined]
#  [2] macro expansion
#    @ ./lock.jl:376 [inlined]
#  [3] __require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:2388
#  [4] require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:2364
#  [5] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489

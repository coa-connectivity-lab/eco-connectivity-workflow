# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Salmo_trutta'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Salmo_trutta.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Salmo_trutta

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Salmo_trutta/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Salmo_trutta/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Salmo_trutta/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Salmo_trutta/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Salmo_trutta/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Salmo_trutta/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Salmo_trutta/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Salmo_trutta/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (101, 230)
#        gbifID  accessRights  bibliographicCitation language       license  \
# 0  6187986561           NaN                    NaN      NaN  CC_BY_NC_4_0
# 1  6178495796           NaN                    NaN      NaN  CC_BY_NC_4_0
# 2  5828915535           NaN                    NaN      NaN  CC_BY_NC_4_0
# 3  5828376786           NaN                    NaN      NaN  CC_BY_NC_4_0
# 4  5827752846           NaN                    NaN      NaN  CC_BY_NC_4_0
#
#                modified  publisher  \
# 0  2026-04-06T15:48:53Z        NaN
# 1  2026-03-08T07:55:53Z        NaN
# 2  2025-10-18T03:31:32Z        NaN
# 3  2025-09-05T00:21:49Z        NaN
# 4  2025-10-16T03:56:12Z        NaN
#
#                                           references           rightsHolder  \
# 0  https://www.inaturalist.org/observations/34764...  Daniel Santos Marques
# 1  https://www.inaturalist.org/observations/34177...            Nuno Campos
# 2  https://www.inaturalist.org/observations/31408...         André Ferreira
# 3  https://www.inaturalist.org/observations/31143...      Filipe Bernardino
# 4  https://www.inaturalist.org/observations/31408...         André Ferreira
#
#   type  ... publishedByGbifRegion  level0Gid  level0Name level1Gid  \
# 0  NaN  ...         NORTH_AMERICA        PRT    Portugal  PRT.19_1
# 1  NaN  ...         NORTH_AMERICA        PRT    Portugal  PRT.20_1
# 2  NaN  ...                EUROPE        PRT    Portugal   PRT.1_1
# 3  NaN  ...                EUROPE        PRT    Portugal  PRT.18_1
# 4  NaN  ...                EUROPE        PRT    Portugal   PRT.1_1
#
#          level1Name    level2Gid            level2Name       level3Gid  \
# 0         Vila Real   PRT.19.5_1       Mondim de Basto    PRT.19.5.5_1
# 1             Viseu  PRT.20.16_1      São Pedro do Sul  PRT.20.16.10_1
# 2            Aveiro   PRT.1.15_1  Santa Maria da Feira   PRT.1.15.12_1
# 3  Viana do Castelo   PRT.18.8_1               Valença    PRT.18.8.4_1
# 4            Aveiro   PRT.1.15_1  Santa Maria da Feira   PRT.1.15.12_1
#
#             level3Name  iucnRedListCategory
# 0      Mondim De Basto                   LC
# 1  Santa Cruz Da Trapa                   LC
# 2                Lobão                   LC
# 3        Cristelo Covo                   LC
# 4                Lobão                   LC
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (101, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (101, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (101, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (101, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (101, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (87, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (84, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (84, 12)
#        gbifID       species  decimalLatitude  decimalLongitude countryCode  \
# 0  6187986561  Salmo trutta        41.399011         -7.954463          PT
# 1  6178495796  Salmo trutta        40.771902         -8.127625          PT
# 2  5828915535  Salmo trutta        40.975239         -8.502521          PT
# 3  5828376786  Salmo trutta        42.001784         -8.657328          PT
# 4  5827752846  Salmo trutta        40.975283         -8.502536          PT
#
#              eventDate      basisOfRecord  coordinateUncertaintyInMeters  \
# 0     2026-04-03T15:32  HUMAN_OBSERVATION                           39.0
# 1    2026-03-07T21:10Z  HUMAN_OBSERVATION                           13.0
# 2     2025-08-16T17:01  HUMAN_OBSERVATION                            4.0
# 3  2025-09-04T09:57:05  HUMAN_OBSERVATION                           20.0
# 4     2025-08-16T17:27  HUMAN_OBSERVATION                            4.0
#
#    year  month  day                   geometry
# 0  2026      4    3  POINT (-7.95446 41.39901)
# 1  2026      3    7   POINT (-8.12762 40.7719)
# 2  2025      8   16  POINT (-8.50252 40.97524)
# 3  2025      9    4  POINT (-8.65733 42.00178)
# 4  2025      8   16  POINT (-8.50254 40.97528)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Salmo_trutta

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Salmo_trutta/Salmo_trutta.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Salmo_trutta/Salmo_trutta.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Salmo_trutta/Salmo_trutta.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Salmo_trutta/Salmo_trutta.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Salmo_trutta
# Records: 84
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Salmo_trutta/Salmo_trutta.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Salmo_trutta/Salmo_trutta.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Salmo_trutta/Salmo_trutta.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Salmo_trutta/Salmo_trutta.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f0e7231c165b92b6bea48e97b3adc99 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f0e7231c165b92b6bea48e97b3adc99&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f0e7231c165b92b6bea48e97b3adc99 = L.map(
#                 &quot;map_4f0e7231c165b92b6bea48e97b3adc99&quot;,
#                 {
#                     center: [40.862693547619045, -8.390254500000001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51e86643c7fda70f456edd02453280e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_51e86643c7fda70f456edd02453280e1.addTo(map_4f0e7231c165b92b6bea48e97b3adc99);
#
#
#             var marker_cluster_936ab5727d778bcac163b6dec2e2b837 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_406f98184aee762c257897c6ddb00006 = L.circleMarker(
#                 [41.399011, -7.954463],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_936ab5727d778bcac163b6dec2e2b837);
#
#
#         var popup_c55912d41324cf71af8d3bb26e0e18a3 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_e5be2db32fd6b3076c6146258c7f7256 = $(`&lt;div id=&quot;html_e5be2db32fd6b3076c6146258c7f7256&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6187986561&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Salmo trutta&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-04-03T15:32&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 39.0     &lt;/div&gt;`)[0];
#                 popup_c55912d41324cf71af8d3bb26e0e18a3.setContent(html_e5be2db32fd6b3076c6146258c7f7256);
#
#
#
#         circle_marker_406f98184aee762c257897c6ddb00006.bindPopup(popup_c55912d41324cf71af8d3bb26e0e18a3)
#         ;
#
#
#
#
#             var circle_marker_8bdaec04c79116f17bbd8a4e060bc46c = L.circleMarker(
#                 [40.771902, -8.127625],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_936ab5727d778bcac163b6dec2e2b837);
#
#
#         var popup_71ad6ab6bb830937de7893bfc8a663bd = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_d4750aa0934f508d5178ccacf71b6eca = $(`&lt;div id=&quot;html_d4750aa0934f508d5178ccacf71b6eca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6178495796&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Salmo trutta&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-03-07T21:10Z&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 13.0     &lt;/div&gt;`)[0];
#                 popup_71ad6ab6bb830937de7893bfc8a663bd.setContent(html_d4750aa0934f508d5178ccacf71b6eca);
#
#
#
#         circle_marker_8bdaec04c79116f17bbd8a4e060bc46c.bindPopup(popup_71ad6ab6bb830937de7893bfc8a663bd)
#         ;
#
#
#
#
#             var circle_marker_9f8c8b072fd0719d21dd9ebabed43c59 = L.circleMarker(
#                 [40.975239, -8.502521],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: nul

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 84

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 84

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa0862059b89d8d849ea631f20a65c11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa0862059b89d8d849ea631f20a65c11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa0862059b89d8d849ea631f20a65c11 = L.map(
#                 &quot;map_aa0862059b89d8d849ea631f20a65c11&quot;,
#                 {
#                     center: [40.862693547619045, -8.390254500000001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_992830ee9b4c6a34d1c9c6d08ca2d1b6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_992830ee9b4c6a34d1c9c6d08ca2d1b6.addTo(map_aa0862059b89d8d849ea631f20a65c11);
#
#
#             var circle_marker_3e2a9c62ebd845ceffeb606ba89d69bd = L.circleMarker(
#                 [41.399011, -7.954463],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aa0862059b89d8d849ea631f20a65c11);
#
#
#         var popup_d9b59324ae0dab64a6a4ca7ce0334f39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f7770ba141a88fd4664cb127fb28bd7 = $(`&lt;div id=&quot;html_4f7770ba141a88fd4664cb127fb28bd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6187986561&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Salmo trutta&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_d9b59324ae0dab64a6a4ca7ce0334f39.setContent(html_4f7770ba141a88fd4664cb127fb28bd7);
#
#
#
#         circle_marker_3e2a9c62ebd845ceffeb606ba89d69bd.bindPopup(popup_d9b59324ae0dab64a6a4ca7ce0334f39)
#         ;
#
#
#
#
#             var circle_marker_5bfb2a3d9117cbeb6b86e28109555ff6 = L.circleMarker(
#                 [40.771902, -8.127625],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aa0862059b89d8d849ea631f20a65c11);
#
#
#         var popup_5cdfd4e2ee76dcf427f2f0ecc27585b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73b08bd87a0edf72db0c58e358d246b5 = $(`&lt;div id=&quot;html_73b08bd87a0edf72db0c58e358d246b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6178495796&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Salmo trutta&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_5cdfd4e2ee76dcf427f2f0ecc27585b9.setContent(html_73b08bd87a0edf72db0c58e358d246b5);
#
#
#
#         circle_marker_5bfb2a3d9117cbeb6b86e28109555ff6.bindPopup(popup_5cdfd4e2ee76dcf427f2f0ecc27585b9)
#         ;
#
#
#
#
#             var circle_marker_494cf79991a79f10dc24c391e0115e1e = L.circleMarker(
#                 [40.975239, -8.502521],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aa0862059b89d8d849ea631f20a65c11);
#
#
#         var popup_d980d60ddc030465bd8ed4462d0af440 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_285648b768a1ba670e1fdc03a659ca8c = $(`&lt;div id=&quot;html_285648b768a1ba670e1fdc03a659ca8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5828915535&lt;br&gt;     &lt;b&gt;Species:&lt;/

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Salmo_trutta/Salmo_trutta_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Salmo_trutta/Salmo_trutta_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Salmo_trutta/Salmo_trutta_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID       species  decimalLatitude  decimalLongitude countryCode  \
# 0  6187986561  Salmo trutta        41.399011         -7.954463          PT
# 1  6178495796  Salmo trutta        40.771902         -8.127625          PT
# 2  5828915535  Salmo trutta        40.975239         -8.502521          PT
# 3  5828376786  Salmo trutta        42.001784         -8.657328          PT
# 4  5827752846  Salmo trutta        40.975283         -8.502536          PT
#
#              eventDate      basisOfRecord  coordinateUncertaintyInMeters  \
# 0  2026-04-03T15:32:00  HUMAN_OBSERVATION                           39.0
# 1  2026-03-07T21:10:00  HUMAN_OBSERVATION                           13.0
# 2  2025-08-16T17:01:00  HUMAN_OBSERVATION                            4.0
# 3  2025-09-04T09:57:05  HUMAN_OBSERVATION                           20.0
# 4  2025-08-16T17:27:00  HUMAN_OBSERVATION                            4.0
#
#    year  month  day                   geometry
# 0  2026      4    3  POINT (-7.95446 41.39901)
# 1  2026      3    7   POINT (-8.12762 40.7719)
# 2  2025      8   16  POINT (-8.50252 40.97524)
# 3  2025      9    4  POINT (-8.65733 42.00178)
# 4  2025      8   16  POINT (-8.50254 40.97528)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count      67.000000
# mean      173.104478
# std       633.520422
# min         2.000000
# 25%         6.500000
# 50%        14.000000
# 75%        86.500000
# max      4354.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 84 original records
# 42 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Salmo_trutta/Salmo_trutta_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="spp_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Salmo_trutta/Salmo_trutta_clean.gpkg

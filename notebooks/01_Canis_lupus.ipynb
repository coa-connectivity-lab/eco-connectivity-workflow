# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Canis_lupus'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Canis_lupus.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Canis_lupus

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Canis_lupus/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Canis_lupus/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Canis_lupus/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Canis_lupus/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Canis_lupus/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Canis_lupus/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Canis_lupus/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Canis_lupus/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (138, 230)
#        gbifID  accessRights  bibliographicCitation  language       license  \
# 0  6195775096           NaN                    NaN       NaN  CC_BY_NC_4_0
# 1  6187955131           NaN                    NaN       NaN  CC_BY_NC_4_0
# 2  6185652144           NaN                    NaN       NaN  CC_BY_NC_4_0
# 3  6185362013           NaN                    NaN       NaN  CC_BY_NC_4_0
# 4  6185310681           NaN                    NaN       NaN  CC_BY_NC_4_0
#
#                modified  publisher  \
# 0  2026-04-12T17:52:52Z        NaN
# 1  2026-03-31T19:09:53Z        NaN
# 2  2026-03-18T18:49:43Z        NaN
# 3  2026-03-24T09:08:37Z        NaN
# 4  2026-03-24T09:08:15Z        NaN
#
#                                           references  \
# 0  https://www.inaturalist.org/observations/34929...
# 1  https://www.inaturalist.org/observations/34636...
# 2  https://www.inaturalist.org/observations/80157946
# 3  https://www.inaturalist.org/observations/34473...
# 4  https://www.inaturalist.org/observations/34473...
#
#                  rightsHolder  type  ...  publishedByGbifRegion  level0Gid  \
# 0  Gonzalo Mucientes Sandoval   NaN  ...          NORTH_AMERICA        NaN
# 1                 joaoalmeida   NaN  ...          NORTH_AMERICA        NaN
# 2                Maria Soares   NaN  ...                 EUROPE        PRT
# 3  Gonzalo Mucientes Sandoval   NaN  ...          NORTH_AMERICA        ESP
# 4  Gonzalo Mucientes Sandoval   NaN  ...          NORTH_AMERICA        ESP
#
#    level0Name level1Gid level1Name    level2Gid    level2Name       level3Gid  \
# 0         NaN       NaN        NaN          NaN           NaN             NaN
# 1         NaN       NaN        NaN          NaN           NaN             NaN
# 2    Portugal  PRT.11_1     Leiria  PRT.11.16_1  Porto de Mós  PRT.11.16.12_1
# 3       Spain  ESP.12_1    Galicia   ESP.12.3_1       Ourense    ESP.12.3.1_1
# 4       Spain  ESP.12_1    Galicia   ESP.12.3_1       Ourense    ESP.12.3.2_1
#
#    level3Name  iucnRedListCategory
# 0         NaN                   LC
# 1         NaN                   LC
# 2   São Bento                  NaN
# 3  n.a. (197)                   LC
# 4  n.a. (198)                   LC
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (138, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (138, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (138, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (138, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (138, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (135, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (83, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (83, 12)
#         gbifID      species  decimalLatitude  decimalLongitude countryCode  \
# 2   6185652144  Canis lupus        39.553570         -8.800753          PT
# 5   6185251549  Canis lupus        41.077606         -8.601757          PT
# 6   6185026082  Canis lupus        41.868138         -7.985825          PT
# 10  6179384907  Canis lupus        37.346921         -7.468764          PT
# 13  6159544997  Canis lupus        40.619247         -7.665688          PT
#
#                eventDate      basisOfRecord  coordinateUncertaintyInMeters  \
# 2   2021-01-02T12:43:29Z  HUMAN_OBSERVATION                            NaN
# 5   2026-03-20T17:22:04Z  HUMAN_OBSERVATION                            4.0
# 6    2026-03-29T17:14:54  HUMAN_OBSERVATION                          336.0
# 10     2026-03-08T11:41Z  HUMAN_OBSERVATION                           31.0
# 13     2023-12-06T16:35Z  HUMAN_OBSERVATION                           27.0
#
#     year  month  day                   geometry
# 2   2021      1    2  POINT (-8.80075 39.55357)
# 5   2026      3   20  POINT (-8.60176 41.07761)
# 6   2026      3   29  POINT (-7.98582 41.86814)
# 10  2026      3    8  POINT (-7.46876 37.34692)
# 13  2023     12    6  POINT (-7.66569 40.61925)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Canis_lupus

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Canis_lupus/Canis_lupus.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Canis_lupus/Canis_lupus.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Canis_lupus/Canis_lupus.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Canis_lupus/Canis_lupus.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Canis_lupus
# Records: 83
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Canis_lupus/Canis_lupus.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Canis_lupus/Canis_lupus.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Canis_lupus/Canis_lupus.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Canis_lupus/Canis_lupus.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f47e7e91aae61421984bc2b9b82f32ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f47e7e91aae61421984bc2b9b82f32ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f47e7e91aae61421984bc2b9b82f32ae = L.map(
#                 &quot;map_f47e7e91aae61421984bc2b9b82f32ae&quot;,
#                 {
#                     center: [39.53432259036145, -8.782448506024098],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4472931bf1d9d5c6ab5ee8943dcb3aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f4472931bf1d9d5c6ab5ee8943dcb3aa.addTo(map_f47e7e91aae61421984bc2b9b82f32ae);
#
#
#             var marker_cluster_885a7c9b69e93a55a35b9ba0c2f2baa0 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_588289a78f48d27b7d88aacdfb3c1783 = L.circleMarker(
#                 [39.55357, -8.800753],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_885a7c9b69e93a55a35b9ba0c2f2baa0);
#
#
#         var popup_2897c111ccb1b44c543ac10b97e0350b = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_b8c52046b282d06185b06a05d7af5cac = $(`&lt;div id=&quot;html_b8c52046b282d06185b06a05d7af5cac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6185652144&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Canis lupus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2021-01-02T12:43:29Z&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; nan     &lt;/div&gt;`)[0];
#                 popup_2897c111ccb1b44c543ac10b97e0350b.setContent(html_b8c52046b282d06185b06a05d7af5cac);
#
#
#
#         circle_marker_588289a78f48d27b7d88aacdfb3c1783.bindPopup(popup_2897c111ccb1b44c543ac10b97e0350b)
#         ;
#
#
#
#
#             var circle_marker_f714102ca54d77d5194e33fd5dcb2cf3 = L.circleMarker(
#                 [41.077606, -8.601757],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_885a7c9b69e93a55a35b9ba0c2f2baa0);
#
#
#         var popup_90812af13b049fa37b387d17c42372d0 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_c0ab12256218c2190958315950720a7e = $(`&lt;div id=&quot;html_c0ab12256218c2190958315950720a7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6185251549&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Canis lupus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-03-20T17:22:04Z&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 4.0     &lt;/div&gt;`)[0];
#                 popup_90812af13b049fa37b387d17c42372d0.setContent(html_c0ab12256218c2190958315950720a7e);
#
#
#
#         circle_marker_f714102ca54d77d5194e33fd5dcb2cf3.bindPopup(popup_90812af13b049fa37b387d17c42372d0)
#         ;
#
#
#
#
#             var circle_marker_b7da577114be1bfc26742e11062bba4b = L.circleMarker(
#                 [41.868138, -7.985825],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: nu

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 83

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 83

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0568d16742515242d5363ebe73af588 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0568d16742515242d5363ebe73af588&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0568d16742515242d5363ebe73af588 = L.map(
#                 &quot;map_c0568d16742515242d5363ebe73af588&quot;,
#                 {
#                     center: [39.53432259036145, -8.782448506024098],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49116ac8cb932cee12a9e5cbf45dda83 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_49116ac8cb932cee12a9e5cbf45dda83.addTo(map_c0568d16742515242d5363ebe73af588);
#
#
#             var circle_marker_401acc2a4cf7699b0854769d07c78f44 = L.circleMarker(
#                 [39.55357, -8.800753],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c0568d16742515242d5363ebe73af588);
#
#
#         var popup_d1e7f311c7f0a34c784b322df0d682b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02861bfdf0fbb83136b4b2d9aae5f202 = $(`&lt;div id=&quot;html_02861bfdf0fbb83136b4b2d9aae5f202&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6185652144&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Canis lupus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_d1e7f311c7f0a34c784b322df0d682b6.setContent(html_02861bfdf0fbb83136b4b2d9aae5f202);
#
#
#
#         circle_marker_401acc2a4cf7699b0854769d07c78f44.bindPopup(popup_d1e7f311c7f0a34c784b322df0d682b6)
#         ;
#
#
#
#
#             var circle_marker_0a52bcb24bf6d9ea4a183494840b96f0 = L.circleMarker(
#                 [41.077606, -8.601757],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c0568d16742515242d5363ebe73af588);
#
#
#         var popup_e9bc98e7a08b9f53d0ed5c2712ca1a8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edea4ea3b9fde2c7b56c3abffc312b32 = $(`&lt;div id=&quot;html_edea4ea3b9fde2c7b56c3abffc312b32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6185251549&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Canis lupus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_e9bc98e7a08b9f53d0ed5c2712ca1a8b.setContent(html_edea4ea3b9fde2c7b56c3abffc312b32);
#
#
#
#         circle_marker_0a52bcb24bf6d9ea4a183494840b96f0.bindPopup(popup_e9bc98e7a08b9f53d0ed5c2712ca1a8b)
#         ;
#
#
#
#
#             var circle_marker_7637586d1e914854dab2f784a6cb4dec = L.circleMarker(
#                 [41.868138, -7.985825],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c0568d16742515242d5363ebe73af588);
#
#
#         var popup_9708bcb36321e56d1675502dfcf647af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40acf6b644cc121b32fd13996c02dba0 = $(`&lt;div id=&quot;html_40acf6b644cc121b32fd13996c02dba0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6185026082&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Canis_lupus/Canis_lupus_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Canis_lupus/Canis_lupus_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Canis_lupus/Canis_lupus_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID      species  decimalLatitude  decimalLongitude countryCode  \
# 0  6185652144  Canis lupus        39.553570         -8.800753          PT
# 1  6185251549  Canis lupus        41.077606         -8.601757          PT
# 2  6185026082  Canis lupus        41.868138         -7.985825          PT
# 3  6179384907  Canis lupus        37.346921         -7.468764          PT
# 4  6159544997  Canis lupus        40.619247         -7.665688          PT
#
#                    eventDate      basisOfRecord  \
# 0  2021-01-02T12:43:29+00:00  HUMAN_OBSERVATION
# 1  2026-03-20T17:22:04+00:00  HUMAN_OBSERVATION
# 2        2026-03-29T17:14:54  HUMAN_OBSERVATION
# 3        2026-03-08T11:41:00  HUMAN_OBSERVATION
# 4        2023-12-06T16:35:00  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month  day                   geometry
# 0                            NaN  2021      1    2  POINT (-8.80075 39.55357)
# 1                            4.0  2026      3   20  POINT (-8.60176 41.07761)
# 2                          336.0  2026      3   29  POINT (-7.98582 41.86814)
# 3                           31.0  2026      3    8  POINT (-7.46876 37.34692)
# 4                           27.0  2023     12    6  POINT (-7.66569 40.61925)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count      72.000000
# mean      268.944444
# std       578.760742
# min         2.000000
# 25%        14.250000
# 50%        16.000000
# 75%       250.000000
# max      2977.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 83 original records
# 41 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Canis_lupus/Canis_lupus_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="Canis_lupus_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Canis_lupus/Canis_lupus_clean.gpkg

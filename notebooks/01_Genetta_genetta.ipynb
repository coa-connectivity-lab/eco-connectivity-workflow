# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Genetta_genetta'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Genetta_genetta.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Genetta_genetta

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Genetta_genetta/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Genetta_genetta/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Genetta_genetta/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Genetta_genetta/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Genetta_genetta/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Genetta_genetta/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Genetta_genetta/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Genetta_genetta/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (795, 230)
#        gbifID  accessRights  bibliographicCitation language       license  \
# 0  6236295464           NaN                    NaN      NaN  CC_BY_NC_4_0
# 1  6236163760           NaN                    NaN      NaN  CC_BY_NC_4_0
# 2  6236091728           NaN                    NaN      NaN  CC_BY_NC_4_0
# 3  6235486599           NaN                    NaN      NaN  CC_BY_NC_4_0
# 4  6234724648           NaN                    NaN      NaN       CC0_1_0
#
#                modified  publisher  \
# 0  2026-04-27T11:26:06Z        NaN
# 1  2026-04-20T14:49:38Z        NaN
# 2  2026-04-27T11:24:02Z        NaN
# 3  2026-04-26T13:41:41Z        NaN
# 4  2026-04-23T16:54:25Z        NaN
#
#                                           references     rightsHolder type  \
# 0  https://www.inaturalist.org/observations/35522...        pamstello  NaN
# 1  https://www.inaturalist.org/observations/35145...          brandao  NaN
# 2  https://www.inaturalist.org/observations/35351...      David Claro  NaN
# 3  https://www.inaturalist.org/observations/35431...  rodolfoferreira  NaN
# 4  https://www.inaturalist.org/observations/35221...       João Sousa  NaN
#
#    ... publishedByGbifRegion  level0Gid  level0Name level1Gid level1Name  \
# 0  ...         NORTH_AMERICA        PRT    Portugal  PRT.11_1     Leiria
# 1  ...         NORTH_AMERICA        PRT    Portugal  PRT.10_1     Guarda
# 2  ...                EUROPE        PRT    Portugal   PRT.8_1      Évora
# 3  ...         NORTH_AMERICA        PRT    Portugal   PRT.5_1   Bragança
# 4  ...                EUROPE        PRT    Portugal  PRT.12_1     Lisboa
#
#     level2Gid          level2Name      level3Gid             level3Name  \
# 0  PRT.11.1_1            Alcobaça  PRT.11.1.15_1  São Martinho Do Porto
# 1  PRT.10.5_1  Fornos de Algodres  PRT.10.5.15_1             Vila Ruiva
# 2   PRT.8.6_1     Montemor-o-Novo    PRT.8.6.9_1          São Cristóvão
# 3  PRT.5.10_1           Vila Flor  PRT.5.10.18_1  Vilarinho Das Azenhas
# 4  PRT.12.1_1            Alenquer   PRT.12.1.7_1               Cadafais
#
#    iucnRedListCategory
# 0                   LC
# 1                   LC
# 2                   LC
# 3                   LC
# 4                   LC
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (795, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (795, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (795, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (795, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (795, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (635, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (616, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (616, 12)
#        gbifID          species  decimalLatitude  decimalLongitude countryCode  \
# 0  6236295464  Genetta genetta        39.520195         -9.136200          PT
# 1  6236163760  Genetta genetta        40.575858         -7.516512          PT
# 2  6236091728  Genetta genetta        38.563544         -8.300381          PT
# 3  6235486599  Genetta genetta        41.364094         -7.205558          PT
# 4  6234724648  Genetta genetta        39.016399         -9.003270          PT
#
#              eventDate      basisOfRecord  coordinateUncertaintyInMeters  \
# 0  2026-04-05T10:22:07  HUMAN_OBSERVATION                            3.0
# 1     2026-04-08T15:14  HUMAN_OBSERVATION                           24.0
# 2  2026-04-25T13:29:02  HUMAN_OBSERVATION                           25.0
# 3     2026-04-26T13:06  HUMAN_OBSERVATION                           31.0
# 4  2026-04-23T10:58:43  HUMAN_OBSERVATION                           39.0
#
#    year  month   day                   geometry
# 0  2026      4   5.0    POINT (-9.1362 39.5202)
# 1  2026      4   8.0  POINT (-7.51651 40.57586)
# 2  2026      4  25.0  POINT (-8.30038 38.56354)
# 3  2026      4  26.0  POINT (-7.20556 41.36409)
# 4  2026      4  23.0   POINT (-9.00327 39.0164)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Genetta_genetta

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Genetta_genetta/Genetta_genetta.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Genetta_genetta/Genetta_genetta.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Genetta_genetta/Genetta_genetta.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Genetta_genetta/Genetta_genetta.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Genetta_genetta
# Records: 616
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Genetta_genetta/Genetta_genetta.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Genetta_genetta/Genetta_genetta.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Genetta_genetta/Genetta_genetta.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Genetta_genetta/Genetta_genetta.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_665334d4510b1926882587fb0997ed4e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_665334d4510b1926882587fb0997ed4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_665334d4510b1926882587fb0997ed4e = L.map(
#                 &quot;map_665334d4510b1926882587fb0997ed4e&quot;,
#                 {
#                     center: [39.59895847077922, -7.979942461038961],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af3aeb0765104ef15e99d1fb17253b30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af3aeb0765104ef15e99d1fb17253b30.addTo(map_665334d4510b1926882587fb0997ed4e);
#
#
#             var marker_cluster_8bdf9ac6065dbfba308000beba0fa375 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_36902ae1a98df67e2702d8a808d46b46 = L.circleMarker(
#                 [39.520195, -9.1362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_8bdf9ac6065dbfba308000beba0fa375);
#
#
#         var popup_d0f4135f2a68af678960befd4dd80d75 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_0452528fb2ab88645cddf4674e818820 = $(`&lt;div id=&quot;html_0452528fb2ab88645cddf4674e818820&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6236295464&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Genetta genetta&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-04-05T10:22:07&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 3.0     &lt;/div&gt;`)[0];
#                 popup_d0f4135f2a68af678960befd4dd80d75.setContent(html_0452528fb2ab88645cddf4674e818820);
#
#
#
#         circle_marker_36902ae1a98df67e2702d8a808d46b46.bindPopup(popup_d0f4135f2a68af678960befd4dd80d75)
#         ;
#
#
#
#
#             var circle_marker_96f0c8b1ff4653b6367213107ebb2dde = L.circleMarker(
#                 [40.575858, -7.516512],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_8bdf9ac6065dbfba308000beba0fa375);
#
#
#         var popup_7e592e6e2024a1b13519f1fbd84ff280 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_ec45993ee0b7202221512c45565a7d6d = $(`&lt;div id=&quot;html_ec45993ee0b7202221512c45565a7d6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6236163760&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Genetta genetta&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-04-08T15:14&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 24.0     &lt;/div&gt;`)[0];
#                 popup_7e592e6e2024a1b13519f1fbd84ff280.setContent(html_ec45993ee0b7202221512c45565a7d6d);
#
#
#
#         circle_marker_96f0c8b1ff4653b6367213107ebb2dde.bindPopup(popup_7e592e6e2024a1b13519f1fbd84ff280)
#         ;
#
#
#
#
#             var circle_marker_5e57703d605efcdbfbccf0c2eb1afab8 = L.circleMarker(
#                 [38.563544, -8.300381],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;:

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 616

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 616

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b12b57513015e0c61e814914c7febf4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b12b57513015e0c61e814914c7febf4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b12b57513015e0c61e814914c7febf4 = L.map(
#                 &quot;map_3b12b57513015e0c61e814914c7febf4&quot;,
#                 {
#                     center: [39.59895847077922, -7.979942461038961],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83b451ba7a28dc6d196147f157be0fbc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_83b451ba7a28dc6d196147f157be0fbc.addTo(map_3b12b57513015e0c61e814914c7febf4);
#
#
#             var circle_marker_c06fc8805b1a0b32b251e7432284bfa5 = L.circleMarker(
#                 [39.520195, -9.1362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3b12b57513015e0c61e814914c7febf4);
#
#
#         var popup_60407584f91bd53a50534b0737b07303 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85f757f5d6ca110eb811e3f37cbf31c1 = $(`&lt;div id=&quot;html_85f757f5d6ca110eb811e3f37cbf31c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6236295464&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Genetta genetta&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_60407584f91bd53a50534b0737b07303.setContent(html_85f757f5d6ca110eb811e3f37cbf31c1);
#
#
#
#         circle_marker_c06fc8805b1a0b32b251e7432284bfa5.bindPopup(popup_60407584f91bd53a50534b0737b07303)
#         ;
#
#
#
#
#             var circle_marker_04353be1ce5cc3c1306e0bab2cf35db4 = L.circleMarker(
#                 [40.575858, -7.516512],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3b12b57513015e0c61e814914c7febf4);
#
#
#         var popup_9fcc9c223779aecf27e4acccb0544a52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4a0657b0b56738bb0fdd58a616c000c = $(`&lt;div id=&quot;html_e4a0657b0b56738bb0fdd58a616c000c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6236163760&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Genetta genetta&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_9fcc9c223779aecf27e4acccb0544a52.setContent(html_e4a0657b0b56738bb0fdd58a616c000c);
#
#
#
#         circle_marker_04353be1ce5cc3c1306e0bab2cf35db4.bindPopup(popup_9fcc9c223779aecf27e4acccb0544a52)
#         ;
#
#
#
#
#             var circle_marker_8878a832279562c230aa34e331b283aa = L.circleMarker(
#                 [38.563544, -8.300381],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3b12b57513015e0c61e814914c7febf4);
#
#
#         var popup_eae8532c6293a5c254891c15943d6f94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6211963a2b910b1fc0c8fe1a094ae1e = $(`&lt;div id=&quot;html_d6211963a2b910b1fc0c8fe1a094ae1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6236091728&lt;br&gt;     &lt;b&gt;Species:&l

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Genetta_genetta/Genetta_genetta_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Genetta_genetta/Genetta_genetta_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Genetta_genetta/Genetta_genetta_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID          species  decimalLatitude  decimalLongitude countryCode  \
# 0  6236295464  Genetta genetta        39.520195         -9.136200          PT
# 1  6236163760  Genetta genetta        40.575858         -7.516512          PT
# 2  6236091728  Genetta genetta        38.563544         -8.300381          PT
# 3  6235486599  Genetta genetta        41.364094         -7.205558          PT
# 4  6234724648  Genetta genetta        39.016399         -9.003270          PT
#
#              eventDate      basisOfRecord  coordinateUncertaintyInMeters  \
# 0  2026-04-05T10:22:07  HUMAN_OBSERVATION                            3.0
# 1     2026-04-08T15:14  HUMAN_OBSERVATION                           24.0
# 2  2026-04-25T13:29:02  HUMAN_OBSERVATION                           25.0
# 3     2026-04-26T13:06  HUMAN_OBSERVATION                           31.0
# 4  2026-04-23T10:58:43  HUMAN_OBSERVATION                           39.0
#
#    year  month   day                   geometry
# 0  2026      4   5.0    POINT (-9.1362 39.5202)
# 1  2026      4   8.0  POINT (-7.51651 40.57586)
# 2  2026      4  25.0  POINT (-8.30038 38.56354)
# 3  2026      4  26.0  POINT (-7.20556 41.36409)
# 4  2026      4  23.0   POINT (-9.00327 39.0164)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count     557.000000
# mean      117.344704
# std       420.831491
# min         1.000000
# 25%         5.000000
# 50%        30.000000
# 75%        46.000000
# max      4394.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 616 original records
# 402 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Genetta_genetta/Genetta_genetta_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="Genetta_genetta_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Genetta_genetta/Genetta_genetta_clean.gpkg

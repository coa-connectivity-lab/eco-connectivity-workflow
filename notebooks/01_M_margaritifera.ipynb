# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'M_margaritifera'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/M_margaritifera.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/M_margaritifera

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/M_margaritifera/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/M_margaritifera/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/M_margaritifera/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/M_margaritifera/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/M_margaritifera/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/M_margaritifera/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/M_margaritifera/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/M_margaritifera/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (95, 230)
#        gbifID  accessRights  bibliographicCitation  language       license  \
# 0  5231621491           NaN                    NaN       NaN  CC_BY_NC_4_0
# 1  5231572451           NaN                    NaN       NaN  CC_BY_NC_4_0
# 2  5231305754           NaN                    NaN       NaN  CC_BY_NC_4_0
# 3  5230461491           NaN                    NaN       NaN  CC_BY_NC_4_0
# 4  4605340506           NaN                    NaN       NaN     CC_BY_4_0
#
#                modified  publisher  \
# 0  2026-02-06T11:40:49Z        NaN
# 1  2026-02-06T11:41:01Z        NaN
# 2  2025-07-18T18:42:59Z        NaN
# 3  2026-02-06T11:40:55Z        NaN
# 4  2024-04-11T00:00:00Z        NaN
#
#                                           references rightsHolder   type  ...  \
# 0  https://www.inaturalist.org/observations/29707...        puxin    NaN  ...
# 1  https://www.inaturalist.org/observations/29707...        puxin    NaN  ...
# 2  https://www.inaturalist.org/observations/29898...        puxin    NaN  ...
# 3  https://www.inaturalist.org/observations/29708...        puxin    NaN  ...
# 4                                                NaN      Movhera  event  ...
#
#   publishedByGbifRegion  level0Gid  level0Name level1Gid level1Name  \
# 0         NORTH_AMERICA        NaN         NaN       NaN        NaN
# 1         NORTH_AMERICA        NaN         NaN       NaN        NaN
# 2         NORTH_AMERICA        NaN         NaN       NaN        NaN
# 3         NORTH_AMERICA        NaN         NaN       NaN        NaN
# 4                EUROPE        PRT    Portugal   PRT.5_1   Bragança
#
#    level2Gid level2Name    level3Gid level3Name  iucnRedListCategory
# 0        NaN        NaN          NaN        NaN                   EN
# 1        NaN        NaN          NaN        NaN                   EN
# 2        NaN        NaN          NaN        NaN                   EN
# 3        NaN        NaN          NaN        NaN                   EN
# 4  PRT.5.7_1  Mirandela  PRT.5.7.3_1  Aguieiras                   EN
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (95, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (95, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (95, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (95, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (95, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (85, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (39, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (39, 12)
#         gbifID                      species  decimalLatitude  \
# 4   4605340506  Margaritifera margaritifera         41.67778
# 5   4605340495  Margaritifera margaritifera         41.59944
# 6   4605340490  Margaritifera margaritifera         41.55122
# 9   4605340368  Margaritifera margaritifera         41.64694
# 14  4462993522  Margaritifera margaritifera         41.71556
#
#     decimalLongitude countryCode   eventDate      basisOfRecord  \
# 4           -7.21750          PT  2023-09-04  HUMAN_OBSERVATION
# 5           -7.25556          PT  2021-07-01  HUMAN_OBSERVATION
# 6           -7.24994          PT  2022-07-19  HUMAN_OBSERVATION
# 9           -7.23833          PT  2021-07-01  HUMAN_OBSERVATION
# 14          -7.20611          PT  2018-06-25  HUMAN_OBSERVATION
#
#     coordinateUncertaintyInMeters    year  month   day  \
# 4                             5.0  2023.0    9.0   4.0
# 5                             5.0  2021.0    7.0   1.0
# 6                             5.0  2022.0    7.0  19.0
# 9                             5.0  2021.0    7.0   1.0
# 14                            5.0  2018.0    6.0  25.0
#
#                      geometry
# 4    POINT (-7.2175 41.67778)
# 5   POINT (-7.25556 41.59944)
# 6   POINT (-7.24994 41.55122)
# 9   POINT (-7.23833 41.64694)
# 14  POINT (-7.20611 41.71556)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/M_margaritifera

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/M_margaritifera/M_margaritifera.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/M_margaritifera/M_margaritifera.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/M_margaritifera/M_margaritifera.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/M_margaritifera/M_margaritifera.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: M_margaritifera
# Records: 39
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/M_margaritifera/M_margaritifera.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/M_margaritifera/M_margaritifera.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/M_margaritifera/M_margaritifera.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/M_margaritifera/M_margaritifera.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47d7f6ff0c5f8da39c3f2ca693e0de79 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47d7f6ff0c5f8da39c3f2ca693e0de79&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47d7f6ff0c5f8da39c3f2ca693e0de79 = L.map(
#                 &quot;map_47d7f6ff0c5f8da39c3f2ca693e0de79&quot;,
#                 {
#                     center: [41.70875812820513, -7.250085512820513],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43c0e204bcca59a4530cf89e0e72774f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_43c0e204bcca59a4530cf89e0e72774f.addTo(map_47d7f6ff0c5f8da39c3f2ca693e0de79);
#
#
#             var marker_cluster_5d9eafebca0a0d5905138f5d940e759b = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_523b07320660e49fcc7000e9b223c8dc = L.circleMarker(
#                 [41.67778, -7.2175],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_5d9eafebca0a0d5905138f5d940e759b);
#
#
#         var popup_85fea7eee90157a7b1995a421a1f5add = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_8231ce2dd31af64a06d355e6bff86895 = $(`&lt;div id=&quot;html_8231ce2dd31af64a06d355e6bff86895&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 4605340506&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Margaritifera margaritifera&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2023-09-04&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 5.0     &lt;/div&gt;`)[0];
#                 popup_85fea7eee90157a7b1995a421a1f5add.setContent(html_8231ce2dd31af64a06d355e6bff86895);
#
#
#
#         circle_marker_523b07320660e49fcc7000e9b223c8dc.bindPopup(popup_85fea7eee90157a7b1995a421a1f5add)
#         ;
#
#
#
#
#             var circle_marker_b74787ca6ffcd139600e065586251a72 = L.circleMarker(
#                 [41.59944, -7.25556],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_5d9eafebca0a0d5905138f5d940e759b);
#
#
#         var popup_e7bab71782c1b6cda1cf7ca7510a5543 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_bbae50731e70a8eae2342203d721eaa8 = $(`&lt;div id=&quot;html_bbae50731e70a8eae2342203d721eaa8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 4605340495&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Margaritifera margaritifera&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2021-07-01&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 5.0     &lt;/div&gt;`)[0];
#                 popup_e7bab71782c1b6cda1cf7ca7510a5543.setContent(html_bbae50731e70a8eae2342203d721eaa8);
#
#
#
#         circle_marker_b74787ca6ffcd139600e065586251a72.bindPopup(popup_e7bab71782c1b6cda1cf7ca7510a5543)
#         ;
#
#
#
#
#             var circle_marker_146465ff978bbe49b0905913c7ce222c = L.circleMarker(
#                 [41.55122, -7.24994],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quo

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 39

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 39

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be9bcf2e99f5d30d0c9a60ebe09e3ece {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be9bcf2e99f5d30d0c9a60ebe09e3ece&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be9bcf2e99f5d30d0c9a60ebe09e3ece = L.map(
#                 &quot;map_be9bcf2e99f5d30d0c9a60ebe09e3ece&quot;,
#                 {
#                     center: [41.70875812820513, -7.250085512820513],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be212e38b6c9aa425bc9ac76d7b75d04 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be212e38b6c9aa425bc9ac76d7b75d04.addTo(map_be9bcf2e99f5d30d0c9a60ebe09e3ece);
#
#
#             var circle_marker_63eca9e0358fa7a42032bf07f25e18a3 = L.circleMarker(
#                 [41.67778, -7.2175],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_be9bcf2e99f5d30d0c9a60ebe09e3ece);
#
#
#         var popup_fdadc66a2dc3b4d698e8b4250b306001 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_516a2153cf26610e8beabe0b4c6e3dc9 = $(`&lt;div id=&quot;html_516a2153cf26610e8beabe0b4c6e3dc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 4605340506&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Margaritifera margaritifera&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_fdadc66a2dc3b4d698e8b4250b306001.setContent(html_516a2153cf26610e8beabe0b4c6e3dc9);
#
#
#
#         circle_marker_63eca9e0358fa7a42032bf07f25e18a3.bindPopup(popup_fdadc66a2dc3b4d698e8b4250b306001)
#         ;
#
#
#
#
#             var circle_marker_beff7a003a95ea6ce8bc429cdb3b0534 = L.circleMarker(
#                 [41.59944, -7.25556],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_be9bcf2e99f5d30d0c9a60ebe09e3ece);
#
#
#         var popup_21ee019faa8c5a9ef5e8e536c8390dbb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f3f74fd0313545fff27495c1f12fa2d = $(`&lt;div id=&quot;html_7f3f74fd0313545fff27495c1f12fa2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 4605340495&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Margaritifera margaritifera&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_21ee019faa8c5a9ef5e8e536c8390dbb.setContent(html_7f3f74fd0313545fff27495c1f12fa2d);
#
#
#
#         circle_marker_beff7a003a95ea6ce8bc429cdb3b0534.bindPopup(popup_21ee019faa8c5a9ef5e8e536c8390dbb)
#         ;
#
#
#
#
#             var circle_marker_0b2ab721cde0eeb9e6a0985ca67d38b1 = L.circleMarker(
#                 [41.55122, -7.24994],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_be9bcf2e99f5d30d0c9a60ebe09e3ece);
#
#
#         var popup_8f287ca745a829e1efc4b273688a7389 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37a37fa16cbdcccd61934979ec785ed1 = $(`&lt;div id=&quot;html_37a37fa16cbdcccd61934979ec785ed1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 4605340490&lt;br&gt;

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/M_margaritifera/M_margaritifera_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/M_margaritifera/M_margaritifera_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/M_margaritifera/M_margaritifera_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID                      species  decimalLatitude  decimalLongitude  \
# 0  4605340506  Margaritifera margaritifera         41.67778          -7.21750
# 1  4605340495  Margaritifera margaritifera         41.59944          -7.25556
# 2  4605340490  Margaritifera margaritifera         41.55122          -7.24994
# 3  4605340368  Margaritifera margaritifera         41.64694          -7.23833
# 4  4462993522  Margaritifera margaritifera         41.71556          -7.20611
#
#   countryCode   eventDate      basisOfRecord  coordinateUncertaintyInMeters  \
# 0          PT  2023-09-04  HUMAN_OBSERVATION                            5.0
# 1          PT  2021-07-01  HUMAN_OBSERVATION                            5.0
# 2          PT  2022-07-19  HUMAN_OBSERVATION                            5.0
# 3          PT  2021-07-01  HUMAN_OBSERVATION                            5.0
# 4          PT  2018-06-25  HUMAN_OBSERVATION                            5.0
#
#      year  month   day                   geometry
# 0  2023.0    9.0   4.0   POINT (-7.2175 41.67778)
# 1  2021.0    7.0   1.0  POINT (-7.25556 41.59944)
# 2  2022.0    7.0  19.0  POINT (-7.24994 41.55122)
# 3  2021.0    7.0   1.0  POINT (-7.23833 41.64694)
# 4  2018.0    6.0  25.0  POINT (-7.20611 41.71556)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count       9.000000
# mean      975.777778
# std      1543.962255
# min         5.000000
# 25%         5.000000
# 50%         5.000000
# 75%      1817.000000
# max      3849.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 39 original records
# 6 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/M_margaritifera/M_margaritifera_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="spp_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/M_margaritifera/M_margaritifera_clean.gpkg

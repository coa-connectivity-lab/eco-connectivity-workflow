# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Nicrophorus_vespillo'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Nicrophorus_vespillo.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Nicrophorus_vespillo

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Nicrophorus_vespillo/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Nicrophorus_vespillo/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Nicrophorus_vespillo/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Nicrophorus_vespillo/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Nicrophorus_vespillo/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Nicrophorus_vespillo/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Nicrophorus_vespillo/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Nicrophorus_vespillo/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (18, 230)
#        gbifID  accessRights  bibliographicCitation  language       license  \
# 0  6178503558           NaN                    NaN       NaN  CC_BY_NC_4_0
# 1  5827896471           NaN                    NaN       NaN  CC_BY_NC_4_0
# 2  5230047378           NaN                    NaN       NaN  CC_BY_NC_4_0
# 3  5154723113           NaN                    NaN       NaN  CC_BY_NC_4_0
# 4  4903933483           NaN                    NaN       NaN  CC_BY_NC_4_0
#
#                modified  publisher  \
# 0  2026-03-16T14:52:49Z        NaN
# 1  2025-09-04T12:54:56Z        NaN
# 2  2025-07-20T09:28:06Z        NaN
# 3  2025-05-01T14:43:43Z        NaN
# 4  2024-08-03T21:42:14Z        NaN
#
#                                           references       rightsHolder  type  \
# 0  https://www.inaturalist.org/observations/34331...              mhm43   NaN
# 1  https://www.inaturalist.org/observations/30522...           endornis   NaN
# 2  https://www.inaturalist.org/observations/29700...  Charcos Companhia   NaN
# 3  https://www.inaturalist.org/observations/27487...     Beatriz Simões   NaN
# 4  https://www.inaturalist.org/observations/22655...             Daniel   NaN
#
#    ...  publishedByGbifRegion  level0Gid  level0Name level1Gid level1Name  \
# 0  ...          NORTH_AMERICA        PRT    Portugal   PRT.1_1     Aveiro
# 1  ...          NORTH_AMERICA        PRT    Portugal   PRT.4_1      Braga
# 2  ...                 EUROPE        PRT    Portugal   PRT.1_1     Aveiro
# 3  ...          NORTH_AMERICA        PRT    Portugal   PRT.7_1    Coimbra
# 4  ...                 EUROPE        PRT    Portugal  PRT.15_1      Porto
#
#     level2Gid         level2Name     level3Gid level3Name  iucnRedListCategory
# 0   PRT.1.5_1             Aveiro   PRT.1.5.6_1     Glória                  NaN
# 1   PRT.4.7_1               Fafe  PRT.4.7.27_1   Ribeiros                  NaN
# 2  PRT.1.18_1              Vagos  PRT.1.18.1_1     Calvão                  NaN
# 3   PRT.7.2_1         Cantanhede  PRT.7.2.18_1      Tocha                  NaN
# 4  PRT.15.9_1  Paços de Ferreira  PRT.15.9.8_1  Freamunde                  NaN
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (18, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (18, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (18, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (18, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (18, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (18, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (13, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (13, 12)
#        gbifID               species  decimalLatitude  decimalLongitude  \
# 0  6178503558  Nicrophorus vespillo        40.630628         -8.649583
# 1  5827896471  Nicrophorus vespillo        41.495084         -8.112583
# 2  5230047378  Nicrophorus vespillo        40.490405         -8.686626
# 3  5154723113  Nicrophorus vespillo        40.328999         -8.845453
# 4  4903933483  Nicrophorus vespillo        41.281934         -8.349700
#
#   countryCode             eventDate      basisOfRecord  \
# 0          PT  2026-03-16T12:34:01Z  HUMAN_OBSERVATION
# 1          PT   2025-08-08T18:19:27  HUMAN_OBSERVATION
# 2          PT   2025-07-11T13:28:39  HUMAN_OBSERVATION
# 3          PT   2024-09-14T17:17:39  HUMAN_OBSERVATION
# 4          PT   2024-07-01T23:27:48  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month  day                   geometry
# 0                            NaN  2026      3   16  POINT (-8.64958 40.63063)
# 1                         3361.0  2025      8    8  POINT (-8.11258 41.49508)
# 2                            NaN  2025      7   11   POINT (-8.68663 40.4904)
# 3                            NaN  2024      9   14    POINT (-8.84545 40.329)
# 4                            6.0  2024      7    1   POINT (-8.3497 41.28193)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Nicrophorus_vespillo

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Nicrophorus_vespillo/Nicrophorus_vespillo.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Nicrophorus_vespillo/Nicrophorus_vespillo.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Nicrophorus_vespillo/Nicrophorus_vespillo.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Nicrophorus_vespillo/Nicrophorus_vespillo.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Nicrophorus_vespillo
# Records: 13
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Nicrophorus_vespillo/Nicrophorus_vespillo.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Nicrophorus_vespillo/Nicrophorus_vespillo.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Nicrophorus_vespillo/Nicrophorus_vespillo.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Nicrophorus_vespillo/Nicrophorus_vespillo.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3df7179d20a2d0a06f814759b080f47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3df7179d20a2d0a06f814759b080f47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c3df7179d20a2d0a06f814759b080f47 = L.map(
#                 &quot;map_c3df7179d20a2d0a06f814759b080f47&quot;,
#                 {
#                     center: [40.86091499999999, -8.540339615384614],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aabc1d3f20a141c4c4198b595874cc59 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aabc1d3f20a141c4c4198b595874cc59.addTo(map_c3df7179d20a2d0a06f814759b080f47);
#
#
#             var marker_cluster_ea4ad5d3b6496d08176f4c43bfd0b8fc = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_e2f619a6a1fc6c0e65ef08f29af63ea7 = L.circleMarker(
#                 [40.630628, -8.649583],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_ea4ad5d3b6496d08176f4c43bfd0b8fc);
#
#
#         var popup_72529c65cb87aee19af2f6e050b0269c = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_b1c84ee1c6c11709f4197cd357ef231a = $(`&lt;div id=&quot;html_b1c84ee1c6c11709f4197cd357ef231a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6178503558&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Nicrophorus vespillo&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-03-16T12:34:01Z&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; nan     &lt;/div&gt;`)[0];
#                 popup_72529c65cb87aee19af2f6e050b0269c.setContent(html_b1c84ee1c6c11709f4197cd357ef231a);
#
#
#
#         circle_marker_e2f619a6a1fc6c0e65ef08f29af63ea7.bindPopup(popup_72529c65cb87aee19af2f6e050b0269c)
#         ;
#
#
#
#
#             var circle_marker_611390c44c03ae6c9ff22d2dfe153cb6 = L.circleMarker(
#                 [41.495084, -8.112583],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_ea4ad5d3b6496d08176f4c43bfd0b8fc);
#
#
#         var popup_80d7a996bcf3f8d8ce0c92253f45ed51 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_6079842544033f7e7fb5af07bfccc080 = $(`&lt;div id=&quot;html_6079842544033f7e7fb5af07bfccc080&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5827896471&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Nicrophorus vespillo&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2025-08-08T18:19:27&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 3361.0     &lt;/div&gt;`)[0];
#                 popup_80d7a996bcf3f8d8ce0c92253f45ed51.setContent(html_6079842544033f7e7fb5af07bfccc080);
#
#
#
#         circle_marker_611390c44c03ae6c9ff22d2dfe153cb6.bindPopup(popup_80d7a996bcf3f8d8ce0c92253f45ed51)
#         ;
#
#
#
#
#             var circle_marker_23237360a460fdadcaa5959e06cbd447 = L.circleMarker(
#                 [40.490405, -8.686626],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 13

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 13

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_279006deac711b0a9e9581ca85447cb9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_279006deac711b0a9e9581ca85447cb9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_279006deac711b0a9e9581ca85447cb9 = L.map(
#                 &quot;map_279006deac711b0a9e9581ca85447cb9&quot;,
#                 {
#                     center: [40.86091499999999, -8.540339615384614],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6a3cf4fb4b5860fb640818cfebb6498 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a6a3cf4fb4b5860fb640818cfebb6498.addTo(map_279006deac711b0a9e9581ca85447cb9);
#
#
#             var circle_marker_a144832ea99c01c621800f621e3e6ad2 = L.circleMarker(
#                 [40.630628, -8.649583],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_279006deac711b0a9e9581ca85447cb9);
#
#
#         var popup_9f53988446f3abb3c7b37b72d42d0ab7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0c9e421a7babbf76f74278e51a6c496 = $(`&lt;div id=&quot;html_e0c9e421a7babbf76f74278e51a6c496&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6178503558&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Nicrophorus vespillo&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_9f53988446f3abb3c7b37b72d42d0ab7.setContent(html_e0c9e421a7babbf76f74278e51a6c496);
#
#
#
#         circle_marker_a144832ea99c01c621800f621e3e6ad2.bindPopup(popup_9f53988446f3abb3c7b37b72d42d0ab7)
#         ;
#
#
#
#
#             var circle_marker_d9d517c4c421f0e4854b30d3edf7a573 = L.circleMarker(
#                 [41.495084, -8.112583],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_279006deac711b0a9e9581ca85447cb9);
#
#
#         var popup_23700fd83bad27ebe663cf585d7eb3af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4389818a07b7231f7bb308a90633c4e8 = $(`&lt;div id=&quot;html_4389818a07b7231f7bb308a90633c4e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5827896471&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Nicrophorus vespillo&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_23700fd83bad27ebe663cf585d7eb3af.setContent(html_4389818a07b7231f7bb308a90633c4e8);
#
#
#
#         circle_marker_d9d517c4c421f0e4854b30d3edf7a573.bindPopup(popup_23700fd83bad27ebe663cf585d7eb3af)
#         ;
#
#
#
#
#             var circle_marker_8fc18f1c559ae282d1fba66058bb53f5 = L.circleMarker(
#                 [40.490405, -8.686626],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_279006deac711b0a9e9581ca85447cb9);
#
#
#         var popup_a58c930f87cd6794aa1253dbe890b758 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2994287c245d313152aa1daa6a652b6 = $(`&lt;div id=&quot;html_e2994287c245d313152aa1daa6a652b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5230047378&lt;br&gt;     &lt;b&g

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Nicrophorus_vespillo/Nicrophorus_vespillo_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Nicrophorus_vespillo/Nicrophorus_vespillo_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Nicrophorus_vespillo/Nicrophorus_vespillo_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID               species  decimalLatitude  decimalLongitude  \
# 0  6178503558  Nicrophorus vespillo        40.630628         -8.649583
# 1  5827896471  Nicrophorus vespillo        41.495084         -8.112583
# 2  5230047378  Nicrophorus vespillo        40.490405         -8.686626
# 3  5154723113  Nicrophorus vespillo        40.328999         -8.845453
# 4  4903933483  Nicrophorus vespillo        41.281934         -8.349700
#
#   countryCode                  eventDate      basisOfRecord  \
# 0          PT  2026-03-16T12:34:01+00:00  HUMAN_OBSERVATION
# 1          PT        2025-08-08T18:19:27  HUMAN_OBSERVATION
# 2          PT        2025-07-11T13:28:39  HUMAN_OBSERVATION
# 3          PT        2024-09-14T17:17:39  HUMAN_OBSERVATION
# 4          PT        2024-07-01T23:27:48  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month  day                   geometry
# 0                            NaN  2026      3   16  POINT (-8.64958 40.63063)
# 1                         3361.0  2025      8    8  POINT (-8.11258 41.49508)
# 2                            NaN  2025      7   11   POINT (-8.68663 40.4904)
# 3                            NaN  2024      9   14    POINT (-8.84545 40.329)
# 4                            6.0  2024      7    1   POINT (-8.3497 41.28193)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count       7.000000
# mean      505.428571
# std      1259.871403
# min         4.000000
# 25%         7.000000
# 50%         8.000000
# 75%        75.500000
# max      3361.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 13 original records
# 4 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Nicrophorus_vespillo/Nicrophorus_vespillo_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="spp_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Nicrophorus_vespillo/Nicrophorus_vespillo_clean.gpkg

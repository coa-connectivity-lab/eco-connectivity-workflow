# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'P_polylepis'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/P_polylepis.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/P_polylepis

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/P_polylepis/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/P_polylepis/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/P_polylepis/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/P_polylepis/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/P_polylepis/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/P_polylepis/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/P_polylepis/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/P_polylepis/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (38, 230)
#        gbifID  accessRights  bibliographicCitation  language       license  \
# 0  5920015065           NaN                    NaN       NaN  CC_BY_NC_4_0
# 1  5909368203           NaN                    NaN       NaN  CC_BY_NC_4_0
# 2  5909257916           NaN                    NaN       NaN  CC_BY_NC_4_0
# 3  5909208386           NaN                    NaN       NaN       CC0_1_0
# 4  5909043682           NaN                    NaN       NaN  CC_BY_NC_4_0
#
#                modified  publisher  \
# 0  2025-12-04T16:29:07Z        NaN
# 1  2025-12-04T11:01:42Z        NaN
# 2  2025-12-04T11:01:49Z        NaN
# 3  2025-12-03T21:22:33Z        NaN
# 4  2025-12-04T11:02:12Z        NaN
#
#                                           references  rightsHolder  type  ...  \
# 0  https://www.inaturalist.org/observations/13224...  josemmartins   NaN  ...
# 1  https://www.inaturalist.org/observations/32723...   marcoarruda   NaN  ...
# 2  https://www.inaturalist.org/observations/32723...   marcoarruda   NaN  ...
# 3  https://www.inaturalist.org/observations/55786139      GMarques   NaN  ...
# 4  https://www.inaturalist.org/observations/32723...   marcoarruda   NaN  ...
#
#    publishedByGbifRegion  level0Gid  level0Name level1Gid level1Name  \
# 0                 EUROPE        PRT    Portugal  PRT.11_1     Leiria
# 1                 EUROPE        PRT    Portugal  PRT.16_1   Santarém
# 2                 EUROPE        PRT    Portugal  PRT.16_1   Santarém
# 3                 EUROPE        PRT    Portugal   PRT.1_1     Aveiro
# 4                 EUROPE        PRT    Portugal  PRT.16_1   Santarém
#
#      level2Gid      level2Name       level3Gid           level3Name  \
# 0  PRT.11.15_1          Pombal  PRT.11.15.12_1               Pombal
# 1  PRT.16.17_1        Santarém  PRT.16.17.14_1               Pernes
# 2  PRT.16.17_1        Santarém  PRT.16.17.14_1               Pernes
# 3   PRT.1.17_1  Sever do Vouga    PRT.1.17.9_1             Talhadas
# 4  PRT.16.17_1        Santarém  PRT.16.17.23_1  São Vicente Do Paul
#
#    iucnRedListCategory
# 0                   VU
# 1                   VU
# 2                   VU
# 3                   VU
# 4                   VU
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (38, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (38, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (38, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (38, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (38, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (38, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (36, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (36, 12)
#        gbifID                       species  decimalLatitude  \
# 0  5920015065  Pseudochondrostoma polylepis        39.900143
# 1  5909368203  Pseudochondrostoma polylepis        39.386362
# 2  5909257916  Pseudochondrostoma polylepis        39.386391
# 3  5909208386  Pseudochondrostoma polylepis        40.650636
# 4  5909043682  Pseudochondrostoma polylepis        39.351307
#
#    decimalLongitude countryCode            eventDate      basisOfRecord  \
# 0         -8.631133          PT  2022-08-24T18:32:05  HUMAN_OBSERVATION
# 1         -8.657855          PT     2025-07-21T11:01  HUMAN_OBSERVATION
# 2         -8.657862          PT     2025-07-21T11:01  HUMAN_OBSERVATION
# 3         -8.300488          PT  2020-08-08T12:04:56  HUMAN_OBSERVATION
# 4         -8.615156          PT     2025-07-21T11:01  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month  day                   geometry
# 0                            6.0  2022      8   24  POINT (-8.63113 39.90014)
# 1                            2.0  2025      7   21  POINT (-8.65786 39.38636)
# 2                            2.0  2025      7   21  POINT (-8.65786 39.38639)
# 3                            NaN  2020      8    8  POINT (-8.30049 40.65064)
# 4                          488.0  2025      7   21  POINT (-8.61516 39.35131)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/P_polylepis

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/P_polylepis/P_polylepis.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/P_polylepis/P_polylepis.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/P_polylepis/P_polylepis.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/P_polylepis/P_polylepis.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: P_polylepis
# Records: 36
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/P_polylepis/P_polylepis.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/P_polylepis/P_polylepis.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/P_polylepis/P_polylepis.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/P_polylepis/P_polylepis.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2ec07426bd9a6354f01afda7f32ea9c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2ec07426bd9a6354f01afda7f32ea9c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2ec07426bd9a6354f01afda7f32ea9c = L.map(
#                 &quot;map_b2ec07426bd9a6354f01afda7f32ea9c&quot;,
#                 {
#                     center: [39.62261927777779, -8.44791227777778],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7055d8b46675771eaf3a92f614de3cda = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7055d8b46675771eaf3a92f614de3cda.addTo(map_b2ec07426bd9a6354f01afda7f32ea9c);
#
#
#             var marker_cluster_de0522fe4c14905a405befff77c50ba6 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_56395d3128da66a5b233242a9007447a = L.circleMarker(
#                 [39.900143, -8.631133],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_de0522fe4c14905a405befff77c50ba6);
#
#
#         var popup_3f1d8b7e9ba3099ce91db6e8a826a623 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_b8bf1e85ab707df85f6bb1b8020c31ce = $(`&lt;div id=&quot;html_b8bf1e85ab707df85f6bb1b8020c31ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5920015065&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Pseudochondrostoma polylepis&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2022-08-24T18:32:05&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 6.0     &lt;/div&gt;`)[0];
#                 popup_3f1d8b7e9ba3099ce91db6e8a826a623.setContent(html_b8bf1e85ab707df85f6bb1b8020c31ce);
#
#
#
#         circle_marker_56395d3128da66a5b233242a9007447a.bindPopup(popup_3f1d8b7e9ba3099ce91db6e8a826a623)
#         ;
#
#
#
#
#             var circle_marker_30ec79d8d1dc77418d4c9c8199326e3e = L.circleMarker(
#                 [39.386362, -8.657855],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_de0522fe4c14905a405befff77c50ba6);
#
#
#         var popup_f5420c04507a81dd3f4b2455b870cf90 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_3b318a04cd741d8c05058844ad5bd752 = $(`&lt;div id=&quot;html_3b318a04cd741d8c05058844ad5bd752&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5909368203&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Pseudochondrostoma polylepis&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2025-07-21T11:01&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 2.0     &lt;/div&gt;`)[0];
#                 popup_f5420c04507a81dd3f4b2455b870cf90.setContent(html_3b318a04cd741d8c05058844ad5bd752);
#
#
#
#         circle_marker_30ec79d8d1dc77418d4c9c8199326e3e.bindPopup(popup_f5420c04507a81dd3f4b2455b870cf90)
#         ;
#
#
#
#
#             var circle_marker_497c37c46cc93f06c352399c615b6a55 = L.circleMarker(
#                 [39.386391, -8.657862],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: nul

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 36

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 36

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c434fef99a3c730c68b3452434a637f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c434fef99a3c730c68b3452434a637f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c434fef99a3c730c68b3452434a637f = L.map(
#                 &quot;map_0c434fef99a3c730c68b3452434a637f&quot;,
#                 {
#                     center: [39.62261927777779, -8.44791227777778],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ddb00f0209ebf1f232049cbb8a391dc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ddb00f0209ebf1f232049cbb8a391dc.addTo(map_0c434fef99a3c730c68b3452434a637f);
#
#
#             var circle_marker_032f1cae79b9be3c6dd54bde74ce3a2c = L.circleMarker(
#                 [39.900143, -8.631133],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0c434fef99a3c730c68b3452434a637f);
#
#
#         var popup_d7dbc2eed0005bd60942455e76ba935c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c28058440f5c3135e53cffd872ce868 = $(`&lt;div id=&quot;html_9c28058440f5c3135e53cffd872ce868&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5920015065&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Pseudochondrostoma polylepis&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_d7dbc2eed0005bd60942455e76ba935c.setContent(html_9c28058440f5c3135e53cffd872ce868);
#
#
#
#         circle_marker_032f1cae79b9be3c6dd54bde74ce3a2c.bindPopup(popup_d7dbc2eed0005bd60942455e76ba935c)
#         ;
#
#
#
#
#             var circle_marker_6e01a3de393dfcc76dd775a819640de5 = L.circleMarker(
#                 [39.386362, -8.657855],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0c434fef99a3c730c68b3452434a637f);
#
#
#         var popup_8b6b47fd5560ada4a870ff9edb485fed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f9c4b3459242765b62047c144972a3d = $(`&lt;div id=&quot;html_1f9c4b3459242765b62047c144972a3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5909368203&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Pseudochondrostoma polylepis&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_8b6b47fd5560ada4a870ff9edb485fed.setContent(html_1f9c4b3459242765b62047c144972a3d);
#
#
#
#         circle_marker_6e01a3de393dfcc76dd775a819640de5.bindPopup(popup_8b6b47fd5560ada4a870ff9edb485fed)
#         ;
#
#
#
#
#             var circle_marker_a73ff524c2a7672aa9229732d9cbb919 = L.circleMarker(
#                 [39.386391, -8.657862],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0c434fef99a3c730c68b3452434a637f);
#
#
#         var popup_d5f6dd1af40ee600ab4a812b8f728c67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b80b9b01b4644f46f1671deb47d71818 = $(`&lt;div id=&quot;html_b80b9b01b4644f46f1671deb47d71818&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5909257916&lt;br&

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/P_polylepis/P_polylepis_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/P_polylepis/P_polylepis_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/P_polylepis/P_polylepis_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID                       species  decimalLatitude  \
# 0  5920015065  Pseudochondrostoma polylepis        39.900143
# 1  5909368203  Pseudochondrostoma polylepis        39.386362
# 2  5909257916  Pseudochondrostoma polylepis        39.386391
# 3  5909208386  Pseudochondrostoma polylepis        40.650636
# 4  5909043682  Pseudochondrostoma polylepis        39.351307
#
#    decimalLongitude countryCode            eventDate      basisOfRecord  \
# 0         -8.631133          PT  2022-08-24T18:32:05  HUMAN_OBSERVATION
# 1         -8.657855          PT  2025-07-21T11:01:00  HUMAN_OBSERVATION
# 2         -8.657862          PT  2025-07-21T11:01:00  HUMAN_OBSERVATION
# 3         -8.300488          PT  2020-08-08T12:04:56  HUMAN_OBSERVATION
# 4         -8.615156          PT  2025-07-21T11:01:00  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month  day                   geometry
# 0                            6.0  2022      8   24  POINT (-8.63113 39.90014)
# 1                            2.0  2025      7   21  POINT (-8.65786 39.38636)
# 2                            2.0  2025      7   21  POINT (-8.65786 39.38639)
# 3                            NaN  2020      8    8  POINT (-8.30049 40.65064)
# 4                          488.0  2025      7   21  POINT (-8.61516 39.35131)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count      28.000000
# mean      167.392857
# std       380.591483
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        33.750000
# max      1670.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 36 original records
# 20 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/P_polylepis/P_polylepis_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="P_polylepis_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/P_polylepis/P_polylepis_clean.gpkg

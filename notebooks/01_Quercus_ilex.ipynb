# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Quercus_ilex'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Quercus_ilex.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Quercus_ilex

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Quercus_ilex/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Quercus_ilex/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Quercus_ilex/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Quercus_ilex/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Quercus_ilex/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Quercus_ilex/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Quercus_ilex/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Quercus_ilex/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (230, 230)
#        gbifID  accessRights  bibliographicCitation  language       license  \
# 0  6234829813           NaN                    NaN       NaN     CC_BY_4_0
# 1  6228108415           NaN                    NaN       NaN  CC_BY_NC_4_0
# 2  6187780797           NaN                    NaN       NaN     CC_BY_4_0
# 3  6178171498           NaN                    NaN       NaN     CC_BY_4_0
# 4  6131210306           NaN                    NaN       NaN  CC_BY_NC_4_0
#
#                modified  publisher  \
# 0  2026-04-16T02:15:27Z        NaN
# 1  2026-04-23T10:05:00Z        NaN
# 2                   NaN        NaN
# 3                   NaN        NaN
# 4  2026-01-11T16:15:06Z        NaN
#
#                                           references  \
# 0  https://www.inaturalist.org/observations/34748...
# 1                                                NaN
# 2  https://enjoynature.net/?gebiet=1030105112&dat...
# 3  https://enjoynature.net/?gebiet=-250924723&dat...
# 4  https://www.inaturalist.org/observations/33420...
#
#                           rightsHolder  type  ...  publishedByGbifRegion  \
# 0                           James Hyde   NaN  ...          NORTH_AMERICA
# 1  Stichting Observation International   NaN  ...                 EUROPE
# 2                                  NaN   NaN  ...                 EUROPE
# 3                                  NaN   NaN  ...                 EUROPE
# 4                           saqlain146   NaN  ...          NORTH_AMERICA
#
#    level0Gid  level0Name level1Gid level1Name   level2Gid   level2Name  \
# 0        PRT    Portugal  PRT.13_1    Madeira  PRT.13.7_1  Porto Santo
# 1        PRT    Portugal   PRT.9_1       Faro   PRT.9.8_1        Loulé
# 2        PRT    Portugal   PRT.9_1       Faro   PRT.9.8_1        Loulé
# 3        PRT    Portugal   PRT.9_1       Faro   PRT.9.8_1        Loulé
# 4        PRT    Portugal  PRT.13_1    Madeira  PRT.13.9_1   Santa Cruz
#
#       level3Gid   level3Name  iucnRedListCategory
# 0  PRT.13.7.2_1  Porto Santo                   LC
# 1   PRT.9.8.9_1     Querença                   LC
# 2   PRT.9.8.9_1     Querença                   LC
# 3  PRT.9.8.10_1        Salir                   LC
# 4  PRT.13.9.1_1      Camacha                   LC
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (230, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (230, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (230, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (230, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (230, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (220, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (220, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (220, 12)
#        gbifID       species  decimalLatitude  decimalLongitude countryCode  \
# 0  6234829813  Quercus ilex        33.081203        -16.333916          PT
# 1  6228108415  Quercus ilex        37.198704         -8.004391          PT
# 2  6187780797  Quercus ilex        37.206844         -8.005310          PT
# 3  6178171498  Quercus ilex        37.252125         -8.105507          PT
# 4  6131210306  Quercus ilex        32.683823        -16.851933          PT
#
#               eventDate      basisOfRecord  coordinateUncertaintyInMeters  \
# 0   2026-04-05T10:37:10  HUMAN_OBSERVATION                            5.0
# 1            2026-04-21  HUMAN_OBSERVATION                           11.0
# 2      2026-02-28T00:00  HUMAN_OBSERVATION                          250.0
# 3      2026-02-23T00:00  HUMAN_OBSERVATION                          250.0
# 4  2026-01-10T11:30:33Z  HUMAN_OBSERVATION                            4.0
#
#    year  month  day                    geometry
# 0  2026      4    5   POINT (-16.33392 33.0812)
# 1  2026      4   21    POINT (-8.00439 37.1987)
# 2  2026      2   28   POINT (-8.00531 37.20684)
# 3  2026      2   23   POINT (-8.10551 37.25212)
# 4  2026      1   10  POINT (-16.85193 32.68382)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Quercus_ilex

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Quercus_ilex/Quercus_ilex.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Quercus_ilex/Quercus_ilex.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Quercus_ilex/Quercus_ilex.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Quercus_ilex/Quercus_ilex.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Quercus_ilex
# Records: 220
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Quercus_ilex/Quercus_ilex.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Quercus_ilex/Quercus_ilex.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Quercus_ilex/Quercus_ilex.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Quercus_ilex/Quercus_ilex.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aadc6fe7e203d6bdf7410580cf7ba082 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aadc6fe7e203d6bdf7410580cf7ba082&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aadc6fe7e203d6bdf7410580cf7ba082 = L.map(
#                 &quot;map_aadc6fe7e203d6bdf7410580cf7ba082&quot;,
#                 {
#                     center: [38.20737408636363, -9.261161218181817],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cefa8662dafbd1a421edb4eca4893b1f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cefa8662dafbd1a421edb4eca4893b1f.addTo(map_aadc6fe7e203d6bdf7410580cf7ba082);
#
#
#             var marker_cluster_bb819f2a271578aa3301d06178819b51 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_18c7c7f9ad308c3f4cf6512f373812ef = L.circleMarker(
#                 [33.081203, -16.333916],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_bb819f2a271578aa3301d06178819b51);
#
#
#         var popup_3e4e358c33bfc49ca5962136fdd3c3a5 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_da45191dc007a4d78661529618fde9eb = $(`&lt;div id=&quot;html_da45191dc007a4d78661529618fde9eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6234829813&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Quercus ilex&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-04-05T10:37:10&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 5.0     &lt;/div&gt;`)[0];
#                 popup_3e4e358c33bfc49ca5962136fdd3c3a5.setContent(html_da45191dc007a4d78661529618fde9eb);
#
#
#
#         circle_marker_18c7c7f9ad308c3f4cf6512f373812ef.bindPopup(popup_3e4e358c33bfc49ca5962136fdd3c3a5)
#         ;
#
#
#
#
#             var circle_marker_25d2989113f758d614ac5d3bb79afaff = L.circleMarker(
#                 [37.198704, -8.004391],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_bb819f2a271578aa3301d06178819b51);
#
#
#         var popup_5992e05d8a8e0daf26204f1a0977eb50 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_ae0f59747a826a2f7c23c7cacb219ae1 = $(`&lt;div id=&quot;html_ae0f59747a826a2f7c23c7cacb219ae1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6228108415&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Quercus ilex&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-04-21&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 11.0     &lt;/div&gt;`)[0];
#                 popup_5992e05d8a8e0daf26204f1a0977eb50.setContent(html_ae0f59747a826a2f7c23c7cacb219ae1);
#
#
#
#         circle_marker_25d2989113f758d614ac5d3bb79afaff.bindPopup(popup_5992e05d8a8e0daf26204f1a0977eb50)
#         ;
#
#
#
#
#             var circle_marker_62355fee9e140fb6a6dcb65d5ddc6cb1 = L.circleMarker(
#                 [37.206844, -8.00531],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &qu

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 220

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 220

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7f1cd17c521c64dc6d2f639b087d31e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7f1cd17c521c64dc6d2f639b087d31e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7f1cd17c521c64dc6d2f639b087d31e = L.map(
#                 &quot;map_b7f1cd17c521c64dc6d2f639b087d31e&quot;,
#                 {
#                     center: [38.20737408636363, -9.261161218181817],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6afbfb72773c6178ff52e826c8e69c4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a6afbfb72773c6178ff52e826c8e69c4.addTo(map_b7f1cd17c521c64dc6d2f639b087d31e);
#
#
#             var circle_marker_1487fad64a0aacc23dc99fa994c54edf = L.circleMarker(
#                 [33.081203, -16.333916],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7f1cd17c521c64dc6d2f639b087d31e);
#
#
#         var popup_de9f5fc72ddad3199e5fc971a07e1b41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abee993999296a69f12b22bd1be5d28d = $(`&lt;div id=&quot;html_abee993999296a69f12b22bd1be5d28d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6234829813&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Quercus ilex&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_de9f5fc72ddad3199e5fc971a07e1b41.setContent(html_abee993999296a69f12b22bd1be5d28d);
#
#
#
#         circle_marker_1487fad64a0aacc23dc99fa994c54edf.bindPopup(popup_de9f5fc72ddad3199e5fc971a07e1b41)
#         ;
#
#
#
#
#             var circle_marker_b60519df0ffbf3bb9f4331931277c10f = L.circleMarker(
#                 [37.198704, -8.004391],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7f1cd17c521c64dc6d2f639b087d31e);
#
#
#         var popup_e9f03c4f6042e73d6ff6c206fbcc82be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb575d2d3de6873223c2feebe6d14f12 = $(`&lt;div id=&quot;html_fb575d2d3de6873223c2feebe6d14f12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6228108415&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Quercus ilex&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_e9f03c4f6042e73d6ff6c206fbcc82be.setContent(html_fb575d2d3de6873223c2feebe6d14f12);
#
#
#
#         circle_marker_b60519df0ffbf3bb9f4331931277c10f.bindPopup(popup_e9f03c4f6042e73d6ff6c206fbcc82be)
#         ;
#
#
#
#
#             var circle_marker_16d4f9b420a943502892d5bbd0f250c8 = L.circleMarker(
#                 [37.206844, -8.00531],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7f1cd17c521c64dc6d2f639b087d31e);
#
#
#         var popup_8ffd7ca3cef611b56baa8d94469161a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a8c24adc51f5b34d21c416f2973261f = $(`&lt;div id=&quot;html_2a8c24adc51f5b34d21c416f2973261f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6187780797&lt;br&gt;     &lt;b&gt;Species:&lt;/b

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Quercus_ilex/Quercus_ilex_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Quercus_ilex/Quercus_ilex_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Quercus_ilex/Quercus_ilex_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID       species  decimalLatitude  decimalLongitude countryCode  \
# 0  6234829813  Quercus ilex        33.081203        -16.333916          PT
# 1  6228108415  Quercus ilex        37.198704         -8.004391          PT
# 2  6187780797  Quercus ilex        37.206844         -8.005310          PT
# 3  6178171498  Quercus ilex        37.252125         -8.105507          PT
# 4  6131210306  Quercus ilex        32.683823        -16.851933          PT
#
#                    eventDate      basisOfRecord  \
# 0        2026-04-05T10:37:10  HUMAN_OBSERVATION
# 1        2026-04-21T00:00:00  HUMAN_OBSERVATION
# 2        2026-02-28T00:00:00  HUMAN_OBSERVATION
# 3        2026-02-23T00:00:00  HUMAN_OBSERVATION
# 4  2026-01-10T11:30:33+00:00  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month  day                    geometry
# 0                            5.0  2026      4    5   POINT (-16.33392 33.0812)
# 1                           11.0  2026      4   21    POINT (-8.00439 37.1987)
# 2                          250.0  2026      2   28   POINT (-8.00531 37.20684)
# 3                          250.0  2026      2   23   POINT (-8.10551 37.25212)
# 4                            4.0  2026      1   10  POINT (-16.85193 32.68382)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count     171.000000
# mean       76.081871
# std       197.148628
# min         1.000000
# 25%         9.000000
# 50%        19.000000
# 75%        50.000000
# max      2200.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 220 original records
# 119 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Quercus_ilex/Quercus_ilex_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="spp_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Quercus_ilex/Quercus_ilex_clean.gpkg

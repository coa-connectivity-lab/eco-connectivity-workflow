# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Emys_orbicularis'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Emys_orbicularis.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Emys_orbicularis

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Emys_orbicularis/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Emys_orbicularis/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Emys_orbicularis/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Emys_orbicularis/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Emys_orbicularis/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Emys_orbicularis/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Emys_orbicularis/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Emys_orbicularis/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (319, 230)
#        gbifID  accessRights  bibliographicCitation  language       license  \
# 0   891077141           NaN                    NaN       NaN     CC_BY_4_0
# 1  6235670546           NaN                    NaN       NaN  CC_BY_NC_4_0
# 2  6195626743           NaN                    NaN       NaN  CC_BY_NC_4_0
# 3  6185134707           NaN                    NaN       NaN  CC_BY_NC_4_0
# 4  6185129326           NaN                    NaN       NaN  CC_BY_NC_4_0
#
#                modified  publisher  \
# 0  2025-01-14T16:10:01Z        NaN
# 1  2026-04-17T19:26:17Z        NaN
# 2  2026-04-08T12:40:26Z        NaN
# 3  2026-04-04T12:49:04Z        NaN
# 4  2026-03-25T21:29:45Z        NaN
#
#                                           references      rightsHolder type  \
# 0     https://www.inaturalist.org/observations/68049       snake snake  NaN
# 1  https://www.inaturalist.org/observations/34975...  Joao Tata Regala  NaN
# 2  https://www.inaturalist.org/observations/34825...        mmostert12  NaN
# 3  https://www.inaturalist.org/observations/34578...     Daniel Raposo  NaN
# 4  https://www.inaturalist.org/observations/34425...      João Esteves  NaN
#
#    ... publishedByGbifRegion  level0Gid  level0Name level1Gid level1Name  \
# 0  ...         NORTH_AMERICA        NaN         NaN       NaN        NaN
# 1  ...         NORTH_AMERICA        NaN         NaN       NaN        NaN
# 2  ...         NORTH_AMERICA        NaN         NaN       NaN        NaN
# 3  ...         NORTH_AMERICA        NaN         NaN       NaN        NaN
# 4  ...                EUROPE        NaN         NaN       NaN        NaN
#
#   level2Gid  level2Name level3Gid level3Name iucnRedListCategory
# 0       NaN         NaN       NaN        NaN                 NaN
# 1       NaN         NaN       NaN        NaN                  NT
# 2       NaN         NaN       NaN        NaN                  NT
# 3       NaN         NaN       NaN        NaN                 NaN
# 4       NaN         NaN       NaN        NaN                  NT
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (319, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (319, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (319, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (319, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (319, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (259, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (86, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (86, 12)
#         gbifID           species  decimalLatitude  decimalLongitude  \
# 5   6183525431  Emys orbicularis        37.034090         -7.812064
# 6   6182939655  Emys orbicularis        37.765770         -8.005957
# 7   6182844310  Emys orbicularis        37.032825         -7.812135
# 9   6170564886  Emys orbicularis        37.765718         -8.006792
# 10  6169208199  Emys orbicularis        37.028742         -8.009981
#
#    countryCode   eventDate      basisOfRecord  coordinateUncertaintyInMeters  \
# 5           PT  2026-01-24  HUMAN_OBSERVATION                           15.0
# 6           PT  2026-02-23  HUMAN_OBSERVATION                            3.0
# 7           PT  2025-05-08  HUMAN_OBSERVATION                           32.0
# 9           PT  2026-02-23  HUMAN_OBSERVATION                            5.0
# 10          PT  2026-02-27  HUMAN_OBSERVATION                           19.0
#
#     year  month   day                   geometry
# 5   2026    1.0  24.0  POINT (-7.81206 37.03409)
# 6   2026    2.0  23.0  POINT (-8.00596 37.76577)
# 7   2025    5.0   8.0  POINT (-7.81214 37.03282)
# 9   2026    2.0  23.0  POINT (-8.00679 37.76572)
# 10  2026    2.0  27.0  POINT (-8.00998 37.02874)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Emys_orbicularis

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Emys_orbicularis/Emys_orbicularis.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Emys_orbicularis/Emys_orbicularis.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Emys_orbicularis/Emys_orbicularis.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Emys_orbicularis/Emys_orbicularis.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Emys_orbicularis
# Records: 86
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Emys_orbicularis/Emys_orbicularis.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Emys_orbicularis/Emys_orbicularis.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Emys_orbicularis/Emys_orbicularis.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Emys_orbicularis/Emys_orbicularis.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51035aefd0b0d5bcd98ba020c851262e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51035aefd0b0d5bcd98ba020c851262e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51035aefd0b0d5bcd98ba020c851262e = L.map(
#                 &quot;map_51035aefd0b0d5bcd98ba020c851262e&quot;,
#                 {
#                     center: [37.85280583720931, -7.947090209302327],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2646b377e6fe7d4b7fc9ad1683d64d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a2646b377e6fe7d4b7fc9ad1683d64d7.addTo(map_51035aefd0b0d5bcd98ba020c851262e);
#
#
#             var marker_cluster_4faaaac1af3b4bbde9c93a0c7a2980d8 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_c26b09d8d5d167a0e3fb76ed6245ac49 = L.circleMarker(
#                 [37.03409, -7.812064],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_4faaaac1af3b4bbde9c93a0c7a2980d8);
#
#
#         var popup_0179ec4a756f4e2aa790b10b0a96b55a = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_956c9ab93f478ee251e8056aea624f88 = $(`&lt;div id=&quot;html_956c9ab93f478ee251e8056aea624f88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6183525431&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Emys orbicularis&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-01-24&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 15.0     &lt;/div&gt;`)[0];
#                 popup_0179ec4a756f4e2aa790b10b0a96b55a.setContent(html_956c9ab93f478ee251e8056aea624f88);
#
#
#
#         circle_marker_c26b09d8d5d167a0e3fb76ed6245ac49.bindPopup(popup_0179ec4a756f4e2aa790b10b0a96b55a)
#         ;
#
#
#
#
#             var circle_marker_2101c76f56616cfe81b0345c9a41eede = L.circleMarker(
#                 [37.76577, -8.005957],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_4faaaac1af3b4bbde9c93a0c7a2980d8);
#
#
#         var popup_c37266df3283e6bc36a3868e11736af1 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_69eae4d90df7a4cfebd9b38e39ff38d0 = $(`&lt;div id=&quot;html_69eae4d90df7a4cfebd9b38e39ff38d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6182939655&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Emys orbicularis&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-02-23&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 3.0     &lt;/div&gt;`)[0];
#                 popup_c37266df3283e6bc36a3868e11736af1.setContent(html_69eae4d90df7a4cfebd9b38e39ff38d0);
#
#
#
#         circle_marker_2101c76f56616cfe81b0345c9a41eede.bindPopup(popup_c37266df3283e6bc36a3868e11736af1)
#         ;
#
#
#
#
#             var circle_marker_7850b2b9c8ee550460ca975ae6c3875c = L.circleMarker(
#                 [37.032825, -7.812135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 86

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 86

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2799fa32b61cbda8b13fbddeb2e550c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2799fa32b61cbda8b13fbddeb2e550c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2799fa32b61cbda8b13fbddeb2e550c6 = L.map(
#                 &quot;map_2799fa32b61cbda8b13fbddeb2e550c6&quot;,
#                 {
#                     center: [37.85280583720931, -7.947090209302327],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58de74888eb4b5279910f62399ed0202 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_58de74888eb4b5279910f62399ed0202.addTo(map_2799fa32b61cbda8b13fbddeb2e550c6);
#
#
#             var circle_marker_e26b70ab821aca4295a6e4368e37bc7d = L.circleMarker(
#                 [37.03409, -7.812064],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2799fa32b61cbda8b13fbddeb2e550c6);
#
#
#         var popup_5428c7f8fda994d164190ce317d6947f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87bfb310238a00c0cdf402104a3a045d = $(`&lt;div id=&quot;html_87bfb310238a00c0cdf402104a3a045d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6183525431&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Emys orbicularis&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_5428c7f8fda994d164190ce317d6947f.setContent(html_87bfb310238a00c0cdf402104a3a045d);
#
#
#
#         circle_marker_e26b70ab821aca4295a6e4368e37bc7d.bindPopup(popup_5428c7f8fda994d164190ce317d6947f)
#         ;
#
#
#
#
#             var circle_marker_b7e0f96766be1e91a7fd10edc03523ca = L.circleMarker(
#                 [37.76577, -8.005957],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2799fa32b61cbda8b13fbddeb2e550c6);
#
#
#         var popup_b9f15485d4db03aa7ea6cb111089705c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed7f6a8d14669754ab63cfdd52b09a5d = $(`&lt;div id=&quot;html_ed7f6a8d14669754ab63cfdd52b09a5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6182939655&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Emys orbicularis&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_b9f15485d4db03aa7ea6cb111089705c.setContent(html_ed7f6a8d14669754ab63cfdd52b09a5d);
#
#
#
#         circle_marker_b7e0f96766be1e91a7fd10edc03523ca.bindPopup(popup_b9f15485d4db03aa7ea6cb111089705c)
#         ;
#
#
#
#
#             var circle_marker_a0de9fc292b1aac15ff8c778fb35c26a = L.circleMarker(
#                 [37.032825, -7.812135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2799fa32b61cbda8b13fbddeb2e550c6);
#
#
#         var popup_cbc13446c6136aa8e66cf58377112581 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b464b17dca2c1ca187cc560bb4c2b77 = $(`&lt;div id=&quot;html_6b464b17dca2c1ca187cc560bb4c2b77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6182844310&lt;br&gt;     &lt;b&gt;Species:

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Emys_orbicularis/Emys_orbicularis_review_points.geojson

# %%
import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Emys_orbicularis/Emys_orbicularis_review_points.geojson"
gdf = gpd.read_file(path)

gdf.head()
# Out:
#        gbifID           species  decimalLatitude  decimalLongitude  \
# 0  6183525431  Emys orbicularis        37.034090         -7.812064
# 1  6182939655  Emys orbicularis        37.765770         -8.005957
# 2  6182844310  Emys orbicularis        37.032825         -7.812135
# 3  6170564886  Emys orbicularis        37.765718         -8.006792
# 4  6169208199  Emys orbicularis        37.028742         -8.009981
#
#   countryCode   eventDate      basisOfRecord  coordinateUncertaintyInMeters  \
# 0          PT  2026-01-24  HUMAN_OBSERVATION                           15.0
# 1          PT  2026-02-23  HUMAN_OBSERVATION                            3.0
# 2          PT  2025-05-08  HUMAN_OBSERVATION                           32.0
# 3          PT  2026-02-23  HUMAN_OBSERVATION                            5.0
# 4          PT  2026-02-27  HUMAN_OBSERVATION                           19.0
#
#    year  month   day                   geometry
# 0  2026    1.0  24.0  POINT (-7.81206 37.03409)
# 1  2026    2.0  23.0  POINT (-8.00596 37.76577)
# 2  2025    5.0   8.0  POINT (-7.81214 37.03282)
# 3  2026    2.0  23.0  POINT (-8.00679 37.76572)
# 4  2026    2.0  27.0  POINT (-8.00998 37.02874)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count      79.000000
# mean       88.620253
# std       199.846756
# min         3.000000
# 25%         7.500000
# 50%        25.000000
# 75%        30.000000
# max      1000.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 86 original records
# 60 after cleaning

# %%
gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Emys_orbicularis/Emys_orbicularis_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="Emys_orbicularis_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Emys_orbicularis/Emys_orbicularis_clean.gpkg

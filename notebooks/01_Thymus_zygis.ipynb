# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Thymus_zygis'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Thymus_zygis.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Thymus_zygis

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Thymus_zygis/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Thymus_zygis/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Thymus_zygis/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Thymus_zygis/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Thymus_zygis/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Thymus_zygis/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Thymus_zygis/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Thymus_zygis/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (283, 230)
#        gbifID  accessRights  bibliographicCitation language       license  \
# 0  6195949741           NaN                    NaN      NaN  CC_BY_NC_4_0
# 1  6195226949           NaN                    NaN      NaN  CC_BY_NC_4_0
# 2  6188074775           NaN                    NaN      NaN  CC_BY_NC_4_0
# 3  6179058480           NaN                    NaN      NaN  CC_BY_NC_4_0
# 4  6179002508           NaN                    NaN      NaN  CC_BY_NC_4_0
#
#                modified  publisher  \
# 0  2026-04-11T15:03:24Z        NaN
# 1  2026-04-11T15:03:29Z        NaN
# 2  2026-04-04T15:27:56Z        NaN
# 3  2026-03-09T15:39:55Z        NaN
# 4  2026-03-09T15:34:41Z        NaN
#
#                                           references   rightsHolder type  ...  \
# 0  https://www.inaturalist.org/observations/34620...    Exner Tamás  NaN  ...
# 1  https://www.inaturalist.org/observations/34620...    Exner Tamás  NaN  ...
# 2  https://www.inaturalist.org/observations/22008...  Sílvia Castro  NaN  ...
# 3  https://www.inaturalist.org/observations/28273...         ruv321  NaN  ...
# 4  https://www.inaturalist.org/observations/28639...         ruv321  NaN  ...
#
#   publishedByGbifRegion level0Gid  level0Name level1Gid level1Name  \
# 0         NORTH_AMERICA       PRT    Portugal  PRT.17_1    Setúbal
# 1         NORTH_AMERICA       PRT    Portugal  PRT.17_1    Setúbal
# 2         NORTH_AMERICA       PRT    Portugal   PRT.7_1    Coimbra
# 3                EUROPE       PRT    Portugal  PRT.17_1    Setúbal
# 4                EUROPE       PRT    Portugal  PRT.17_1    Setúbal
#
#      level2Gid       level2Name      level3Gid          level3Name  \
# 0  PRT.17.12_1          Setúbal  PRT.17.12.3_1        São Lourenço
# 1  PRT.17.11_1         Sesimbra  PRT.17.11.2_1  Sesimbra (Castelo)
# 2    PRT.7.4_1  Condeixa-a-Nova    PRT.7.4.7_1           Furadouro
# 3  PRT.17.11_1         Sesimbra  PRT.17.11.2_1  Sesimbra (Castelo)
# 4  PRT.17.11_1         Sesimbra  PRT.17.11.2_1  Sesimbra (Castelo)
#
#   iucnRedListCategory
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (283, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (283, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (283, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (283, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (283, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (163, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (156, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (156, 12)
#        gbifID       species  decimalLatitude  decimalLongitude countryCode  \
# 0  6195949741  Thymus zygis        38.505000         -9.015000          PT
# 1  6195226949  Thymus zygis        38.425000         -9.215000          PT
# 2  6188074775  Thymus zygis        40.054587         -8.496657          PT
# 3  6179058480  Thymus zygis        38.436410         -9.179349          PT
# 4  6179002508  Thymus zygis        38.438585         -9.172428          PT
#
#            eventDate      basisOfRecord  coordinateUncertaintyInMeters  year  \
# 0  2026-03-28T12:11Z  HUMAN_OBSERVATION                            NaN  2026
# 1  2026-03-24T14:03Z  HUMAN_OBSERVATION                            NaN  2026
# 2   2020-05-24T08:46  HUMAN_OBSERVATION                           31.0  2020
# 3   2025-05-17T19:00  HUMAN_OBSERVATION                            NaN  2025
# 4   2025-03-31T13:27  HUMAN_OBSERVATION                            NaN  2025
#
#    month   day                   geometry
# 0    3.0  28.0      POINT (-9.015 38.505)
# 1    3.0  24.0      POINT (-9.215 38.425)
# 2    5.0  24.0  POINT (-8.49666 40.05459)
# 3    5.0  17.0  POINT (-9.17935 38.43641)
# 4    3.0  31.0  POINT (-9.17243 38.43858)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Thymus_zygis

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Thymus_zygis/Thymus_zygis.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Thymus_zygis/Thymus_zygis.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Thymus_zygis/Thymus_zygis.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Thymus_zygis/Thymus_zygis.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Thymus_zygis
# Records: 156
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Thymus_zygis/Thymus_zygis.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Thymus_zygis/Thymus_zygis.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Thymus_zygis/Thymus_zygis.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Thymus_zygis/Thymus_zygis.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_663e6432ff15acfdc97f97298f69056b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_663e6432ff15acfdc97f97298f69056b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_663e6432ff15acfdc97f97298f69056b = L.map(
#                 &quot;map_663e6432ff15acfdc97f97298f69056b&quot;,
#                 {
#                     center: [39.65033937179487, -8.37218223076923],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48c784dca1bef53167a03ea37e920f41 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48c784dca1bef53167a03ea37e920f41.addTo(map_663e6432ff15acfdc97f97298f69056b);
#
#
#             var marker_cluster_39bf9edb4dae77384ed474532a1ebaec = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_f86d8a3e3158b81d7f826ec9f1754676 = L.circleMarker(
#                 [38.505, -9.015],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_39bf9edb4dae77384ed474532a1ebaec);
#
#
#         var popup_074356b4c8bee07a93a4d6c99bef5888 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_742f0f19ee5be8adb19f9abdefb12bba = $(`&lt;div id=&quot;html_742f0f19ee5be8adb19f9abdefb12bba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6195949741&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Thymus zygis&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-03-28T12:11Z&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; nan     &lt;/div&gt;`)[0];
#                 popup_074356b4c8bee07a93a4d6c99bef5888.setContent(html_742f0f19ee5be8adb19f9abdefb12bba);
#
#
#
#         circle_marker_f86d8a3e3158b81d7f826ec9f1754676.bindPopup(popup_074356b4c8bee07a93a4d6c99bef5888)
#         ;
#
#
#
#
#             var circle_marker_bec50d772b8b87508f36d3273c731f94 = L.circleMarker(
#                 [38.425, -9.215],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_39bf9edb4dae77384ed474532a1ebaec);
#
#
#         var popup_daf4e6128f079fb4cd64670af4fa9083 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_6c7653f8302f454a853553ebff000ce0 = $(`&lt;div id=&quot;html_6c7653f8302f454a853553ebff000ce0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6195226949&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Thymus zygis&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-03-24T14:03Z&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; nan     &lt;/div&gt;`)[0];
#                 popup_daf4e6128f079fb4cd64670af4fa9083.setContent(html_6c7653f8302f454a853553ebff000ce0);
#
#
#
#         circle_marker_bec50d772b8b87508f36d3273c731f94.bindPopup(popup_daf4e6128f079fb4cd64670af4fa9083)
#         ;
#
#
#
#
#             var circle_marker_978680e94370274fce292817fcde76d6 = L.circleMarker(
#                 [40.054587, -8.496657],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&q

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 156

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 156

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b64aed5e171110ecaf642951e6e523a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b64aed5e171110ecaf642951e6e523a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b64aed5e171110ecaf642951e6e523a5 = L.map(
#                 &quot;map_b64aed5e171110ecaf642951e6e523a5&quot;,
#                 {
#                     center: [39.65033937179487, -8.37218223076923],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bbd52e9d929cc2478c9a3e6ce8ee9860 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bbd52e9d929cc2478c9a3e6ce8ee9860.addTo(map_b64aed5e171110ecaf642951e6e523a5);
#
#
#             var circle_marker_e096e7f376ee8ad8d7767f26f7d6fdc3 = L.circleMarker(
#                 [38.505, -9.015],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b64aed5e171110ecaf642951e6e523a5);
#
#
#         var popup_f7ebed474d17bfeafbb47a39843ff389 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2472d56e065036f6fad65c806ee289a5 = $(`&lt;div id=&quot;html_2472d56e065036f6fad65c806ee289a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6195949741&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Thymus zygis&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_f7ebed474d17bfeafbb47a39843ff389.setContent(html_2472d56e065036f6fad65c806ee289a5);
#
#
#
#         circle_marker_e096e7f376ee8ad8d7767f26f7d6fdc3.bindPopup(popup_f7ebed474d17bfeafbb47a39843ff389)
#         ;
#
#
#
#
#             var circle_marker_189177a3945bf9bf03e3633d332a612f = L.circleMarker(
#                 [38.425, -9.215],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b64aed5e171110ecaf642951e6e523a5);
#
#
#         var popup_7c038bd959434b0db0cae06dac5cc2f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_333e337c4afb03ec50f101710c1b1158 = $(`&lt;div id=&quot;html_333e337c4afb03ec50f101710c1b1158&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6195226949&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Thymus zygis&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_7c038bd959434b0db0cae06dac5cc2f8.setContent(html_333e337c4afb03ec50f101710c1b1158);
#
#
#
#         circle_marker_189177a3945bf9bf03e3633d332a612f.bindPopup(popup_7c038bd959434b0db0cae06dac5cc2f8)
#         ;
#
#
#
#
#             var circle_marker_d50b23a1db5b30d9ea77e4955d46732f = L.circleMarker(
#                 [40.054587, -8.496657],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b64aed5e171110ecaf642951e6e523a5);
#
#
#         var popup_8916e583e1ce820947b31b145ea9a508 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27c0a6fe2eb474574d2fea2789ec56c9 = $(`&lt;div id=&quot;html_27c0a6fe2eb474574d2fea2789ec56c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6188074775&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Thymus z

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Thymus_zygis/Thymus_zygis_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Thymus_zygis/Thymus_zygis_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Thymus_zygis/Thymus_zygis_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID       species  decimalLatitude  decimalLongitude countryCode  \
# 0  6195949741  Thymus zygis        38.505000         -9.015000          PT
# 1  6195226949  Thymus zygis        38.425000         -9.215000          PT
# 2  6188074775  Thymus zygis        40.054587         -8.496657          PT
# 3  6179058480  Thymus zygis        38.436410         -9.179349          PT
# 4  6179002508  Thymus zygis        38.438585         -9.172428          PT
#
#            eventDate      basisOfRecord  coordinateUncertaintyInMeters  year  \
# 0  2026-03-28T12:11Z  HUMAN_OBSERVATION                            NaN  2026
# 1  2026-03-24T14:03Z  HUMAN_OBSERVATION                            NaN  2026
# 2   2020-05-24T08:46  HUMAN_OBSERVATION                           31.0  2020
# 3   2025-05-17T19:00  HUMAN_OBSERVATION                            NaN  2025
# 4   2025-03-31T13:27  HUMAN_OBSERVATION                            NaN  2025
#
#    month   day                   geometry
# 0    3.0  28.0      POINT (-9.015 38.505)
# 1    3.0  24.0      POINT (-9.215 38.425)
# 2    5.0  24.0  POINT (-8.49666 40.05459)
# 3    5.0  17.0  POINT (-9.17935 38.43641)
# 4    3.0  31.0  POINT (-9.17243 38.43858)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count      80.000000
# mean      147.237500
# std       416.726552
# min         1.000000
# 25%         5.000000
# 50%         8.000000
# 75%        30.250000
# max      2501.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 156 original records
# 60 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Thymus_zygis/Thymus_zygis_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="spp_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Thymus_zygis/Thymus_zygis_clean.gpkg

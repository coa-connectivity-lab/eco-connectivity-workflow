# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Lacerta_schreiberi'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Lacerta_schreiberi.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Lacerta_schreiberi

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lacerta_schreiberi/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lacerta_schreiberi/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lacerta_schreiberi/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lacerta_schreiberi/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lacerta_schreiberi/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lacerta_schreiberi/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lacerta_schreiberi/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lacerta_schreiberi/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (1624, 230)
#        gbifID  accessRights  bibliographicCitation  language       license  \
# 0  6352822786           NaN                    NaN       NaN  CC_BY_NC_4_0
# 1  6352779560           NaN                    NaN       NaN  CC_BY_NC_4_0
# 2  6352677387           NaN                    NaN       NaN  CC_BY_NC_4_0
# 3  6352552560           NaN                    NaN       NaN  CC_BY_NC_4_0
# 4  6352541748           NaN                    NaN       NaN  CC_BY_NC_4_0
#
#                modified  publisher  \
# 0  2026-05-29T13:52:00Z        NaN
# 1  2026-05-30T11:18:25Z        NaN
# 2  2026-05-26T06:11:34Z        NaN
# 3  2026-05-31T17:32:31Z        NaN
# 4  2026-05-29T13:51:41Z        NaN
#
#                                           references    rightsHolder type  \
# 0  https://www.inaturalist.org/observations/36629...  ruifilipecosta  NaN
# 1  https://www.inaturalist.org/observations/36631...       leguan123  NaN
# 2  https://www.inaturalist.org/observations/36522...      beija_flor  NaN
# 3  https://www.inaturalist.org/observations/36643...     Jose Filipe  NaN
# 4  https://www.inaturalist.org/observations/36628...       leguan123  NaN
#
#    ... publishedByGbifRegion  level0Gid  level0Name level1Gid      level1Name  \
# 0  ...         NORTH_AMERICA        PRT    Portugal   PRT.4_1           Braga
# 1  ...         NORTH_AMERICA        PRT    Portugal   PRT.1_1          Aveiro
# 2  ...         NORTH_AMERICA        PRT    Portugal   PRT.1_1          Aveiro
# 3  ...         NORTH_AMERICA        PRT    Portugal   PRT.6_1  Castelo Branco
# 4  ...         NORTH_AMERICA        PRT    Portugal   PRT.1_1          Aveiro
#
#     level2Gid            level2Name      level3Gid      level3Name  \
# 0  PRT.4.10_1       Terras de Bouro  PRT.4.10.17_1  Vilar Da Veiga
# 1   PRT.1.4_1                Arouca   PRT.1.4.14_1          Moldes
# 2  PRT.1.11_1               Murtosa   PRT.1.11.1_1        Bunheiro
# 3  PRT.6.10_1           Vila de Rei   PRT.6.10.3_1     Vila De Rei
# 4  PRT.1.15_1  Santa Maria da Feira  PRT.1.15.12_1           Lobão
#
#   iucnRedListCategory
# 0                  LC
# 1                  LC
# 2                  LC
# 3                  LC
# 4                  LC
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (1624, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (1624, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (1624, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (1624, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (1624, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (1436, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (1066, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (1066, 12)
#        gbifID             species  decimalLatitude  decimalLongitude  \
# 0  6352822786  Lacerta schreiberi        41.715600         -8.152982
# 1  6352779560  Lacerta schreiberi        40.899222         -8.224253
# 2  6352677387  Lacerta schreiberi        40.754471         -8.653314
# 3  6352552560  Lacerta schreiberi        39.628267         -8.165472
# 4  6352541748  Lacerta schreiberi        40.989508         -8.500533
#
#   countryCode            eventDate      basisOfRecord  \
# 0          PT  2026-04-04T15:23:15  HUMAN_OBSERVATION
# 1          PT  2026-05-29T13:07:31  HUMAN_OBSERVATION
# 2          PT     2026-05-06T11:01  HUMAN_OBSERVATION
# 3          PT  2026-05-16T16:34:24  HUMAN_OBSERVATION
# 4          PT  2026-05-29T10:56:31  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month   day                   geometry
# 0                            4.0  2026    4.0   4.0   POINT (-8.15298 41.7156)
# 1                            4.0  2026    5.0  29.0  POINT (-8.22425 40.89922)
# 2                          296.0  2026    5.0   6.0  POINT (-8.65331 40.75447)
# 3                            9.0  2026    5.0  16.0  POINT (-8.16547 39.62827)
# 4                           10.0  2026    5.0  29.0  POINT (-8.50053 40.98951)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Lacerta_schreiberi

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Lacerta_schreiberi/Lacerta_schreiberi.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Lacerta_schreiberi/Lacerta_schreiberi.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Lacerta_schreiberi/Lacerta_schreiberi.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Lacerta_schreiberi/Lacerta_schreiberi.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Lacerta_schreiberi
# Records: 1066
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Lacerta_schreiberi/Lacerta_schreiberi.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Lacerta_schreiberi/Lacerta_schreiberi.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Lacerta_schreiberi/Lacerta_schreiberi.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Lacerta_schreiberi/Lacerta_schreiberi.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_978d099f6942f598a9a5a750d6016792 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_978d099f6942f598a9a5a750d6016792&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_978d099f6942f598a9a5a750d6016792 = L.map(
#                 &quot;map_978d099f6942f598a9a5a750d6016792&quot;,
#                 {
#                     center: [40.89874021013132, -8.171112793621013],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_456d3441b25485e11e508da3307879a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_456d3441b25485e11e508da3307879a4.addTo(map_978d099f6942f598a9a5a750d6016792);
#
#
#             var marker_cluster_7112f0d71fe4ea303f9232c7e325a84e = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_4d3c75244ff121c047230e4bc3b57e47 = L.circleMarker(
#                 [41.7156, -8.152982],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_7112f0d71fe4ea303f9232c7e325a84e);
#
#
#         var popup_dfa224313374578169acb40814a42588 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_cd79142ff6d21dc6069997c80ddff783 = $(`&lt;div id=&quot;html_cd79142ff6d21dc6069997c80ddff783&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6352822786&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Lacerta schreiberi&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-04-04T15:23:15&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 4.0     &lt;/div&gt;`)[0];
#                 popup_dfa224313374578169acb40814a42588.setContent(html_cd79142ff6d21dc6069997c80ddff783);
#
#
#
#         circle_marker_4d3c75244ff121c047230e4bc3b57e47.bindPopup(popup_dfa224313374578169acb40814a42588)
#         ;
#
#
#
#
#             var circle_marker_a81a4201ab5bef18ad3b8fa82140813c = L.circleMarker(
#                 [40.899222, -8.224253],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_7112f0d71fe4ea303f9232c7e325a84e);
#
#
#         var popup_00bfa76fc5101d64ab836029894a316d = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_d0a270be5e9a2bcc93231795627f69e6 = $(`&lt;div id=&quot;html_d0a270be5e9a2bcc93231795627f69e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6352779560&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Lacerta schreiberi&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-05-29T13:07:31&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 4.0     &lt;/div&gt;`)[0];
#                 popup_00bfa76fc5101d64ab836029894a316d.setContent(html_d0a270be5e9a2bcc93231795627f69e6);
#
#
#
#         circle_marker_a81a4201ab5bef18ad3b8fa82140813c.bindPopup(popup_00bfa76fc5101d64ab836029894a316d)
#         ;
#
#
#
#
#             var circle_marker_180a76f8e8d31aa81ae7b72f2b7456ae = L.circleMarker(
#                 [40.754471, -8.653314],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffse

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 1066

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 1066

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb677877a5da4eb97ba5b84155968f49 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb677877a5da4eb97ba5b84155968f49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb677877a5da4eb97ba5b84155968f49 = L.map(
#                 &quot;map_bb677877a5da4eb97ba5b84155968f49&quot;,
#                 {
#                     center: [40.89874021013132, -8.171112793621013],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a08788904c42008ffb831e885944d40e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a08788904c42008ffb831e885944d40e.addTo(map_bb677877a5da4eb97ba5b84155968f49);
#
#
#             var circle_marker_4ed5ae1f306f77780af592f945da3db8 = L.circleMarker(
#                 [41.7156, -8.152982],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bb677877a5da4eb97ba5b84155968f49);
#
#
#         var popup_c48a3e2176b994f081a530222caefd01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f83d219384e6f9270911c9285f61808 = $(`&lt;div id=&quot;html_7f83d219384e6f9270911c9285f61808&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6352822786&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Lacerta schreiberi&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_c48a3e2176b994f081a530222caefd01.setContent(html_7f83d219384e6f9270911c9285f61808);
#
#
#
#         circle_marker_4ed5ae1f306f77780af592f945da3db8.bindPopup(popup_c48a3e2176b994f081a530222caefd01)
#         ;
#
#
#
#
#             var circle_marker_a33745dc57e497d4568d53308384812e = L.circleMarker(
#                 [40.899222, -8.224253],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bb677877a5da4eb97ba5b84155968f49);
#
#
#         var popup_c0659a269b9377e21a2f280b7899afce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d21a2fb808b1741820d945a7556a67c = $(`&lt;div id=&quot;html_8d21a2fb808b1741820d945a7556a67c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6352779560&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Lacerta schreiberi&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_c0659a269b9377e21a2f280b7899afce.setContent(html_8d21a2fb808b1741820d945a7556a67c);
#
#
#
#         circle_marker_a33745dc57e497d4568d53308384812e.bindPopup(popup_c0659a269b9377e21a2f280b7899afce)
#         ;
#
#
#
#
#             var circle_marker_ddcc6e34a804b2e9064696201e474e1f = L.circleMarker(
#                 [40.754471, -8.653314],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bb677877a5da4eb97ba5b84155968f49);
#
#
#         var popup_42908bf767ee3396fbffa4eb3a318149 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0250db67ec41566855dc7bc7429b8bd7 = $(`&lt;div id=&quot;html_0250db67ec41566855dc7bc7429b8bd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6352677387&lt;br&gt;     &lt;b&gt;Spec

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Lacerta_schreiberi/Lacerta_schreiberi_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Lacerta_schreiberi/Lacerta_schreiberi_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Lacerta_schreiberi/Lacerta_schreiberi_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID             species  decimalLatitude  decimalLongitude  \
# 0  6352822786  Lacerta schreiberi        41.715600         -8.152982
# 1  6352779560  Lacerta schreiberi        40.899222         -8.224253
# 2  6352677387  Lacerta schreiberi        40.754471         -8.653314
# 3  6352552560  Lacerta schreiberi        39.628267         -8.165472
# 4  6352541748  Lacerta schreiberi        40.989508         -8.500533
#
#   countryCode            eventDate      basisOfRecord  \
# 0          PT  2026-04-04T15:23:15  HUMAN_OBSERVATION
# 1          PT  2026-05-29T13:07:31  HUMAN_OBSERVATION
# 2          PT     2026-05-06T11:01  HUMAN_OBSERVATION
# 3          PT  2026-05-16T16:34:24  HUMAN_OBSERVATION
# 4          PT  2026-05-29T10:56:31  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month   day                   geometry
# 0                            4.0  2026    4.0   4.0   POINT (-8.15298 41.7156)
# 1                            4.0  2026    5.0  29.0  POINT (-8.22425 40.89922)
# 2                          296.0  2026    5.0   6.0  POINT (-8.65331 40.75447)
# 3                            9.0  2026    5.0  16.0  POINT (-8.16547 39.62827)
# 4                           10.0  2026    5.0  29.0  POINT (-8.50053 40.98951)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count     924.000000
# mean      229.863636
# std       609.460252
# min         1.000000
# 25%        10.000000
# 50%        30.000000
# 75%        83.000000
# max      4471.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 1066 original records
# 612 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Lacerta_schreiberi/Lacerta_schreiberi_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="spp_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Lacerta_schreiberi/Lacerta_schreiberi_clean.gpkg

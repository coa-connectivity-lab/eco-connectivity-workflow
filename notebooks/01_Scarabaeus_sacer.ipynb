# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Scarabaeus_sacer'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Scarabaeus_sacer.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Scarabaeus_sacer

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Scarabaeus_sacer/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Scarabaeus_sacer/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Scarabaeus_sacer/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Scarabaeus_sacer/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Scarabaeus_sacer/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Scarabaeus_sacer/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Scarabaeus_sacer/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Scarabaeus_sacer/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (17, 230)
#        gbifID  accessRights  bibliographicCitation  language       license  \
# 0  5843938458           NaN                    NaN       NaN  CC_BY_NC_4_0
# 1  5023809429           NaN                    NaN       NaN     CC_BY_4_0
# 2  5014787128           NaN                    NaN       NaN     CC_BY_4_0
# 3  4952572833           NaN                    NaN       NaN  CC_BY_NC_4_0
# 4  4886014074           NaN                    NaN       NaN  CC_BY_NC_4_0
#
#                modified  publisher  \
# 0  2025-10-13T07:30:48Z        NaN
# 1                   NaN        NaN
# 2                   NaN        NaN
# 3  2025-06-05T01:43:09Z        NaN
# 4  2024-02-17T10:02:00Z        NaN
#
#                                           references  \
# 0  https://www.inaturalist.org/observations/24415...
# 1  https://enjoynature.net/?gebiet=770225184&datu...
# 2  https://enjoynature.net/?gebiet=1703483723&dat...
# 3  https://www.inaturalist.org/observations/24527...
# 4                                                NaN
#
#                           rightsHolder  type  ...  publishedByGbifRegion  \
# 0                          Zhaoqi Leng   NaN  ...          NORTH_AMERICA
# 1                                  NaN   NaN  ...                 EUROPE
# 2                                  NaN   NaN  ...                 EUROPE
# 3                           moritzomer   NaN  ...          NORTH_AMERICA
# 4  Stichting Observation International   NaN  ...                 EUROPE
#
#    level0Gid  level0Name level1Gid      level1Name    level2Gid  \
# 0        PRT    Portugal   PRT.9_1            Faro   PRT.9.15_1
# 1        PRT    Portugal   PRT.9_1            Faro    PRT.9.3_1
# 2        PRT    Portugal  PRT.14_1      Portalegre   PRT.14.5_1
# 3        PRT    Portugal   PRT.6_1  Castelo Branco    PRT.6.2_1
# 4        PRT    Portugal  PRT.10_1          Guarda  PRT.10.10_1
#
#         level2Name      level3Gid             level3Name  iucnRedListCategory
# 0    Vila do Bispo   PRT.9.15.4_1                 Sagres                  NaN
# 1          Aljezur    PRT.9.3.3_1               Odeceixe                  NaN
# 2  Castelo de Vide   PRT.14.5.2_1  Santa Maria Da Devesa                  NaN
# 3   Castelo Branco   PRT.6.2.14_1        Malpica Do Tejo                  NaN
# 4           Pinhel  PRT.10.10.7_1              Cidadelhe                  NaN
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (17, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (17, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (17, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (17, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (17, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (17, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (15, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (15, 12)
#        gbifID           species  decimalLatitude  decimalLongitude  \
# 0  5843938458  Scarabaeus sacer        37.040239         -8.956614
# 1  5023809429  Scarabaeus sacer        37.401699         -8.739562
# 2  5014787128  Scarabaeus sacer        39.399590         -7.423325
# 3  4952572833  Scarabaeus sacer        39.699804         -7.313682
# 4  4886014074  Scarabaeus sacer        40.929489         -7.098156
#
#   countryCode            eventDate      basisOfRecord  \
# 0          PT     2024-09-26T13:31  HUMAN_OBSERVATION
# 1          PT     2022-05-03T00:00  HUMAN_OBSERVATION
# 2          PT     2011-04-18T00:00  HUMAN_OBSERVATION
# 3          PT  2024-10-01T12:14:57  HUMAN_OBSERVATION
# 4          PT           2011-05-24  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month  day                   geometry
# 0                          122.0  2024      9   26  POINT (-8.95661 37.04024)
# 1                          250.0  2022      5    3   POINT (-8.73956 37.4017)
# 2                          250.0  2011      4   18  POINT (-7.42332 39.39959)
# 3                          143.0  2024     10    1   POINT (-7.31368 39.6998)
# 4                            NaN  2011      5   24  POINT (-7.09816 40.92949)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Scarabaeus_sacer

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Scarabaeus_sacer/Scarabaeus_sacer.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Scarabaeus_sacer/Scarabaeus_sacer.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Scarabaeus_sacer/Scarabaeus_sacer.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Scarabaeus_sacer/Scarabaeus_sacer.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Scarabaeus_sacer
# Records: 15
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Scarabaeus_sacer/Scarabaeus_sacer.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Scarabaeus_sacer/Scarabaeus_sacer.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Scarabaeus_sacer/Scarabaeus_sacer.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Scarabaeus_sacer/Scarabaeus_sacer.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1be32af3d9f57073a6557f088a326eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1be32af3d9f57073a6557f088a326eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1be32af3d9f57073a6557f088a326eb = L.map(
#                 &quot;map_c1be32af3d9f57073a6557f088a326eb&quot;,
#                 {
#                     center: [39.2244198, -7.774103866666666],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be9f538372d37def4da742d0630a6ddf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be9f538372d37def4da742d0630a6ddf.addTo(map_c1be32af3d9f57073a6557f088a326eb);
#
#
#             var marker_cluster_22c1ee5db04311922084bd8bd7864ac2 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_f1ac34be2196ecdcb43c0cf3a655bbc1 = L.circleMarker(
#                 [37.040239, -8.956614],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_22c1ee5db04311922084bd8bd7864ac2);
#
#
#         var popup_1d2374b2f518235b9702e33e2dc62f8b = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_1b11efb5c4ffb3d1b93fe80e0a7d10d6 = $(`&lt;div id=&quot;html_1b11efb5c4ffb3d1b93fe80e0a7d10d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5843938458&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Scarabaeus sacer&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2024-09-26T13:31&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 122.0     &lt;/div&gt;`)[0];
#                 popup_1d2374b2f518235b9702e33e2dc62f8b.setContent(html_1b11efb5c4ffb3d1b93fe80e0a7d10d6);
#
#
#
#         circle_marker_f1ac34be2196ecdcb43c0cf3a655bbc1.bindPopup(popup_1d2374b2f518235b9702e33e2dc62f8b)
#         ;
#
#
#
#
#             var circle_marker_51c6a4aab99f48ad9e9ce3cbe85f50cd = L.circleMarker(
#                 [37.401699, -8.739562],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_22c1ee5db04311922084bd8bd7864ac2);
#
#
#         var popup_f456c00ddf3d623bd1577b6fe781aa09 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_027af58b8ddb883ac16af3f20065d14f = $(`&lt;div id=&quot;html_027af58b8ddb883ac16af3f20065d14f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5023809429&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Scarabaeus sacer&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2022-05-03T00:00&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 250.0     &lt;/div&gt;`)[0];
#                 popup_f456c00ddf3d623bd1577b6fe781aa09.setContent(html_027af58b8ddb883ac16af3f20065d14f);
#
#
#
#         circle_marker_51c6a4aab99f48ad9e9ce3cbe85f50cd.bindPopup(popup_f456c00ddf3d623bd1577b6fe781aa09)
#         ;
#
#
#
#
#             var circle_marker_d6faf6553df10a46a1f89a0a4d51d288 = L.circleMarker(
#                 [39.39959, -7.423325],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: nul

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 15

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 15

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e5a4c9a438a5fb1c40021b30ec4f052 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e5a4c9a438a5fb1c40021b30ec4f052&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e5a4c9a438a5fb1c40021b30ec4f052 = L.map(
#                 &quot;map_3e5a4c9a438a5fb1c40021b30ec4f052&quot;,
#                 {
#                     center: [39.2244198, -7.774103866666666],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c25f2c607a2d7ed30abaafdbe07895e2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c25f2c607a2d7ed30abaafdbe07895e2.addTo(map_3e5a4c9a438a5fb1c40021b30ec4f052);
#
#
#             var circle_marker_8927d2b06d0c09cdc91ab4db5430cf53 = L.circleMarker(
#                 [37.040239, -8.956614],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3e5a4c9a438a5fb1c40021b30ec4f052);
#
#
#         var popup_173c5df190c7a7bcd8a1de46a6b6dfb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbe1d67cd8de064bddaa68cf038d8baf = $(`&lt;div id=&quot;html_cbe1d67cd8de064bddaa68cf038d8baf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5843938458&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Scarabaeus sacer&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_173c5df190c7a7bcd8a1de46a6b6dfb5.setContent(html_cbe1d67cd8de064bddaa68cf038d8baf);
#
#
#
#         circle_marker_8927d2b06d0c09cdc91ab4db5430cf53.bindPopup(popup_173c5df190c7a7bcd8a1de46a6b6dfb5)
#         ;
#
#
#
#
#             var circle_marker_9f4c70b67a59ded562b03866fedc8fa9 = L.circleMarker(
#                 [37.401699, -8.739562],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3e5a4c9a438a5fb1c40021b30ec4f052);
#
#
#         var popup_8cf8b9f3f44831ec0e632f7147fee6cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f3ba0cd69e0ea6ab72a84e8e94390fc = $(`&lt;div id=&quot;html_1f3ba0cd69e0ea6ab72a84e8e94390fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5023809429&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Scarabaeus sacer&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_8cf8b9f3f44831ec0e632f7147fee6cb.setContent(html_1f3ba0cd69e0ea6ab72a84e8e94390fc);
#
#
#
#         circle_marker_9f4c70b67a59ded562b03866fedc8fa9.bindPopup(popup_8cf8b9f3f44831ec0e632f7147fee6cb)
#         ;
#
#
#
#
#             var circle_marker_26d9fb66b93244468a5aa8b88f7246ce = L.circleMarker(
#                 [39.39959, -7.423325],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3e5a4c9a438a5fb1c40021b30ec4f052);
#
#
#         var popup_10620e1ce1480bc405e1650f6b80413c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_200fe2285147c1cd28f0b2b36ddffb4a = $(`&lt;div id=&quot;html_200fe2285147c1cd28f0b2b36ddffb4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5014787128&lt;br&gt;     &lt;b&gt;Species:&lt;/b

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Scarabaeus_sacer/Scarabaeus_sacer_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Scarabaeus_sacer/Scarabaeus_sacer_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Scarabaeus_sacer/Scarabaeus_sacer_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID           species  decimalLatitude  decimalLongitude  \
# 0  5843938458  Scarabaeus sacer        37.040239         -8.956614
# 1  5023809429  Scarabaeus sacer        37.401699         -8.739562
# 2  5014787128  Scarabaeus sacer        39.399590         -7.423325
# 3  4952572833  Scarabaeus sacer        39.699804         -7.313682
# 4  4886014074  Scarabaeus sacer        40.929489         -7.098156
#
#   countryCode           eventDate      basisOfRecord  \
# 0          PT 2024-09-26 13:31:00  HUMAN_OBSERVATION
# 1          PT 2022-05-03 00:00:00  HUMAN_OBSERVATION
# 2          PT 2011-04-18 00:00:00  HUMAN_OBSERVATION
# 3          PT 2024-10-01 12:14:57  HUMAN_OBSERVATION
# 4          PT 2011-05-24 00:00:00  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month  day                   geometry
# 0                          122.0  2024      9   26  POINT (-8.95661 37.04024)
# 1                          250.0  2022      5    3   POINT (-8.73956 37.4017)
# 2                          250.0  2011      4   18  POINT (-7.42332 39.39959)
# 3                          143.0  2024     10    1   POINT (-7.31368 39.6998)
# 4                            NaN  2011      5   24  POINT (-7.09816 40.92949)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count      11.000000
# mean      254.818182
# std       414.891749
# min         4.000000
# 25%        18.500000
# 50%       122.000000
# 75%       250.000000
# max      1440.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 15 original records
# 3 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Scarabaeus_sacer/Scarabaeus_sacer_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="spp_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Scarabaeus_sacer/Scarabaeus_sacer_clean.gpkg

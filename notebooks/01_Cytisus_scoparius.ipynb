# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Cytisus_scoparius'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Cytisus_scoparius.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Cytisus_scoparius

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Cytisus_scoparius/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Cytisus_scoparius/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Cytisus_scoparius/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Cytisus_scoparius/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Cytisus_scoparius/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Cytisus_scoparius/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Cytisus_scoparius/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Cytisus_scoparius/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (1379, 230)
#        gbifID  accessRights  bibliographicCitation language       license  \
# 0  6236521344           NaN                    NaN      NaN  CC_BY_NC_4_0
# 1  6235360742           NaN                    NaN      NaN  CC_BY_NC_4_0
# 2  6234269212           NaN                    NaN      NaN  CC_BY_NC_4_0
# 3  6234190588           NaN                    NaN      NaN  CC_BY_NC_4_0
# 4  6195983629           NaN                    NaN      NaN  CC_BY_NC_4_0
#
#                modified  publisher  \
# 0  2026-04-26T21:21:17Z        NaN
# 1  2026-04-27T12:51:24Z        NaN
# 2  2026-04-17T17:41:44Z        NaN
# 3  2026-04-20T06:11:38Z        NaN
# 4  2026-04-12T10:28:40Z        NaN
#
#                                           references      rightsHolder type  \
# 0  https://www.inaturalist.org/observations/35426...      Ana Oliveira  NaN
# 1  https://www.inaturalist.org/observations/35446...  Rodrigo Oliveira  NaN
# 2  https://www.inaturalist.org/observations/35050...  Fátima Fernandes  NaN
# 3  https://www.inaturalist.org/observations/35127...   Rafael Carvalho  NaN
# 4  https://www.inaturalist.org/observations/34895...        João Botto  NaN
#
#    ... publishedByGbifRegion level0Gid  level0Name level1Gid level1Name  \
# 0  ...                EUROPE       PRT    Portugal   PRT.4_1      Braga
# 1  ...         NORTH_AMERICA       PRT    Portugal   PRT.4_1      Braga
# 2  ...                EUROPE       PRT    Portugal   PRT.7_1    Coimbra
# 3  ...         NORTH_AMERICA       PRT    Portugal  PRT.20_1      Viseu
# 4  ...         NORTH_AMERICA       PRT    Portugal  PRT.20_1      Viseu
#
#      level2Gid              level2Name      level3Gid        level3Name  \
# 0   PRT.4.12_1  Vila Nova de Famalicão  PRT.4.12.29_1              Nine
# 1    PRT.4.8_1               Guimarães    PRT.4.8.1_1            Abação
# 2    PRT.7.3_1                 Coimbra   PRT.7.3.19_1       Santa Clara
# 3  PRT.20.20_1                 Tarouca  PRT.20.20.5_1          Salzedas
# 4  PRT.20.15_1   São João da Pesqueira  PRT.20.15.9_1  Soutelo Do Douro
#
#   iucnRedListCategory
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (1379, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (1379, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (1379, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (1379, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (1379, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (1113, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (1094, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (1094, 12)
#        gbifID            species  decimalLatitude  decimalLongitude  \
# 0  6236521344  Cytisus scoparius        41.469144         -8.562592
# 1  6235360742  Cytisus scoparius        41.415122         -8.270736
# 2  6234269212  Cytisus scoparius        40.211983         -8.449201
# 3  6234190588  Cytisus scoparius        41.074502         -7.745150
# 4  6195983629  Cytisus scoparius        41.185710         -7.426562
#
#   countryCode            eventDate      basisOfRecord  \
# 0          PT  2026-04-26T08:51:52  HUMAN_OBSERVATION
# 1          PT  2026-04-26T16:38:54  HUMAN_OBSERVATION
# 2          PT  2026-04-17T13:50:41  HUMAN_OBSERVATION
# 3          PT  2026-04-19T12:30:25  HUMAN_OBSERVATION
# 4          PT     2026-04-05T09:37  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month   day                   geometry
# 0                          138.0  2026    4.0  26.0  POINT (-8.56259 41.46914)
# 1                           24.0  2026    4.0  26.0  POINT (-8.27074 41.41512)
# 2                            8.0  2026    4.0  17.0   POINT (-8.4492 40.21198)
# 3                            NaN  2026    4.0  19.0   POINT (-7.74515 41.0745)
# 4                           15.0  2026    4.0   5.0  POINT (-7.42656 41.18571)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Cytisus_scoparius

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Cytisus_scoparius/Cytisus_scoparius.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Cytisus_scoparius/Cytisus_scoparius.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Cytisus_scoparius/Cytisus_scoparius.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Cytisus_scoparius/Cytisus_scoparius.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Cytisus_scoparius
# Records: 1094
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Cytisus_scoparius/Cytisus_scoparius.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Cytisus_scoparius/Cytisus_scoparius.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Cytisus_scoparius/Cytisus_scoparius.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Cytisus_scoparius/Cytisus_scoparius.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6973fc52180ab65f46b52a99c63b3844 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6973fc52180ab65f46b52a99c63b3844&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6973fc52180ab65f46b52a99c63b3844 = L.map(
#                 &quot;map_6973fc52180ab65f46b52a99c63b3844&quot;,
#                 {
#                     center: [37.035928171846436, -19.320963057586837],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5338c3f7aa6fb5b7041d250a8b5152b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5338c3f7aa6fb5b7041d250a8b5152b3.addTo(map_6973fc52180ab65f46b52a99c63b3844);
#
#
#             var marker_cluster_730e6b3e704cd6ec64e00b07365ce83a = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_63246f6dc247a46347e686ecd87e7547 = L.circleMarker(
#                 [41.469144, -8.562592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_730e6b3e704cd6ec64e00b07365ce83a);
#
#
#         var popup_2e46e14c600b8fd6d0f6a2cd16f369c6 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_337bdc7db271befe1c788a9708d8bc96 = $(`&lt;div id=&quot;html_337bdc7db271befe1c788a9708d8bc96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6236521344&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Cytisus scoparius&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-04-26T08:51:52&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 138.0     &lt;/div&gt;`)[0];
#                 popup_2e46e14c600b8fd6d0f6a2cd16f369c6.setContent(html_337bdc7db271befe1c788a9708d8bc96);
#
#
#
#         circle_marker_63246f6dc247a46347e686ecd87e7547.bindPopup(popup_2e46e14c600b8fd6d0f6a2cd16f369c6)
#         ;
#
#
#
#
#             var circle_marker_d226b23d82c447d198d58b75618bc0a4 = L.circleMarker(
#                 [41.415122, -8.270736],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_730e6b3e704cd6ec64e00b07365ce83a);
#
#
#         var popup_d102a13973a8e01c1e23f9362ccd4390 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_10214b05bea996230e32d9d67ff8f7bd = $(`&lt;div id=&quot;html_10214b05bea996230e32d9d67ff8f7bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6235360742&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Cytisus scoparius&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-04-26T16:38:54&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 24.0     &lt;/div&gt;`)[0];
#                 popup_d102a13973a8e01c1e23f9362ccd4390.setContent(html_10214b05bea996230e32d9d67ff8f7bd);
#
#
#
#         circle_marker_d226b23d82c447d198d58b75618bc0a4.bindPopup(popup_d102a13973a8e01c1e23f9362ccd4390)
#         ;
#
#
#
#
#             var circle_marker_ea0fa67d226b1e7ee5b8cf034786ff32 = L.circleMarker(
#                 [40.211983, -8.449201],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dash

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 1094

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 1094

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08f6c8b67bc538f7f8bf5d0b6fd6e08a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08f6c8b67bc538f7f8bf5d0b6fd6e08a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08f6c8b67bc538f7f8bf5d0b6fd6e08a = L.map(
#                 &quot;map_08f6c8b67bc538f7f8bf5d0b6fd6e08a&quot;,
#                 {
#                     center: [37.035928171846436, -19.320963057586837],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2175b84904162972677aa41d65f0e0e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2175b84904162972677aa41d65f0e0e3.addTo(map_08f6c8b67bc538f7f8bf5d0b6fd6e08a);
#
#
#             var circle_marker_e2483d7ca52ebdb7dfb4e96a05170aca = L.circleMarker(
#                 [41.469144, -8.562592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_08f6c8b67bc538f7f8bf5d0b6fd6e08a);
#
#
#         var popup_7f5d4cf7fba58fc04e2b5a43767e2ddf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b5014f75e9290a3528a37417aeec9f3 = $(`&lt;div id=&quot;html_4b5014f75e9290a3528a37417aeec9f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6236521344&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Cytisus scoparius&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_7f5d4cf7fba58fc04e2b5a43767e2ddf.setContent(html_4b5014f75e9290a3528a37417aeec9f3);
#
#
#
#         circle_marker_e2483d7ca52ebdb7dfb4e96a05170aca.bindPopup(popup_7f5d4cf7fba58fc04e2b5a43767e2ddf)
#         ;
#
#
#
#
#             var circle_marker_37745b23ccb08716a9011753eb032cdd = L.circleMarker(
#                 [41.415122, -8.270736],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_08f6c8b67bc538f7f8bf5d0b6fd6e08a);
#
#
#         var popup_efe7e35e6623c7cd014284164b1d718b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbef3bbc67a4cae3fb6e932169a0937a = $(`&lt;div id=&quot;html_cbef3bbc67a4cae3fb6e932169a0937a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6235360742&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Cytisus scoparius&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_efe7e35e6623c7cd014284164b1d718b.setContent(html_cbef3bbc67a4cae3fb6e932169a0937a);
#
#
#
#         circle_marker_37745b23ccb08716a9011753eb032cdd.bindPopup(popup_efe7e35e6623c7cd014284164b1d718b)
#         ;
#
#
#
#
#             var circle_marker_99e311d603b4a29c46534b4a5643d225 = L.circleMarker(
#                 [40.211983, -8.449201],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_08f6c8b67bc538f7f8bf5d0b6fd6e08a);
#
#
#         var popup_a3aae76561d150d8f9422b09892b2ff6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c586e7b9f8831cb39b5479134d9a4ed2 = $(`&lt;div id=&quot;html_c586e7b9f8831cb39b5479134d9a4ed2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6234269212&lt;br&gt;     &lt;b&gt;Sp

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Cytisus_scoparius/Cytisus_scoparius_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Cytisus_scoparius/Cytisus_scoparius_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Cytisus_scoparius/Cytisus_scoparius_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID            species  decimalLatitude  decimalLongitude  \
# 0  6236521344  Cytisus scoparius        41.469144         -8.562592
# 1  6235360742  Cytisus scoparius        41.415122         -8.270736
# 2  6234269212  Cytisus scoparius        40.211983         -8.449201
# 3  6234190588  Cytisus scoparius        41.074502         -7.745150
# 4  6195983629  Cytisus scoparius        41.185710         -7.426562
#
#   countryCode            eventDate      basisOfRecord  \
# 0          PT  2026-04-26T08:51:52  HUMAN_OBSERVATION
# 1          PT  2026-04-26T16:38:54  HUMAN_OBSERVATION
# 2          PT  2026-04-17T13:50:41  HUMAN_OBSERVATION
# 3          PT  2026-04-19T12:30:25  HUMAN_OBSERVATION
# 4          PT     2026-04-05T09:37  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month   day                   geometry
# 0                          138.0  2026    4.0  26.0  POINT (-8.56259 41.46914)
# 1                           24.0  2026    4.0  26.0  POINT (-8.27074 41.41512)
# 2                            8.0  2026    4.0  17.0   POINT (-8.4492 40.21198)
# 3                            NaN  2026    4.0  19.0   POINT (-7.74515 41.0745)
# 4                           15.0  2026    4.0   5.0  POINT (-7.42656 41.18571)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count     826.000000
# mean      378.996368
# std       421.815133
# min         1.000000
# 25%        25.000000
# 50%       500.000000
# 75%       500.000000
# max      4951.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 1094 original records
# 217 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Cytisus_scoparius/Cytisus_scoparius_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="spp_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Cytisus_scoparius/Cytisus_scoparius_clean.gpkg

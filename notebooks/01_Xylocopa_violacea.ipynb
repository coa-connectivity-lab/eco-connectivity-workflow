# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Xylocopa_violacea'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Xylocopa_violacea.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Xylocopa_violacea

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Xylocopa_violacea/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Xylocopa_violacea/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Xylocopa_violacea/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Xylocopa_violacea/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Xylocopa_violacea/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Xylocopa_violacea/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Xylocopa_violacea/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Xylocopa_violacea/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (1244, 230)
#        gbifID  accessRights  bibliographicCitation language       license  \
# 0   891027200           NaN                    NaN      NaN  CC_BY_NC_4_0
# 1  6236473342           NaN                    NaN      NaN  CC_BY_NC_4_0
# 2  6236220748           NaN                    NaN      NaN  CC_BY_NC_4_0
# 3  6236025652           NaN                    NaN      NaN  CC_BY_NC_4_0
# 4  6235844882           NaN                    NaN      NaN  CC_BY_NC_4_0
#
#                modified  publisher  \
# 0  2024-04-21T10:51:30Z        NaN
# 1  2026-04-27T15:16:57Z        NaN
# 2  2026-04-27T06:29:14Z        NaN
# 3  2026-04-22T07:05:36Z        NaN
# 4  2026-04-27T15:16:57Z        NaN
#
#                                           references  \
# 0    https://www.inaturalist.org/observations/374342
# 1  https://www.inaturalist.org/observations/68924424
# 2  https://www.inaturalist.org/observations/35446...
# 3  https://www.inaturalist.org/observations/35167...
# 4  https://www.inaturalist.org/observations/58249532
#
#                rightsHolder type  ... publishedByGbifRegion  level0Gid  \
# 0  zoe jewell & sky alibhai  NaN  ...         NORTH_AMERICA        PRT
# 1         Américo Guerreiro  NaN  ...                EUROPE        PRT
# 2             Sílvia Castro  NaN  ...                EUROPE        PRT
# 3                     Pedro  NaN  ...                EUROPE        PRT
# 4         Américo Guerreiro  NaN  ...                EUROPE        PRT
#
#   level0Name level1Gid level1Name    level2Gid           level2Name  \
# 0   Portugal   PRT.9_1       Faro    PRT.9.9_1            Monchique
# 1   Portugal  PRT.12_1     Lisboa  PRT.12.16_1  Vila Franca de Xira
# 2   Portugal   PRT.7_1    Coimbra    PRT.7.3_1              Coimbra
# 3   Portugal  PRT.12_1     Lisboa   PRT.12.7_1               Lisboa
# 4   Portugal  PRT.12_1     Lisboa  PRT.12.11_1             Odivelas
#
#        level3Gid               level3Name iucnRedListCategory
# 0    PRT.9.9.3_1                Monchique                 NaN
# 1  PRT.12.16.5_1  Castanheira Do Ribatejo                 NaN
# 2   PRT.7.3.19_1              Santa Clara                 NaN
# 3   PRT.12.7.2_1                Alcântara                 NaN
# 4  PRT.12.11.3_1                 Odivelas                 NaN
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (1244, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (1244, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (1244, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (1244, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (1244, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (1179, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (1140, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (1140, 12)
#        gbifID            species  decimalLatitude  decimalLongitude  \
# 0   891027200  Xylocopa violacea        37.371253         -8.639273
# 1  6236473342  Xylocopa violacea        38.999837         -8.945133
# 2  6236220748  Xylocopa violacea        40.199162         -8.443670
# 3  6236025652  Xylocopa violacea        38.718013         -9.186660
# 4  6235844882  Xylocopa violacea        38.787073         -9.176393
#
#   countryCode            eventDate      basisOfRecord  \
# 0          PT           2013-08-21  HUMAN_OBSERVATION
# 1          PT    2021-01-15T13:56Z  HUMAN_OBSERVATION
# 2          PT  2026-04-19T17:06:59  HUMAN_OBSERVATION
# 3          PT     2026-04-18T10:06  HUMAN_OBSERVATION
# 4          PT     2020-04-11T16:44  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month  day                   geometry
# 0                           20.0  2013      8   21  POINT (-8.63927 37.37125)
# 1                           83.0  2021      1   15  POINT (-8.94513 38.99984)
# 2                            4.0  2026      4   19  POINT (-8.44367 40.19916)
# 3                          288.0  2026      4   18  POINT (-9.18666 38.71801)
# 4                           31.0  2020      4   11  POINT (-9.17639 38.78707)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Xylocopa_violacea

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Xylocopa_violacea/Xylocopa_violacea.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Xylocopa_violacea/Xylocopa_violacea.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Xylocopa_violacea/Xylocopa_violacea.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Xylocopa_violacea/Xylocopa_violacea.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Xylocopa_violacea
# Records: 1140
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Xylocopa_violacea/Xylocopa_violacea.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Xylocopa_violacea/Xylocopa_violacea.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Xylocopa_violacea/Xylocopa_violacea.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Xylocopa_violacea/Xylocopa_violacea.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44ac5520e837c1eace4ea9fce0ecfa72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44ac5520e837c1eace4ea9fce0ecfa72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44ac5520e837c1eace4ea9fce0ecfa72 = L.map(
#                 &quot;map_44ac5520e837c1eace4ea9fce0ecfa72&quot;,
#                 {
#                     center: [38.71333466666667, -8.453188818421053],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03a40384ba1708fda21419a1ee742e8f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_03a40384ba1708fda21419a1ee742e8f.addTo(map_44ac5520e837c1eace4ea9fce0ecfa72);
#
#
#             var marker_cluster_c0477fb222697516710c98b15a4c9a1e = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_f13cb2976e7dcb6b35cfacb086690e18 = L.circleMarker(
#                 [37.371253, -8.639273],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_c0477fb222697516710c98b15a4c9a1e);
#
#
#         var popup_d67d53faaf44426eb8b0afc3753fcfbf = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_1e49b33e9ff2bcad747c33edfc4fc3b3 = $(`&lt;div id=&quot;html_1e49b33e9ff2bcad747c33edfc4fc3b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 891027200&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Xylocopa violacea&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2013-08-21&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 20.0     &lt;/div&gt;`)[0];
#                 popup_d67d53faaf44426eb8b0afc3753fcfbf.setContent(html_1e49b33e9ff2bcad747c33edfc4fc3b3);
#
#
#
#         circle_marker_f13cb2976e7dcb6b35cfacb086690e18.bindPopup(popup_d67d53faaf44426eb8b0afc3753fcfbf)
#         ;
#
#
#
#
#             var circle_marker_153f65ce1b7afd3e311a2ba1cd802dac = L.circleMarker(
#                 [38.999837, -8.945133],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_c0477fb222697516710c98b15a4c9a1e);
#
#
#         var popup_f12f88b03ff72e5a4c5379afb8a85684 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_1293be03feb478799d14b957ecb7708c = $(`&lt;div id=&quot;html_1293be03feb478799d14b957ecb7708c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6236473342&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Xylocopa violacea&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2021-01-15T13:56Z&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 83.0     &lt;/div&gt;`)[0];
#                 popup_f12f88b03ff72e5a4c5379afb8a85684.setContent(html_1293be03feb478799d14b957ecb7708c);
#
#
#
#         circle_marker_153f65ce1b7afd3e311a2ba1cd802dac.bindPopup(popup_f12f88b03ff72e5a4c5379afb8a85684)
#         ;
#
#
#
#
#             var circle_marker_40bba7c55884d6fd1c52e60ae1d6b0cb = L.circleMarker(
#                 [40.199162, -8.44367],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: nu

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 1140

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 1140

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3e01a45c47c129213dd317cdf6b5e9f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3e01a45c47c129213dd317cdf6b5e9f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3e01a45c47c129213dd317cdf6b5e9f = L.map(
#                 &quot;map_b3e01a45c47c129213dd317cdf6b5e9f&quot;,
#                 {
#                     center: [38.71333466666667, -8.453188818421053],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c1bac0f848c2dcdb256c28e8aa74e1e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0c1bac0f848c2dcdb256c28e8aa74e1e.addTo(map_b3e01a45c47c129213dd317cdf6b5e9f);
#
#
#             var circle_marker_dec881f3ddaad27f9d7e7cd718652b71 = L.circleMarker(
#                 [37.371253, -8.639273],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b3e01a45c47c129213dd317cdf6b5e9f);
#
#
#         var popup_21f4999d6dfed8d02d068961c3b47e22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea21ba796f0cadb5bf105f3d6735494e = $(`&lt;div id=&quot;html_ea21ba796f0cadb5bf105f3d6735494e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 891027200&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Xylocopa violacea&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_21f4999d6dfed8d02d068961c3b47e22.setContent(html_ea21ba796f0cadb5bf105f3d6735494e);
#
#
#
#         circle_marker_dec881f3ddaad27f9d7e7cd718652b71.bindPopup(popup_21f4999d6dfed8d02d068961c3b47e22)
#         ;
#
#
#
#
#             var circle_marker_6c0dee8bd376c3e3341b5ff07f23e776 = L.circleMarker(
#                 [38.999837, -8.945133],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b3e01a45c47c129213dd317cdf6b5e9f);
#
#
#         var popup_57e86e9600fcc08639cdc2ea85d06682 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10edd0a2be8f21cce3de69b7edb28e53 = $(`&lt;div id=&quot;html_10edd0a2be8f21cce3de69b7edb28e53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6236473342&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Xylocopa violacea&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_57e86e9600fcc08639cdc2ea85d06682.setContent(html_10edd0a2be8f21cce3de69b7edb28e53);
#
#
#
#         circle_marker_6c0dee8bd376c3e3341b5ff07f23e776.bindPopup(popup_57e86e9600fcc08639cdc2ea85d06682)
#         ;
#
#
#
#
#             var circle_marker_9129d1276272174a2ab5bf58d020aa0c = L.circleMarker(
#                 [40.199162, -8.44367],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b3e01a45c47c129213dd317cdf6b5e9f);
#
#
#         var popup_a76bd61d2fb30d3e9280062717b938bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d797d2c5813b0386c5f16a81aff22df = $(`&lt;div id=&quot;html_8d797d2c5813b0386c5f16a81aff22df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6236220748&lt;br&gt;     &lt;b&gt;Specie

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Xylocopa_violacea/Xylocopa_violacea_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Xylocopa_violacea/Xylocopa_violacea_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Xylocopa_violacea/Xylocopa_violacea_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID            species  decimalLatitude  decimalLongitude  \
# 0   891027200  Xylocopa violacea        37.371253         -8.639273
# 1  6236473342  Xylocopa violacea        38.999837         -8.945133
# 2  6236220748  Xylocopa violacea        40.199162         -8.443670
# 3  6236025652  Xylocopa violacea        38.718013         -9.186660
# 4  6235844882  Xylocopa violacea        38.787073         -9.176393
#
#   countryCode            eventDate      basisOfRecord  \
# 0          PT  2013-08-21T00:00:00  HUMAN_OBSERVATION
# 1          PT  2021-01-15T13:56:00  HUMAN_OBSERVATION
# 2          PT  2026-04-19T17:06:59  HUMAN_OBSERVATION
# 3          PT  2026-04-18T10:06:00  HUMAN_OBSERVATION
# 4          PT  2020-04-11T16:44:00  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month  day                   geometry
# 0                           20.0  2013      8   21  POINT (-8.63927 37.37125)
# 1                           83.0  2021      1   15  POINT (-8.94513 38.99984)
# 2                            4.0  2026      4   19  POINT (-8.44367 40.19916)
# 3                          288.0  2026      4   18  POINT (-9.18666 38.71801)
# 4                           31.0  2020      4   11  POINT (-9.17639 38.78707)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count     878.000000
# mean      259.375854
# std       695.481620
# min         1.000000
# 25%         5.000000
# 50%        20.000000
# 75%       116.000000
# max      4857.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 1140 original records
# 521 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Xylocopa_violacea/Xylocopa_violacea_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="spp_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Xylocopa_violacea/Xylocopa_violacea_clean.gpkg

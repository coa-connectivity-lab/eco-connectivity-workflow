# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Capra_pyrenaica'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Capra_pyrenaica.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Capra_pyrenaica

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capra_pyrenaica/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capra_pyrenaica/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capra_pyrenaica/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capra_pyrenaica/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capra_pyrenaica/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capra_pyrenaica/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capra_pyrenaica/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capra_pyrenaica/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (88, 230)
#        gbifID  accessRights  bibliographicCitation language       license  \
# 0  6195769322           NaN                    NaN      NaN  CC_BY_NC_4_0
# 1  6186070054           NaN                    NaN      NaN  CC_BY_NC_4_0
# 2  6185992967           NaN                    NaN      NaN  CC_BY_NC_4_0
# 3  6185844101           NaN                    NaN      NaN  CC_BY_NC_4_0
# 4  6185774649           NaN                    NaN      NaN  CC_BY_NC_4_0
#
#                modified  publisher  \
# 0  2026-04-12T22:33:40Z        NaN
# 1  2026-03-31T15:57:09Z        NaN
# 2  2026-03-31T15:55:14Z        NaN
# 3  2026-03-31T15:55:51Z        NaN
# 4  2026-03-31T15:49:25Z        NaN
#
#                                           references  \
# 0  https://www.inaturalist.org/observations/34875...
# 1  https://www.inaturalist.org/observations/34620...
# 2  https://www.inaturalist.org/observations/34620...
# 3  https://www.inaturalist.org/observations/34620...
# 4  https://www.inaturalist.org/observations/34620...
#
#                  rightsHolder type  ... publishedByGbifRegion  level0Gid  \
# 0               Diana Correia  NaN  ...         NORTH_AMERICA        NaN
# 1  Gonzalo Mucientes Sandoval  NaN  ...                EUROPE        ESP
# 2  Gonzalo Mucientes Sandoval  NaN  ...                EUROPE        ESP
# 3  Gonzalo Mucientes Sandoval  NaN  ...                EUROPE        ESP
# 4  Gonzalo Mucientes Sandoval  NaN  ...                EUROPE        ESP
#
#    level0Name level1Gid level1Name   level2Gid  level2Name     level3Gid  \
# 0         NaN       NaN        NaN         NaN         NaN           NaN
# 1       Spain  ESP.12_1    Galicia  ESP.12.3_1     Ourense  ESP.12.3.1_1
# 2       Spain  ESP.12_1    Galicia  ESP.12.3_1     Ourense  ESP.12.3.1_1
# 3       Spain  ESP.12_1    Galicia  ESP.12.3_1     Ourense  ESP.12.3.1_1
# 4       Spain  ESP.12_1    Galicia  ESP.12.4_1  Pontevedra  ESP.12.4.1_1
#
#    level3Name  iucnRedListCategory
# 0         NaN                   LC
# 1  n.a. (197)                  NaN
# 2  n.a. (197)                  NaN
# 3  n.a. (197)                  NaN
# 4  n.a. (207)                  NaN
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (88, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (88, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (88, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (88, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (88, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (88, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (12, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (12, 12)
#         gbifID          species  decimalLatitude  decimalLongitude  \
# 35  5197800743  Capra pyrenaica        41.978390         -8.232147
# 46  4995547365  Capra pyrenaica        42.028915         -8.149858
# 55  4460418174  Capra pyrenaica        41.975922         -8.225673
# 62  3804708377  Capra pyrenaica        41.787009         -7.971064
# 63  3804707507  Capra pyrenaica        41.816165         -8.041350
#
#    countryCode   eventDate      basisOfRecord  coordinateUncertaintyInMeters  \
# 35          PT  2025-06-16  HUMAN_OBSERVATION                           50.0
# 46          PT  2024-12-10  HUMAN_OBSERVATION                            3.0
# 55          PT  2023-09-29  HUMAN_OBSERVATION                            NaN
# 62          PT  2020-08-09  HUMAN_OBSERVATION                           50.0
# 63          PT  2021-09-04  HUMAN_OBSERVATION                           50.0
#
#     year  month  day                   geometry
# 35  2025      6   16  POINT (-8.23215 41.97839)
# 46  2024     12   10  POINT (-8.14986 42.02892)
# 55  2023      9   29  POINT (-8.22567 41.97592)
# 62  2020      8    9  POINT (-7.97106 41.78701)
# 63  2021      9    4  POINT (-8.04135 41.81616)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Capra_pyrenaica

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Capra_pyrenaica/Capra_pyrenaica.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Capra_pyrenaica/Capra_pyrenaica.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Capra_pyrenaica/Capra_pyrenaica.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Capra_pyrenaica/Capra_pyrenaica.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Capra_pyrenaica
# Records: 12
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Capra_pyrenaica/Capra_pyrenaica.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Capra_pyrenaica/Capra_pyrenaica.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Capra_pyrenaica/Capra_pyrenaica.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Capra_pyrenaica/Capra_pyrenaica.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f012399cc1743c4e00a728476938258 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f012399cc1743c4e00a728476938258&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f012399cc1743c4e00a728476938258 = L.map(
#                 &quot;map_5f012399cc1743c4e00a728476938258&quot;,
#                 {
#                     center: [41.89533733333334, -8.075939333333332],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c3d308644d4f8a5afefec564230424f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9c3d308644d4f8a5afefec564230424f.addTo(map_5f012399cc1743c4e00a728476938258);
#
#
#             var marker_cluster_a843320310bca99b27b6e0ec9dbee79c = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_cfd78280e9401a05face480983a3df6d = L.circleMarker(
#                 [41.97839, -8.232147],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_a843320310bca99b27b6e0ec9dbee79c);
#
#
#         var popup_accafabf1ad87f7cb120b268d55d8a25 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_5a72bbefe169852a06b11dddf32dcbcd = $(`&lt;div id=&quot;html_5a72bbefe169852a06b11dddf32dcbcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5197800743&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Capra pyrenaica&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2025-06-16&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 50.0     &lt;/div&gt;`)[0];
#                 popup_accafabf1ad87f7cb120b268d55d8a25.setContent(html_5a72bbefe169852a06b11dddf32dcbcd);
#
#
#
#         circle_marker_cfd78280e9401a05face480983a3df6d.bindPopup(popup_accafabf1ad87f7cb120b268d55d8a25)
#         ;
#
#
#
#
#             var circle_marker_032008812bdf66819463adda517f9f03 = L.circleMarker(
#                 [42.028915, -8.149858],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_a843320310bca99b27b6e0ec9dbee79c);
#
#
#         var popup_9337d85f6db07395b876e85e46b9b172 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_ca48689c3d90402362420d4ac248874d = $(`&lt;div id=&quot;html_ca48689c3d90402362420d4ac248874d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 4995547365&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Capra pyrenaica&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2024-12-10&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 3.0     &lt;/div&gt;`)[0];
#                 popup_9337d85f6db07395b876e85e46b9b172.setContent(html_ca48689c3d90402362420d4ac248874d);
#
#
#
#         circle_marker_032008812bdf66819463adda517f9f03.bindPopup(popup_9337d85f6db07395b876e85e46b9b172)
#         ;
#
#
#
#
#             var circle_marker_4778b359f45acc1a912d947628cb3ea9 = L.circleMarker(
#                 [41.975922, -8.225673],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;f

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 12

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 12

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea5e1732e6b70d044f845a4e488255a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea5e1732e6b70d044f845a4e488255a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea5e1732e6b70d044f845a4e488255a5 = L.map(
#                 &quot;map_ea5e1732e6b70d044f845a4e488255a5&quot;,
#                 {
#                     center: [41.89533733333334, -8.075939333333332],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7581d4ab8deb9f169c93db51a974e412 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7581d4ab8deb9f169c93db51a974e412.addTo(map_ea5e1732e6b70d044f845a4e488255a5);
#
#
#             var circle_marker_32036667d7d882bf2dfd525c5b7e60d1 = L.circleMarker(
#                 [41.97839, -8.232147],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea5e1732e6b70d044f845a4e488255a5);
#
#
#         var popup_9aabfaebc2fed05b62e47edafe64ff99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f6585c19d5998102877d53b5b0d6ff9 = $(`&lt;div id=&quot;html_1f6585c19d5998102877d53b5b0d6ff9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5197800743&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Capra pyrenaica&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_9aabfaebc2fed05b62e47edafe64ff99.setContent(html_1f6585c19d5998102877d53b5b0d6ff9);
#
#
#
#         circle_marker_32036667d7d882bf2dfd525c5b7e60d1.bindPopup(popup_9aabfaebc2fed05b62e47edafe64ff99)
#         ;
#
#
#
#
#             var circle_marker_7cba5a8946dc388615a05cc24b1ae92b = L.circleMarker(
#                 [42.028915, -8.149858],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea5e1732e6b70d044f845a4e488255a5);
#
#
#         var popup_41e442f5c4aebdbd5d58e5ff62453171 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f66fb514089a2040be8e00f0f4c45f99 = $(`&lt;div id=&quot;html_f66fb514089a2040be8e00f0f4c45f99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 4995547365&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Capra pyrenaica&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_41e442f5c4aebdbd5d58e5ff62453171.setContent(html_f66fb514089a2040be8e00f0f4c45f99);
#
#
#
#         circle_marker_7cba5a8946dc388615a05cc24b1ae92b.bindPopup(popup_41e442f5c4aebdbd5d58e5ff62453171)
#         ;
#
#
#
#
#             var circle_marker_13c43fede4c729beb0922e11b68324ce = L.circleMarker(
#                 [41.975922, -8.225673],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea5e1732e6b70d044f845a4e488255a5);
#
#
#         var popup_78bbee14942336b8aa622753aab6532f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41d34e2e5d7ea73c0a08ddf347e6e9ac = $(`&lt;div id=&quot;html_41d34e2e5d7ea73c0a08ddf347e6e9ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 4460418174&lt;br&gt;     &lt;b&gt;Species:&

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Capra_pyrenaica/Capra_pyrenaica_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Capra_pyrenaica/Capra_pyrenaica_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Capra_pyrenaica/Capra_pyrenaica_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID          species  decimalLatitude  decimalLongitude countryCode  \
# 0  5197800743  Capra pyrenaica        41.978390         -8.232147          PT
# 1  4995547365  Capra pyrenaica        42.028915         -8.149858          PT
# 2  4460418174  Capra pyrenaica        41.975922         -8.225673          PT
# 3  3804708377  Capra pyrenaica        41.787009         -7.971064          PT
# 4  3804707507  Capra pyrenaica        41.816165         -8.041350          PT
#
#     eventDate      basisOfRecord  coordinateUncertaintyInMeters  year  month  \
# 0  2025-06-16  HUMAN_OBSERVATION                           50.0  2025      6
# 1  2024-12-10  HUMAN_OBSERVATION                            3.0  2024     12
# 2  2023-09-29  HUMAN_OBSERVATION                            NaN  2023      9
# 3  2020-08-09  HUMAN_OBSERVATION                           50.0  2020      8
# 4  2021-09-04  HUMAN_OBSERVATION                           50.0  2021      9
#
#    day                   geometry
# 0   16  POINT (-8.23215 41.97839)
# 1   10  POINT (-8.14986 42.02892)
# 2   29  POINT (-8.22567 41.97592)
# 3    9  POINT (-7.97106 41.78701)
# 4    4  POINT (-8.04135 41.81616)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count       7.000000
# mean      307.857143
# std       473.300619
# min         2.000000
# 25%        26.500000
# 50%        50.000000
# 75%       525.000000
# max      1000.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 12 original records
# 2 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Capra_pyrenaica/Capra_pyrenaica_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="spp_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Capra_pyrenaica/Capra_pyrenaica_clean.gpkg

# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Capreolus_capreolus'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Capreolus_capreolus.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Capreolus_capreolus

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capreolus_capreolus/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capreolus_capreolus/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capreolus_capreolus/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capreolus_capreolus/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capreolus_capreolus/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capreolus_capreolus/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capreolus_capreolus/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Capreolus_capreolus/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (863, 230)
#        gbifID  accessRights  bibliographicCitation language       license  \
# 0  6235894959           NaN                    NaN      NaN  CC_BY_NC_4_0
# 1  6235210980           NaN                    NaN      NaN  CC_BY_NC_4_0
# 2  6234782934           NaN                    NaN      NaN  CC_BY_NC_4_0
# 3  6234594649           NaN                    NaN      NaN  CC_BY_NC_4_0
# 4  6195858981           NaN                    NaN      NaN  CC_BY_NC_4_0
#
#                modified  publisher  \
# 0  2026-04-14T15:47:14Z        NaN
# 1  2026-04-22T15:42:39Z        NaN
# 2  2026-04-29T15:52:00Z        NaN
# 3  2026-04-22T15:43:15Z        NaN
# 4  2026-04-13T14:23:18Z        NaN
#
#                                           references        rightsHolder type  \
# 0  https://www.inaturalist.org/observations/34974...     Daniel Oliveira  NaN
# 1  https://www.inaturalist.org/observations/35025...  Ismael Gomes Queta  NaN
# 2  https://www.inaturalist.org/observations/35222...                lzos  NaN
# 3  https://www.inaturalist.org/observations/35035...   Jean-Léonard Stör  NaN
# 4  https://www.inaturalist.org/observations/34949...       Samuel Duarte  NaN
#
#    ... publishedByGbifRegion  level0Gid  level0Name level1Gid      level1Name  \
# 0  ...                EUROPE        PRT    Portugal   PRT.6_1  Castelo Branco
# 1  ...         NORTH_AMERICA        NaN         NaN       NaN             NaN
# 2  ...         NORTH_AMERICA        NaN         NaN       NaN             NaN
# 3  ...         NORTH_AMERICA        PRT    Portugal  PRT.19_1       Vila Real
# 4  ...         NORTH_AMERICA        PRT    Portugal  PRT.10_1          Guarda
#
#     level2Gid       level2Name     level3Gid           level3Name  \
# 0   PRT.6.6_1          Oleiros   PRT.6.6.7_1             Mosteiro
# 1         NaN              NaN           NaN                  NaN
# 2         NaN              NaN           NaN                  NaN
# 3  PRT.19.5_1  Mondim de Basto  PRT.19.5.4_1               Ermelo
# 4  PRT.10.6_1          Gouveia  PRT.10.6.8_1  Gouveia (São Pedro)
#
#   iucnRedListCategory
# 0                  LC
# 1                  LC
# 2                  LC
# 3                 NaN
# 4                  LC
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (863, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (863, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (863, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (863, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (863, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (659, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (638, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (638, 12)
#         gbifID              species  decimalLatitude  decimalLongitude  \
# 3   6234594649  Capreolus capreolus        41.352247         -7.899472
# 4   6195858981  Capreolus capreolus        40.506031         -7.567541
# 14  6186031439  Capreolus capreolus        40.575389         -7.518224
# 18  6184891612  Capreolus capreolus        40.559750         -7.133257
# 22  6179208251  Capreolus capreolus        39.989215         -8.440301
#
#    countryCode            eventDate      basisOfRecord  \
# 3           PT  2026-04-16T22:36:51  HUMAN_OBSERVATION
# 4           PT    2026-03-19T11:45Z  HUMAN_OBSERVATION
# 14          PT    2026-03-15T06:43Z  HUMAN_OBSERVATION
# 18          PT    2026-03-19T10:37Z  HUMAN_OBSERVATION
# 22          PT    2026-03-04T21:46Z  HUMAN_OBSERVATION
#
#     coordinateUncertaintyInMeters  year  month   day  \
# 3                          1096.0  2026    4.0  16.0
# 4                            17.0  2026    3.0  19.0
# 14                           58.0  2026    3.0  15.0
# 18                          238.0  2026    3.0  19.0
# 22                          188.0  2026    3.0   4.0
#
#                      geometry
# 3   POINT (-7.89947 41.35225)
# 4   POINT (-7.56754 40.50603)
# 14  POINT (-7.51822 40.57539)
# 18  POINT (-7.13326 40.55975)
# 22   POINT (-8.4403 39.98922)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Capreolus_capreolus

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Capreolus_capreolus/Capreolus_capreolus.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Capreolus_capreolus/Capreolus_capreolus.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Capreolus_capreolus/Capreolus_capreolus.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Capreolus_capreolus/Capreolus_capreolus.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Capreolus_capreolus
# Records: 638
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Capreolus_capreolus/Capreolus_capreolus.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Capreolus_capreolus/Capreolus_capreolus.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Capreolus_capreolus/Capreolus_capreolus.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Capreolus_capreolus/Capreolus_capreolus.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f3acd8cb116ae2ec98c293492a873c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f3acd8cb116ae2ec98c293492a873c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f3acd8cb116ae2ec98c293492a873c7 = L.map(
#                 &quot;map_8f3acd8cb116ae2ec98c293492a873c7&quot;,
#                 {
#                     center: [41.03677282445141, -7.433165390282131],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f75eca0091dc1e795aabe8ff750a488 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f75eca0091dc1e795aabe8ff750a488.addTo(map_8f3acd8cb116ae2ec98c293492a873c7);
#
#
#             var marker_cluster_2abb38a83b73abf7fe928956ad3cac79 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_412dc1ebf3224433d372156041e05b1a = L.circleMarker(
#                 [41.352247, -7.899472],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_2abb38a83b73abf7fe928956ad3cac79);
#
#
#         var popup_589154d38df3dae6952c0a119466e572 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_a507d94d1bdcfb65418b3d17f03e2a4b = $(`&lt;div id=&quot;html_a507d94d1bdcfb65418b3d17f03e2a4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6234594649&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Capreolus capreolus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-04-16T22:36:51&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 1096.0     &lt;/div&gt;`)[0];
#                 popup_589154d38df3dae6952c0a119466e572.setContent(html_a507d94d1bdcfb65418b3d17f03e2a4b);
#
#
#
#         circle_marker_412dc1ebf3224433d372156041e05b1a.bindPopup(popup_589154d38df3dae6952c0a119466e572)
#         ;
#
#
#
#
#             var circle_marker_af7bc7a6472ff59dd5127fee827f99f8 = L.circleMarker(
#                 [40.506031, -7.567541],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_2abb38a83b73abf7fe928956ad3cac79);
#
#
#         var popup_e6a014d7ebd79934acb9cae08df3bf1e = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_58a00b6db18bc57bb39cbb4ff2082f67 = $(`&lt;div id=&quot;html_58a00b6db18bc57bb39cbb4ff2082f67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6195858981&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Capreolus capreolus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-03-19T11:45Z&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 17.0     &lt;/div&gt;`)[0];
#                 popup_e6a014d7ebd79934acb9cae08df3bf1e.setContent(html_58a00b6db18bc57bb39cbb4ff2082f67);
#
#
#
#         circle_marker_af7bc7a6472ff59dd5127fee827f99f8.bindPopup(popup_e6a014d7ebd79934acb9cae08df3bf1e)
#         ;
#
#
#
#
#             var circle_marker_72e3d4880f8b4a8b2039dc7c3ada0bdd = L.circleMarker(
#                 [40.575389, -7.518224],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;das

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 638

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 638

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0022e78beeb708665edc97b97c644be6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0022e78beeb708665edc97b97c644be6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0022e78beeb708665edc97b97c644be6 = L.map(
#                 &quot;map_0022e78beeb708665edc97b97c644be6&quot;,
#                 {
#                     center: [41.03677282445141, -7.433165390282131],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b77531e2704c5c5a3fdc5a7009af5328 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b77531e2704c5c5a3fdc5a7009af5328.addTo(map_0022e78beeb708665edc97b97c644be6);
#
#
#             var circle_marker_f96fa46e8d31c60236821fc536404a73 = L.circleMarker(
#                 [41.352247, -7.899472],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0022e78beeb708665edc97b97c644be6);
#
#
#         var popup_f72a2cc70c45b857b53cec36098114b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9567ae6a32aa86c9ee5b1e3b4163fc3 = $(`&lt;div id=&quot;html_d9567ae6a32aa86c9ee5b1e3b4163fc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6234594649&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Capreolus capreolus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_f72a2cc70c45b857b53cec36098114b5.setContent(html_d9567ae6a32aa86c9ee5b1e3b4163fc3);
#
#
#
#         circle_marker_f96fa46e8d31c60236821fc536404a73.bindPopup(popup_f72a2cc70c45b857b53cec36098114b5)
#         ;
#
#
#
#
#             var circle_marker_3f71209c8a92220ac007ea84d4dfd951 = L.circleMarker(
#                 [40.506031, -7.567541],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0022e78beeb708665edc97b97c644be6);
#
#
#         var popup_b148f9e305ec416734d2dac2ab10509e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ec034ebaaa13914166efd1dbd2433fa = $(`&lt;div id=&quot;html_7ec034ebaaa13914166efd1dbd2433fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6195858981&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Capreolus capreolus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_b148f9e305ec416734d2dac2ab10509e.setContent(html_7ec034ebaaa13914166efd1dbd2433fa);
#
#
#
#         circle_marker_3f71209c8a92220ac007ea84d4dfd951.bindPopup(popup_b148f9e305ec416734d2dac2ab10509e)
#         ;
#
#
#
#
#             var circle_marker_d0327a80516382329c4d18b251ec197f = L.circleMarker(
#                 [40.575389, -7.518224],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0022e78beeb708665edc97b97c644be6);
#
#
#         var popup_3c6b75518af320bd781af1b21becd70b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a5ec4795ffeb7f6bbc0d8caa6a6dce2 = $(`&lt;div id=&quot;html_5a5ec4795ffeb7f6bbc0d8caa6a6dce2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6186031439&lt;br&gt;     &lt;b&gt;

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Capreolus_capreolus/Capreolus_capreolus_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Capreolus_capreolus/Capreolus_capreolus_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Capreolus_capreolus/Capreolus_capreolus_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID              species  decimalLatitude  decimalLongitude  \
# 0  6234594649  Capreolus capreolus        41.352247         -7.899472
# 1  6195858981  Capreolus capreolus        40.506031         -7.567541
# 2  6186031439  Capreolus capreolus        40.575389         -7.518224
# 3  6184891612  Capreolus capreolus        40.559750         -7.133257
# 4  6179208251  Capreolus capreolus        39.989215         -8.440301
#
#   countryCode            eventDate      basisOfRecord  \
# 0          PT  2026-04-16T22:36:51  HUMAN_OBSERVATION
# 1          PT    2026-03-19T11:45Z  HUMAN_OBSERVATION
# 2          PT    2026-03-15T06:43Z  HUMAN_OBSERVATION
# 3          PT    2026-03-19T10:37Z  HUMAN_OBSERVATION
# 4          PT    2026-03-04T21:46Z  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month   day                   geometry
# 0                         1096.0  2026    4.0  16.0  POINT (-7.89947 41.35225)
# 1                           17.0  2026    3.0  19.0  POINT (-7.56754 40.50603)
# 2                           58.0  2026    3.0  15.0  POINT (-7.51822 40.57539)
# 3                          238.0  2026    3.0  19.0  POINT (-7.13326 40.55975)
# 4                          188.0  2026    3.0   4.0   POINT (-8.4403 39.98922)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count     593.000000
# mean      208.440135
# std       635.734859
# min         1.000000
# 25%        30.000000
# 50%        30.000000
# 75%        50.000000
# max      5000.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 638 original records
# 424 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Capreolus_capreolus/Capreolus_capreolus_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="Capreolus_capreolus_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Capreolus_capreolus/Capreolus_capreolus_clean.gpkg

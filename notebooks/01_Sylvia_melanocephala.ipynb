# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Sylvia_melanocephala'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Sylvia_melanocephala.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Sylvia_melanocephala

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Sylvia_melanocephala/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Sylvia_melanocephala/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Sylvia_melanocephala/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Sylvia_melanocephala/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Sylvia_melanocephala/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Sylvia_melanocephala/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Sylvia_melanocephala/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Sylvia_melanocephala/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (1934, 230)
#        gbifID  accessRights  bibliographicCitation language    license  \
# 0  6181727452           NaN                    NaN      NaN  CC_BY_4_0
# 1  6178169404           NaN                    NaN      NaN  CC_BY_4_0
# 2  6178166570           NaN                    NaN      NaN  CC_BY_4_0
# 3  6178157814           NaN                    NaN      NaN  CC_BY_4_0
# 4  6178156846           NaN                    NaN      NaN  CC_BY_4_0
#
#   modified  publisher                                         references  \
# 0      NaN        NaN  https://enjoynature.net/?gebiet=952324022&datu...
# 1      NaN        NaN  https://enjoynature.net/?gebiet=-91474217&datu...
# 2      NaN        NaN  https://enjoynature.net/?gebiet=1968275862&dat...
# 3      NaN        NaN  https://enjoynature.net/?gebiet=-1848661194&da...
# 4      NaN        NaN  https://enjoynature.net/?gebiet=-250924723&dat...
#
#   rightsHolder type  ... publishedByGbifRegion  level0Gid  level0Name  \
# 0          NaN  NaN  ...                EUROPE        PRT    Portugal
# 1          NaN  NaN  ...                EUROPE        PRT    Portugal
# 2          NaN  NaN  ...                EUROPE        PRT    Portugal
# 3          NaN  NaN  ...                EUROPE        PRT    Portugal
# 4          NaN  NaN  ...                EUROPE        PRT    Portugal
#
#   level1Gid level1Name   level2Gid                  level2Name     level3Gid  \
# 0   PRT.9_1       Faro  PRT.9.16_1  Vila Real de Santo António  PRT.9.16.1_1
# 1   PRT.9_1       Faro  PRT.9.13_1                      Silves  PRT.9.13.4_1
# 2   PRT.9_1       Faro   PRT.9.8_1                       Loulé   PRT.9.8.1_1
# 3   PRT.9_1       Faro  PRT.9.10_1                       Olhão  PRT.9.10.4_1
# 4   PRT.9_1       Faro   PRT.9.8_1                       Loulé  PRT.9.8.10_1
#
#     level3Name  iucnRedListCategory
# 0  Monte Gordo                  NaN
# 1         Pêra                  NaN
# 2     Almansil                  NaN
# 3      Quelfes                  NaN
# 4        Salir                  NaN
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (1934, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (1934, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (1934, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (1934, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (1934, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (625, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (625, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (625, 12)
#        gbifID               species  decimalLatitude  decimalLongitude  \
# 0  6181727452  Sylvia melanocephala        37.179771         -7.454321
# 1  6178169404  Sylvia melanocephala        37.094757         -8.333302
# 2  6178166570  Sylvia melanocephala        37.017941         -7.996888
# 3  6178157814  Sylvia melanocephala        37.032467         -7.812996
# 4  6178156846  Sylvia melanocephala        37.252125         -8.105507
#
#   countryCode         eventDate      basisOfRecord  \
# 0          PT  2026-03-03T00:00  HUMAN_OBSERVATION
# 1          PT  2026-02-22T00:00  HUMAN_OBSERVATION
# 2          PT  2026-02-20T00:00  HUMAN_OBSERVATION
# 3          PT  2026-02-20T00:00  HUMAN_OBSERVATION
# 4          PT  2026-02-23T00:00  HUMAN_OBSERVATION
#
#    coordinateUncertaintyInMeters  year  month  day                   geometry
# 0                           25.0  2026      3    3  POINT (-7.45432 37.17977)
# 1                          250.0  2026      2   22   POINT (-8.3333 37.09476)
# 2                          250.0  2026      2   20  POINT (-7.99689 37.01794)
# 3                          250.0  2026      2   20    POINT (-7.813 37.03247)
# 4                          250.0  2026      2   23  POINT (-8.10551 37.25212)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Sylvia_melanocephala

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Sylvia_melanocephala/Sylvia_melanocephala.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Sylvia_melanocephala/Sylvia_melanocephala.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Sylvia_melanocephala/Sylvia_melanocephala.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Sylvia_melanocephala/Sylvia_melanocephala.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Sylvia_melanocephala
# Records: 625
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Sylvia_melanocephala/Sylvia_melanocephala.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Sylvia_melanocephala/Sylvia_melanocephala.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Sylvia_melanocephala/Sylvia_melanocephala.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Sylvia_melanocephala/Sylvia_melanocephala.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e46305d476b1ed62956e9495566c8385 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e46305d476b1ed62956e9495566c8385&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e46305d476b1ed62956e9495566c8385 = L.map(
#                 &quot;map_e46305d476b1ed62956e9495566c8385&quot;,
#                 {
#                     center: [39.37404344800001, -7.803530768],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7694d4a131bb3a5d1ce66a5dc901a98 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f7694d4a131bb3a5d1ce66a5dc901a98.addTo(map_e46305d476b1ed62956e9495566c8385);
#
#
#             var marker_cluster_c3d688b15509db54d3f8b5e8f045bb31 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_122aa4bb717883affcbbdeee1fec67a3 = L.circleMarker(
#                 [37.179771, -7.454321],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_c3d688b15509db54d3f8b5e8f045bb31);
#
#
#         var popup_6e46438e6cd06cb7888ee31de8372a46 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_f5fed9c7b4cd00a50e518d940f8a2bac = $(`&lt;div id=&quot;html_f5fed9c7b4cd00a50e518d940f8a2bac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6181727452&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Sylvia melanocephala&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-03-03T00:00&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 25.0     &lt;/div&gt;`)[0];
#                 popup_6e46438e6cd06cb7888ee31de8372a46.setContent(html_f5fed9c7b4cd00a50e518d940f8a2bac);
#
#
#
#         circle_marker_122aa4bb717883affcbbdeee1fec67a3.bindPopup(popup_6e46438e6cd06cb7888ee31de8372a46)
#         ;
#
#
#
#
#             var circle_marker_b705df58a4f724c4957eb9537a56de1d = L.circleMarker(
#                 [37.094757, -8.333302],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_c3d688b15509db54d3f8b5e8f045bb31);
#
#
#         var popup_32b93db085d938a8edffb241e28b3f77 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_6296e2831c58624f02847869be2c4457 = $(`&lt;div id=&quot;html_6296e2831c58624f02847869be2c4457&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6178169404&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Sylvia melanocephala&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2026-02-22T00:00&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 250.0     &lt;/div&gt;`)[0];
#                 popup_32b93db085d938a8edffb241e28b3f77.setContent(html_6296e2831c58624f02847869be2c4457);
#
#
#
#         circle_marker_b705df58a4f724c4957eb9537a56de1d.bindPopup(popup_32b93db085d938a8edffb241e28b3f77)
#         ;
#
#
#
#
#             var circle_marker_42a4a50d29f5937ab5b5fa242e085052 = L.circleMarker(
#                 [37.017941, -7.996888],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&q

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 625

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 625

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7972dc3f83e739283d276ffd991c9dc0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7972dc3f83e739283d276ffd991c9dc0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7972dc3f83e739283d276ffd991c9dc0 = L.map(
#                 &quot;map_7972dc3f83e739283d276ffd991c9dc0&quot;,
#                 {
#                     center: [39.37404344800001, -7.803530768],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90c2df74ede5492b7fd50d0778422b3d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_90c2df74ede5492b7fd50d0778422b3d.addTo(map_7972dc3f83e739283d276ffd991c9dc0);
#
#
#             var circle_marker_99e5e01e3b175d6fb39e51acbdf4a9eb = L.circleMarker(
#                 [37.179771, -7.454321],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7972dc3f83e739283d276ffd991c9dc0);
#
#
#         var popup_2a538cbf0ed33ec199a7bc47c5281a0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6251d4c9ea0adc1b5f01a695b22dc916 = $(`&lt;div id=&quot;html_6251d4c9ea0adc1b5f01a695b22dc916&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6181727452&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Sylvia melanocephala&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_2a538cbf0ed33ec199a7bc47c5281a0a.setContent(html_6251d4c9ea0adc1b5f01a695b22dc916);
#
#
#
#         circle_marker_99e5e01e3b175d6fb39e51acbdf4a9eb.bindPopup(popup_2a538cbf0ed33ec199a7bc47c5281a0a)
#         ;
#
#
#
#
#             var circle_marker_c14975fe9cd613830c6444c5e7cd0a89 = L.circleMarker(
#                 [37.094757, -8.333302],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7972dc3f83e739283d276ffd991c9dc0);
#
#
#         var popup_c664949499c2ac63d1d0655fd41fd6af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b2cda634c9ea6d53782ccb58eb57c32 = $(`&lt;div id=&quot;html_2b2cda634c9ea6d53782ccb58eb57c32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6178169404&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Sylvia melanocephala&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_c664949499c2ac63d1d0655fd41fd6af.setContent(html_2b2cda634c9ea6d53782ccb58eb57c32);
#
#
#
#         circle_marker_c14975fe9cd613830c6444c5e7cd0a89.bindPopup(popup_c664949499c2ac63d1d0655fd41fd6af)
#         ;
#
#
#
#
#             var circle_marker_aa205668306989f14a675116c5499693 = L.circleMarker(
#                 [37.017941, -7.996888],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7972dc3f83e739283d276ffd991c9dc0);
#
#
#         var popup_e40b84c5a6c617d5fef261fea19bac01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ef99cba22fae6869f655fb4eadf9d1a = $(`&lt;div id=&quot;html_4ef99cba22fae6869f655fb4eadf9d1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 6178166570&lt;br&gt;     &lt;b&gt;Spec

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Sylvia_melanocephala/Sylvia_melanocephala_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Sylvia_melanocephala/Sylvia_melanocephala_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Sylvia_melanocephala/Sylvia_melanocephala_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID               species  decimalLatitude  decimalLongitude  \
# 0  6181727452  Sylvia melanocephala        37.179771         -7.454321
# 1  6178169404  Sylvia melanocephala        37.094757         -8.333302
# 2  6178166570  Sylvia melanocephala        37.017941         -7.996888
# 3  6178157814  Sylvia melanocephala        37.032467         -7.812996
# 4  6178156846  Sylvia melanocephala        37.252125         -8.105507
#
#   countryCode  eventDate      basisOfRecord  coordinateUncertaintyInMeters  \
# 0          PT 2026-03-03  HUMAN_OBSERVATION                           25.0
# 1          PT 2026-02-22  HUMAN_OBSERVATION                          250.0
# 2          PT 2026-02-20  HUMAN_OBSERVATION                          250.0
# 3          PT 2026-02-20  HUMAN_OBSERVATION                          250.0
# 4          PT 2026-02-23  HUMAN_OBSERVATION                          250.0
#
#    year  month  day                   geometry
# 0  2026      3    3  POINT (-7.45432 37.17977)
# 1  2026      2   22   POINT (-8.3333 37.09476)
# 2  2026      2   20  POINT (-7.99689 37.01794)
# 3  2026      2   20    POINT (-7.813 37.03247)
# 4  2026      2   23  POINT (-8.10551 37.25212)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count    564.000000
# mean      75.700355
# std      107.636471
# min        5.000000
# 25%        5.000000
# 50%        5.000000
# 75%      250.000000
# max      250.000000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 625 original records
# 409 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Sylvia_melanocephala/Sylvia_melanocephala_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="spp_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Sylvia_melanocephala/Sylvia_melanocephala_clean.gpkg

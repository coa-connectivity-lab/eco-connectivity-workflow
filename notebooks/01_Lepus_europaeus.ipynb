# %% [markdown]
# # 02_clean_occurrences.ipynb
#
# GBIF Darwin Core Archive cleaning workflow for ecological connectivity analysis.
#
# This notebook:
# - extracts DwC-A archives
# - loads occurrence tables
# - validates coordinates
# - removes problematic records
# - converts to GeoDataFrame
# - exports GIS-ready layers for QGIS
# - stores outputs in the project architecture

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import pandas as pd
import geopandas as gpd
import numpy as np

from shapely.geometry import Point

import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# %% [markdown]
# ## Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_GBIF = PROJECT_ROOT / 'data' / 'raw' / 'gbif'
INTERIM_GBIF = PROJECT_ROOT / 'data' / 'interim' / 'gbif'
PROCESSED_SPECIES = PROJECT_ROOT / 'data' / 'processed' / 'species'

INTERIM_GBIF.mkdir(parents=True, exist_ok=True)
PROCESSED_SPECIES.mkdir(parents=True, exist_ok=True)

# %%
# Change species here
SPECIES = 'Lepus_europaeus'

ZIP_PATH = RAW_GBIF / f'{SPECIES}.zip'

EXTRACT_DIR = INTERIM_GBIF / SPECIES
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

print(ZIP_PATH)
print(EXTRACT_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/raw/gbif/Lepus_europaeus.zip
# /home/linda/Documents/myData/data-management/data/interim/gbif/Lepus_europaeus

# %%
QA_DIR = PROJECT_ROOT / 'data' / 'qa' / SPECIES
QA_DIR.mkdir(parents=True, exist_ok=True)

removed_csv_path = QA_DIR / f'{SPECIES}_removed_records.csv'
review_geojson_path = QA_DIR / f'{SPECIES}_review_points.geojson'

# %% [markdown]
# ## Extract Darwin Core Archive

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print('Archive extracted successfully.')
# Out:
# Archive extracted successfully.

# %% [markdown]
# ## Inspect Extracted Files

# %%
list(EXTRACT_DIR.glob('*'))
# Out:
# [PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lepus_europaeus/rights.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lepus_europaeus/meta.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lepus_europaeus/multimedia.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lepus_europaeus/verbatim.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lepus_europaeus/citations.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lepus_europaeus/occurrence.txt'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lepus_europaeus/metadata.xml'),
#  PosixPath('/home/linda/Documents/myData/data-management/data/interim/gbif/Lepus_europaeus/dataset')]

# %% [markdown]
# ## Load Occurrence Table

# %%
occurrence_file = EXTRACT_DIR / 'occurrence.txt'

df = pd.read_csv(
    occurrence_file,
    sep='\t',
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (10, 230)
#        gbifID  accessRights  bibliographicCitation language    license  \
# 0  5027669378           NaN                    NaN      NaN  CC_BY_4_0
# 1  5021531841           NaN                    NaN      NaN  CC_BY_4_0
# 2  5019951673           NaN                    NaN      NaN  CC_BY_4_0
# 3  5019437769           NaN                    NaN      NaN  CC_BY_4_0
# 4  5016571128           NaN                    NaN      NaN  CC_BY_4_0
#
#    modified  publisher                                         references  \
# 0       NaN        NaN  https://enjoynature.net/?gebiet=-91474217&datu...
# 1       NaN        NaN  https://enjoynature.net/?gebiet=1544795775&dat...
# 2       NaN        NaN  https://enjoynature.net/?gebiet=8870776&datum=...
# 3       NaN        NaN  https://enjoynature.net/?gebiet=-891390087&dat...
# 4       NaN        NaN  https://enjoynature.net/?gebiet=294432143&datu...
#
#   rightsHolder type  ... publishedByGbifRegion  level0Gid  level0Name  \
# 0          NaN  NaN  ...                EUROPE        PRT    Portugal
# 1          NaN  NaN  ...                EUROPE        PRT    Portugal
# 2          NaN  NaN  ...                EUROPE        PRT    Portugal
# 3          NaN  NaN  ...                EUROPE        PRT    Portugal
# 4          NaN  NaN  ...                EUROPE        PRT    Portugal
#
#   level1Gid  level1Name   level2Gid    level2Name     level3Gid  \
# 0   PRT.9_1        Faro  PRT.9.13_1        Silves  PRT.9.13.4_1
# 1   PRT.9_1        Faro  PRT.9.14_1        Tavira  PRT.9.14.6_1
# 2   PRT.9_1        Faro  PRT.9.13_1        Silves  PRT.9.13.4_1
# 3   PRT.9_1        Faro   PRT.9.4_1  Castro Marim   PRT.9.4.3_1
# 4  PRT.14_1  Portalegre  PRT.14.4_1   Campo Maior  PRT.14.4.1_1
#
#                     level3Name  iucnRedListCategory
# 0                         Pêra                   LC
# 1                  Santa Luzia                   LC
# 2                         Pêra                   LC
# 3                 Castro Marim                   LC
# 4  Nossa Senhora Da Expectação                   LC
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Keep Essential Columns

# %%
keep_cols = [
    'gbifID',
    'species',
    'decimalLatitude',
    'decimalLongitude',
    'countryCode',
    'eventDate',
    'basisOfRecord',
    'coordinateUncertaintyInMeters',
    'year',
    'month',
    'day'
]

df = df[keep_cols].copy()

print(df.shape)
# Out:
# (10, 11)

# %% [markdown]
# ## Remove Missing Coordinates

# %%
df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (10, 11)

# %% [markdown]
# ## Convert Coordinates to Numeric

# %%
df['decimalLatitude'] = pd.to_numeric(
    df['decimalLatitude'],
    errors='coerce'
)

df['decimalLongitude'] = pd.to_numeric(
    df['decimalLongitude'],
    errors='coerce'
)

df = df.dropna(
    subset=['decimalLatitude', 'decimalLongitude']
)

print(df.shape)
# Out:
# (10, 11)

# %% [markdown]
# ## Remove Invalid Coordinates

# %%
df = df[
    (df['decimalLatitude'] >= -90) &
    (df['decimalLatitude'] <= 90) &
    (df['decimalLongitude'] >= -180) &
    (df['decimalLongitude'] <= 180)
]

print(df.shape)
# Out:
# (10, 11)

# %% [markdown]
# ## Remove Zero Coordinates

# %%
df = df[
    ~(
        (df['decimalLatitude'] == 0) &
        (df['decimalLongitude'] == 0)
    )
]

print(df.shape)
# Out:
# (10, 11)

# %% [markdown]
# ## Remove Duplicate Occurrences

# %%
df = df.drop_duplicates(
    subset=[
        'species',
        'decimalLatitude',
        'decimalLongitude'
    ]
)

print(df.shape)
# Out:
# (10, 11)

# %% [markdown]
# ## Filter Coordinate Uncertainty

# %%
df['coordinateUncertaintyInMeters'] = pd.to_numeric(
    df['coordinateUncertaintyInMeters'],
    errors='coerce'
)

MAX_UNCERTAINTY = 5000

df = df[
    (
        df['coordinateUncertaintyInMeters'].isna()
    ) |
    (
        df['coordinateUncertaintyInMeters'] <= MAX_UNCERTAINTY
    )
]

print(df.shape)
# Out:
# (10, 11)

# %% [markdown]
# ## Convert to GeoDataFrame

# %%
geometry = [
    Point(xy)
    for xy in zip(
        df['decimalLongitude'],
        df['decimalLatitude']
    )
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs='EPSG:4326'
)

print(gdf.shape)
gdf.head()
# Out:
# (10, 12)
#        gbifID          species  decimalLatitude  decimalLongitude countryCode  \
# 0  5027669378  Lepus europaeus        37.094757         -8.333302          PT
# 1  5021531841  Lepus europaeus        37.086269         -7.662406          PT
# 2  5019951673  Lepus europaeus        37.105301         -8.347549          PT
# 3  5019437769  Lepus europaeus        37.231251         -7.426887          PT
# 4  5016571128  Lepus europaeus        39.008831         -7.047425          PT
#
#           eventDate      basisOfRecord  coordinateUncertaintyInMeters  year  \
# 0  2012-10-16T00:00  HUMAN_OBSERVATION                          250.0  2012
# 1  2012-03-10T00:00  HUMAN_OBSERVATION                          250.0  2012
# 2  2012-10-22T00:00  HUMAN_OBSERVATION                          250.0  2012
# 3  2007-03-31T00:00  HUMAN_OBSERVATION                          250.0  2007
# 4  2017-01-30T00:00  HUMAN_OBSERVATION                          250.0  2017
#
#    month  day                   geometry
# 0     10   16   POINT (-8.3333 37.09476)
# 1      3   10  POINT (-7.66241 37.08627)
# 2     10   22   POINT (-8.34755 37.1053)
# 3      3   31  POINT (-7.42689 37.23125)
# 4      1   30  POINT (-7.04742 39.00883)

# %% [markdown]
# ## Reproject to EPSG:3035

# %%
gdf_3035 = gdf.to_crs('EPSG:3035')

print(gdf_3035.crs)
# Out:
# EPSG:3035

# %% [markdown]
# ## Quick Spatial Plot

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf.plot(
    ax=ax,
    markersize=4,
    alpha=0.6
)

ax.set_title(f'{SPECIES} Occurrences')

plt.show()

# %% [markdown]
# ## Output Paths

# %%
SPECIES_DIR = PROCESSED_SPECIES / SPECIES
SPECIES_DIR.mkdir(parents=True, exist_ok=True)

gpkg_path = SPECIES_DIR / f'{SPECIES}.gpkg'
geojson_path = SPECIES_DIR / f'{SPECIES}.geojson'
parquet_path = SPECIES_DIR / f'{SPECIES}.parquet'
csv_path = SPECIES_DIR / f'{SPECIES}.csv'

print(SPECIES_DIR)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Lepus_europaeus

# %% [markdown]
# ## Export GeoPackage

# %%
gdf_3035.to_file(
    gpkg_path,
    driver='GPKG'
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Lepus_europaeus/Lepus_europaeus.gpkg

# %% [markdown]
# ## Export GeoJSON

# %%
gdf.to_file(
    geojson_path,
    driver='GeoJSON'
)

print(geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Lepus_europaeus/Lepus_europaeus.geojson

# %% [markdown]
# ## Export GeoParquet

# %%
gdf.to_parquet(parquet_path)

print(parquet_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Lepus_europaeus/Lepus_europaeus.parquet

# %% [markdown]
# ## Export CSV

# %%
gdf.drop(columns='geometry').to_csv(
    csv_path,
    index=False
)

print(csv_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Lepus_europaeus/Lepus_europaeus.csv

# %% [markdown]
# ## QA Summary

# %%
print('FINAL SUMMARY')
print('-' * 40)

print(f'Species: {SPECIES}')
print(f'Records: {len(gdf)}')
print(f'CRS: {gdf.crs}')

print('\nOutputs:')
print(gpkg_path)
print(geojson_path)
print(parquet_path)
print(csv_path)
# Out:
# FINAL SUMMARY
# ----------------------------------------
# Species: Lepus_europaeus
# Records: 10
# CRS: EPSG:4326
#
# Outputs:
# /home/linda/Documents/myData/data-management/data/processed/species/Lepus_europaeus/Lepus_europaeus.gpkg
# /home/linda/Documents/myData/data-management/data/processed/species/Lepus_europaeus/Lepus_europaeus.geojson
# /home/linda/Documents/myData/data-management/data/processed/species/Lepus_europaeus/Lepus_europaeus.parquet
# /home/linda/Documents/myData/data-management/data/processed/species/Lepus_europaeus/Lepus_europaeus.csv

# %% [markdown]
# ## Interactive OpenStreetMap QA (manual validation)

# %%
review_gdf = gdf.copy()

center_lat = review_gdf['decimalLatitude'].mean()
center_lon = review_gdf['decimalLongitude'].mean()

m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(m)

for _, row in review_gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}<br>
    <b>Date:</b> {row['eventDate']}<br>
    <b>Uncertainty:</b> {row['coordinateUncertaintyInMeters']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db69f34915266f2a3e22f51415eac1dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db69f34915266f2a3e22f51415eac1dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db69f34915266f2a3e22f51415eac1dd = L.map(
#                 &quot;map_db69f34915266f2a3e22f51415eac1dd&quot;,
#                 {
#                     center: [37.0357723, -8.693728199999999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d676ae3a0a75176274c82e94ad6988b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1d676ae3a0a75176274c82e94ad6988b.addTo(map_db69f34915266f2a3e22f51415eac1dd);
#
#
#             var marker_cluster_ea02b7e9183bc6e9bff82f69a7be562c = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_586f7827e11b96a65f6dc09ad0481bdf = L.circleMarker(
#                 [37.094757, -8.333302],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_ea02b7e9183bc6e9bff82f69a7be562c);
#
#
#         var popup_dc4ce11912bdf0ec5e49aae3bd5bbde1 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_1b8d1a510446675d4c50a14ba6af22ee = $(`&lt;div id=&quot;html_1b8d1a510446675d4c50a14ba6af22ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5027669378&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Lepus europaeus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2012-10-16T00:00&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 250.0     &lt;/div&gt;`)[0];
#                 popup_dc4ce11912bdf0ec5e49aae3bd5bbde1.setContent(html_1b8d1a510446675d4c50a14ba6af22ee);
#
#
#
#         circle_marker_586f7827e11b96a65f6dc09ad0481bdf.bindPopup(popup_dc4ce11912bdf0ec5e49aae3bd5bbde1)
#         ;
#
#
#
#
#             var circle_marker_d3b7d7f036a31542ddfec6fdbc2d0fce = L.circleMarker(
#                 [37.086269, -7.662406],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_ea02b7e9183bc6e9bff82f69a7be562c);
#
#
#         var popup_ee27b391c2a459dfcdeccd2cdcaeffce = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_90207d69d5ba37049b4a59d9ea260c5f = $(`&lt;div id=&quot;html_90207d69d5ba37049b4a59d9ea260c5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5021531841&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Lepus europaeus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2012-03-10T00:00&lt;br&gt;     &lt;b&gt;Uncertainty:&lt;/b&gt; 250.0     &lt;/div&gt;`)[0];
#                 popup_ee27b391c2a459dfcdeccd2cdcaeffce.setContent(html_90207d69d5ba37049b4a59d9ea260c5f);
#
#
#
#         circle_marker_d3b7d7f036a31542ddfec6fdbc2d0fce.bindPopup(popup_ee27b391c2a459dfcdeccd2cdcaeffce)
#         ;
#
#
#
#
#             var circle_marker_ea9675137fac7eb79e13a93debef9125 = L.circleMarker(
#                 [37.105301, -8.347549],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null

# %% [markdown]
# ## Manual removal (cherry-pick bad records)

# %%
# Paste GBIF IDs you want to remove after inspecting the map
REMOVE_GBIF_IDS = [
    #5024499210,
   #3329219793,
]

REMOVE_GBIF_IDS = [str(x) for x in REMOVE_GBIF_IDS]

print("Before removal:", len(gdf))
# Out:
# Before removal: 10

# %%
removed_records = gdf[
    gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Removed records:", len(removed_records))

if len(removed_records) > 0:
    removed_records.drop(columns='geometry').to_csv(
        removed_csv_path,
        index=False
    )
    print("Saved removed log:", removed_csv_path)
# Out:
# Removed records: 0

# %%
gdf = gdf[
    ~gdf['gbifID'].astype(str).isin(REMOVE_GBIF_IDS)
].copy()

print("Remaining records:", len(gdf))
# Out:
# Remaining records: 10

# %%
clean_center_lat = gdf['decimalLatitude'].mean()
clean_center_lon = gdf['decimalLongitude'].mean()

clean_map = folium.Map(
    location=[clean_center_lat, clean_center_lon],
    zoom_start=5,
    tiles='OpenStreetMap'
)

for _, row in gdf.iterrows():

    popup = f"""
    <b>GBIF ID:</b> {row['gbifID']}<br>
    <b>Species:</b> {row['species']}<br>
    <b>Country:</b> {row['countryCode']}
    """

    folium.CircleMarker(
        location=[row['decimalLatitude'], row['decimalLongitude']],
        radius=4,
        color='green',
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(clean_map)

display(clean_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82a67614bc618097910994e8c28f0ef2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82a67614bc618097910994e8c28f0ef2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82a67614bc618097910994e8c28f0ef2 = L.map(
#                 &quot;map_82a67614bc618097910994e8c28f0ef2&quot;,
#                 {
#                     center: [37.0357723, -8.693728199999999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0956c398bbe284e64828458030cf22bb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0956c398bbe284e64828458030cf22bb.addTo(map_82a67614bc618097910994e8c28f0ef2);
#
#
#             var circle_marker_4ce321ea27b9ae4119c996cc973fa3c8 = L.circleMarker(
#                 [37.094757, -8.333302],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_82a67614bc618097910994e8c28f0ef2);
#
#
#         var popup_7091a2ba18b8b6dc94ac195c98f0fa85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6f3c9cefe4288b6100a328b17306d49 = $(`&lt;div id=&quot;html_e6f3c9cefe4288b6100a328b17306d49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5027669378&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Lepus europaeus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_7091a2ba18b8b6dc94ac195c98f0fa85.setContent(html_e6f3c9cefe4288b6100a328b17306d49);
#
#
#
#         circle_marker_4ce321ea27b9ae4119c996cc973fa3c8.bindPopup(popup_7091a2ba18b8b6dc94ac195c98f0fa85)
#         ;
#
#
#
#
#             var circle_marker_f353bfbba71019474b5ec4c87060b8f9 = L.circleMarker(
#                 [37.086269, -7.662406],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_82a67614bc618097910994e8c28f0ef2);
#
#
#         var popup_1a97e5dda11d26f2ec97908dc3bc318b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fe5a79d729eb8f13b6eb7c8b27d9829 = $(`&lt;div id=&quot;html_2fe5a79d729eb8f13b6eb7c8b27d9829&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5021531841&lt;br&gt;     &lt;b&gt;Species:&lt;/b&gt; Lepus europaeus&lt;br&gt;     &lt;b&gt;Country:&lt;/b&gt; PT     &lt;/div&gt;`)[0];
#                 popup_1a97e5dda11d26f2ec97908dc3bc318b.setContent(html_2fe5a79d729eb8f13b6eb7c8b27d9829);
#
#
#
#         circle_marker_f353bfbba71019474b5ec4c87060b8f9.bindPopup(popup_1a97e5dda11d26f2ec97908dc3bc318b)
#         ;
#
#
#
#
#             var circle_marker_fe74afa2099ad72745e210cf2d7bdcf3 = L.circleMarker(
#                 [37.105301, -8.347549],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_82a67614bc618097910994e8c28f0ef2);
#
#
#         var popup_ea7f41e81bf2b42e410b1f863b98ffb4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62a5ba16534b87e90594c73f3e917a02 = $(`&lt;div id=&quot;html_62a5ba16534b87e90594c73f3e917a02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;GBIF ID:&lt;/b&gt; 5019951673&lt;br&gt;     &lt;b&gt;Species:&lt;/b&

# %%
clean_map.save(
    SPECIES_DIR / f'{SPECIES}_clean_map.html'
)

# %%
review_gdf.to_file(
    review_geojson_path,
    driver='GeoJSON'
)

print(review_geojson_path)
# Out:
# /home/linda/Documents/myData/data-management/data/qa/Lepus_europaeus/Lepus_europaeus_review_points.geojson

# %%
review_geojson_path
# Out:
# PosixPath('/home/linda/Documents/myData/data-management/data/qa/Lepus_europaeus/Lepus_europaeus_review_points.geojson')

# %%
# Update path 

import geopandas as gpd

path = "/home/linda/Documents/myData/data-management/data/qa/Lepus_europaeus/Lepus_europaeus_review_points.geojson"

gdf = gpd.read_file(path, engine="fiona")

gdf.head()
# Out:
#        gbifID          species  decimalLatitude  decimalLongitude countryCode  \
# 0  5027669378  Lepus europaeus        37.094757         -8.333302          PT
# 1  5021531841  Lepus europaeus        37.086269         -7.662406          PT
# 2  5019951673  Lepus europaeus        37.105301         -8.347549          PT
# 3  5019437769  Lepus europaeus        37.231251         -7.426887          PT
# 4  5016571128  Lepus europaeus        39.008831         -7.047425          PT
#
#    eventDate      basisOfRecord  coordinateUncertaintyInMeters  year  month  \
# 0 2012-10-16  HUMAN_OBSERVATION                          250.0  2012     10
# 1 2012-03-10  HUMAN_OBSERVATION                          250.0  2012      3
# 2 2012-10-22  HUMAN_OBSERVATION                          250.0  2012     10
# 3 2007-03-31  HUMAN_OBSERVATION                          250.0  2007      3
# 4 2017-01-30  HUMAN_OBSERVATION                          250.0  2017      1
#
#    day                   geometry
# 0   16   POINT (-8.3333 37.09476)
# 1   10  POINT (-7.66241 37.08627)
# 2   22   POINT (-8.34755 37.1053)
# 3   31  POINT (-7.42689 37.23125)
# 4   30  POINT (-7.04742 39.00883)

# %%
gdf["coordinateUncertaintyInMeters"].describe()
# Out:
# count      9.0
# mean     225.0
# std       75.0
# min       25.0
# 25%      250.0
# 50%      250.0
# 75%      250.0
# max      250.0
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
gdf["coordinateUncertaintyInMeters"] = gdf["coordinateUncertaintyInMeters"].astype(float)

# %%
gdf_clean = gdf[gdf["coordinateUncertaintyInMeters"] <= 30].copy()

# %%
gdf_clean = gdf_clean.dropna(subset=["coordinateUncertaintyInMeters"])

# %%
print(len(gdf), "original records")
print(len(gdf_clean), "after cleaning")
# Out:
# 10 original records
# 1 after cleaning

# %%
# Update path & layer name here

gpkg_path = "/home/linda/Documents/myData/data-management/data/processed/species/Lepus_europaeus/Lepus_europaeus_clean.gpkg"

gdf_clean.to_file(
    gpkg_path,
    layer="spp_clean",
    driver="GPKG"
)

print(gpkg_path)
# Out:
# /home/linda/Documents/myData/data-management/data/processed/species/Lepus_europaeus/Lepus_europaeus_clean.gpkg
